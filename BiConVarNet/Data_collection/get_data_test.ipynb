# %%
import pandas as pd

# 파일 경로
file_path = r"C:\Users\Kunny\Research\Dataset\Missense Variant dataset\annotateAll\dbNSFP5.1_nsSNV.chr1.gz"

# 파일 읽기 (열이 매우 많기 때문에 low_memory=False로 설정)
df = pd.read_csv(file_path, sep='\t', compression='gzip', low_memory=False)

# %%
print(df[-1:])
# Out:
#          #chr  pos(1-based) ref alt aaref aaalt hg19_chr hg19_pos(1-based)  \
# 8355140     1     248918363   A   T     X     C        1         249212562
#
#         hg18_chr hg18_pos(1-based)     genename cds_strand refcodon codonpos  \
# 8355140        1         247179185  PGBD2;PGBD2        +;+  TGA;TGA      3;3
#
#                           Ensembl_geneid             Ensembl_transcriptid  \
# 8355140  ENSG00000185220;ENSG00000185220  ENST00000355360;ENST00000329291
#
#                        Ensembl_proteinid    aapos
# 8355140  ENSP00000355424;ENSP00000331643  342;593

# %% [markdown]
# df[-1]
