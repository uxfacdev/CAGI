# %%
import os
import pickle
import torch
from torch.utils.data import Dataset
import random

AA_TO_INDEX = {
    'A': 0, 'C': 1, 'D': 2, 'E': 3, 'F': 4,
    'G': 5, 'H': 6, 'I': 7, 'K': 8, 'L': 9,
    'M': 10, 'N': 11, 'P': 12, 'Q': 13, 'R': 14,
    'S': 15, 'T': 16, 'V': 17, 'W': 18, 'Y': 19,
    '-': 20, 'X': 20  # padding 또는 unknown
}

def random_voxel_rotate(voxel):
    # voxel: Tensor [C, D, H, W]
    if random.random() < 0.5:  # 50% 확률로 회전 적용
        axes = [(2, 3), (1, 3), (1, 2)]  # (H, W), (D, W), (D, H)
        k = random.choice([1, 2, 3])  # 실제 회전만 (0 제외)
        axis = random.choice(axes)
        voxel = torch.rot90(voxel, k=k, dims=axis)
    return voxel

def random_voxel_flip(voxel):
    if random.random() < 0.5:
        voxel = torch.flip(voxel, dims=[1])  # D-axis flip
    if random.random() < 0.5:
        voxel = torch.flip(voxel, dims=[2])  # H-axis flip
    if random.random() < 0.5:
        voxel = torch.flip(voxel, dims=[3])  # W-axis flip
    return voxel

class VoxelDataset(Dataset):
    def __init__(self, df, voxel_cache_dir, aug=False, symmetry=False):
        self.df = df.reset_index(drop=True)
        self.voxel_cache_dir = voxel_cache_dir
        self.aug = aug
        self.symmetry = symmetry

    def __len__(self):
        return len(self.df) * 2 if self.symmetry else len(self.df)

    def __getitem__(self, idx):

        if self.symmetry:
            real_idx = idx // 2
            is_reverse = idx % 2  # 0이면 정방향, 1이면 역방향
        else:
            real_idx = idx
            is_reverse = 0

        row = self.df.iloc[real_idx]
        uid = row["PDB"]
        mut_pos = row["MAPPED_PDB_POS"]
        wt = row["WT"]
        mut = row["MT"]
        label = row["DDG"]

        key = f"{uid}_{mut_pos}"
        voxel_path = os.path.join(self.voxel_cache_dir, f"{key}.pkl")

        # Load voxel
        with open(voxel_path, "rb") as f:
            data = pickle.load(f)
            feature = data["feature"]  # shape: (1, 7, 7, 7, 63)

        # Preprocess
        feature_tensor = torch.from_numpy(feature).permute(0, 4, 1, 2, 3).float().squeeze(0)  # (63, 7, 7, 7)

        if self.aug:
            feature_tensor = random_voxel_rotate(feature_tensor)
            feature_tensor = random_voxel_flip(feature_tensor)
        
        if is_reverse == 0:
            # Convert WT/Mut AA to index
            ref_idx = torch.tensor(AA_TO_INDEX.get(str(wt), 20), dtype=torch.long)
            mut_idx = torch.tensor(AA_TO_INDEX.get(str(mut), 20), dtype=torch.long)
            target_label = label
        else:
            mut_idx = torch.tensor(AA_TO_INDEX.get(str(wt), 20), dtype=torch.long)
            ref_idx = torch.tensor(AA_TO_INDEX.get(str(mut), 20), dtype=torch.long)
            target_label = -label

        return feature_tensor, ref_idx, mut_idx, torch.tensor(target_label).float()
    
class MSADataset(Dataset):
    def __init__(self, df, msa_dict_path, max_depth=80, win_size=61, aug=False, symmetry=False):
        with open(msa_dict_path, "rb") as f:
            self.msa_dict = pickle.load(f)
        self.df = df
        self.max_depth = max_depth
        self.win_size = win_size
        self.half_win = win_size // 2  # 중심에서 양쪽 길이
        self.aug = aug
        self.symmetry = symmetry
        
    def __len__(self):
        return len(self.df) * 2 if self.symmetry else len(self.df)

    def __getitem__(self, idx):

        if self.symmetry:
            real_idx = idx // 2
            is_reverse = idx % 2  # 0이면 정방향, 1이면 역방향
        else:
            real_idx = idx
            is_reverse = 0

        row = self.df.iloc[real_idx]
        uid = row["PDB"]
        mut_pos = int(row["POS"]) - 1  # 1-based → 0-based
        mut = row["MT"].upper()
        label = row["DDG"]

        msa_seqs = [seq for _, seq in self.msa_dict[uid][:self.max_depth]]
        query_seq = msa_seqs[0]  # 보통 첫 줄이 ref seq

        # 변이 반영된 mut_seq 생성
        mut_seq = list(query_seq)
        if 0 <= mut_pos < len(mut_seq):
            mut_seq[mut_pos] = mut

        # --- 핵심 로직: 1, 2행 구성 ---
        if is_reverse == 0:
            # 정방향 (Mut -> WT): 기존 방식
            seqs_to_use = [mut_seq, list(query_seq)]
            target_label = label
        else:
            # 역방향 (WT -> Mut): 대칭 증강
            seqs_to_use = [list(query_seq), mut_seq]
            target_label = -label  # 라벨 부호 반전
            
        if len(msa_seqs) > 1:
            seqs_to_use += [list(seq) for seq in msa_seqs[1:self.max_depth - 2]]

        if self.aug:
            msa_part = seqs_to_use[2:]  # 변이+ref 제외
            random.shuffle(msa_part)   # 순서 섞기
            seqs_to_use = seqs_to_use[:2] + msa_part

        centered_msa = []
        for seq in seqs_to_use:
            window = []
            for i in range(self.win_size):
                seq_idx = mut_pos - self.half_win + i
                if 0 <= seq_idx < len(seq):
                    aa = seq[seq_idx]
                else:
                    aa = '-'
                window.append(AA_TO_INDEX.get(aa, 20))
            centered_msa.append(window)

        # depth padding
        while len(centered_msa) < self.max_depth:
            centered_msa.append([20] * self.win_size)  # 20은 패딩 인덱스

        msa_tensor = torch.tensor(centered_msa[:self.max_depth]).long()  # [D, L]
        msa_tensor = msa_tensor.transpose(0, 1)  # [L, D]

        return {
            "msa": msa_tensor,  # [L, D]
            "label": torch.tensor(target_label).float()
        }

class MultimodalDataset(Dataset):
    def __init__(self, df, voxel_cache_dir, msa_dict_path, 
                 voxel_aug=False, msa_aug=False, max_depth=80, win_size=61, symmetry=False):
        self.df = df.reset_index(drop=True)
        self.voxel_dataset = VoxelDataset(df, voxel_cache_dir, aug=voxel_aug, symmetry=symmetry)
        self.msa_dataset = MSADataset(df, msa_dict_path, max_depth=max_depth, win_size=win_size, aug=msa_aug, symmetry=symmetry)
        self.symmetry = symmetry
        
    def __len__(self):
        return len(self.df) * 2 if self.symmetry else len(self.df)

    def __getitem__(self, idx):
        voxel_feat, ref_idx, mut_idx, label = self.voxel_dataset[idx]
        msa_data = self.msa_dataset[idx]  # returns dict with "msa", "label"
        msa_tensor = msa_data["msa"]
        
        # 라벨 일치 확인 (안전용)
        assert label == msa_data["label"], "Mismatch in label!"

        return {
            "voxel": voxel_feat,      # [63, 7, 7, 7]
            "ref_idx": ref_idx,
            "mut_idx": mut_idx,
            "msa": msa_tensor,        # [L=61, D]
            "label": label
        }

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
    
import torch

# %%
import torch
import torch.nn as nn

# --- Voxel (Structural) Branch Components ---

class SqueezeExcitation3D(nn.Module):
    """3D SE block for channel-wise attention in voxel space."""
    def __init__(self, in_channels, reduction=24):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool3d(1)
        self.se = nn.Sequential(
            nn.Conv3d(in_channels, in_channels // reduction, kernel_size=1),
            nn.SiLU(),
            nn.Conv3d(in_channels // reduction, in_channels, kernel_size=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return x * self.se(self.pool(x))

class MBConv3D(nn.Module):
    """3D Inverted Residual Block (MobileNetV3 style) for efficient structural learning."""
    def __init__(self, in_ch, out_ch, expand_ratio=6, kernel_size=3, stride=1, se_reduction=16):
        super().__init__()
        mid_ch = in_ch * expand_ratio
        self.use_res_connect = (stride == 1 and in_ch == out_ch)

        self.expand = nn.Sequential(
            nn.Conv3d(in_ch, mid_ch, kernel_size=1, bias=False),
            nn.BatchNorm3d(mid_ch),
            nn.SiLU()
        ) if expand_ratio != 1 else nn.Identity()

        self.depthwise = nn.Sequential(
            nn.Conv3d(mid_ch, mid_ch, kernel_size=kernel_size, stride=stride,
                      padding=kernel_size//2, groups=mid_ch, bias=False),
            nn.BatchNorm3d(mid_ch),
            nn.SiLU()
        )

        self.se = SqueezeExcitation3D(mid_ch, reduction=se_reduction)
        self.project = nn.Sequential(
            nn.Conv3d(mid_ch, out_ch, kernel_size=1, bias=False),
            nn.BatchNorm3d(out_ch)
        )

    def forward(self, x):
        identity = x
        out = self.project(self.se(self.depthwise(self.expand(x))))

        return out + identity if self.use_res_connect else out


class h_sigmoid(nn.Module):
    def __init__(self, inplace=True):
        super().__init__()
        self.relu = nn.ReLU6(inplace=inplace)

    def forward(self, x):
        return self.relu(x + 3) / 6

class h_swish(nn.Module):
    def __init__(self, inplace=True):
        super().__init__()
        self.sigmoid = h_sigmoid(inplace=inplace)

    def forward(self, x):
        return x * self.sigmoid(x)

class CoordAtt3D(nn.Module):
    """3D Coordinate Attention for capturing long-range spatial dependencies along D, H, W axes."""
    def __init__(self, inp, oup, reduction=16):
        super().__init__()
        self.pool_d = nn.AdaptiveAvgPool3d((None, 1, 1))  
        self.pool_h = nn.AdaptiveAvgPool3d((1, None, 1)) 
        self.pool_w = nn.AdaptiveAvgPool3d((1, 1, None))  

        mip = max(8, inp // reduction)
        self.conv1 = nn.Conv3d(inp, mip, kernel_size=1, stride=1)
        self.bn1 = nn.BatchNorm3d(mip)
        self.act = h_swish()

        self.conv_d = nn.Conv3d(mip, oup, kernel_size=1, stride=1)
        self.conv_h = nn.Conv3d(mip, oup, kernel_size=1, stride=1)
        self.conv_w = nn.Conv3d(mip, oup, kernel_size=1, stride=1)

    def forward(self, x):
        identity = x
        B, C, D, H, W = x.size()

        # Pooling along axes
        x_d = self.pool_d(x)
        x_h = self.pool_h(x).permute(0, 1, 3, 2, 4)
        x_w = self.pool_w(x).permute(0, 1, 4, 2, 3)

        # Concatenate and encode spatial info
        y = self.act(self.bn1(self.conv1(torch.cat([x_d, x_h, x_w], dim=2))))
        y_d, y_h, y_w = torch.split(y, [D, H, W], dim=2)

        # Restore dimensions and apply sigmoid
        a_d = self.conv_d(y_d).sigmoid()
        a_h = self.conv_h(y_h.permute(0, 1, 3, 2, 4)).sigmoid()
        a_w = self.conv_w(y_w.permute(0, 1, 3, 4, 2)).sigmoid()
        
        return identity * a_d * a_h * a_w


class StructuralMutationAttention(nn.Module):
    """
    Option 2: 변이 정보(Mutation)를 Query로 하여 
    구조 피처(Voxel)의 중요한 부분을 선택적으로 강조하는 어텐션
    """
    def __init__(self, feat_dim, mut_dim):
        super().__init__()
        self.mut_to_query = nn.Linear(mut_dim, feat_dim)
        self.kv_conv = nn.Conv3d(feat_dim, feat_dim * 2, kernel_size=1)
        self.scale = feat_dim ** -0.5
        self.final_conv = nn.Conv3d(feat_dim, feat_dim, kernel_size=1)

    def forward(self, x, mut_emb):
        # x: [B, C, D, H, W] (구조 피처 맵)
        # mut_emb: [B, mut_dim] (변이 아미노산 임베딩)
        B, C, D, H, W = x.shape
        
        # 1. Query 생성: 변이 정보를 구조 피처와 같은 차원으로 매핑
        q = self.mut_to_query(mut_emb).view(B, 1, C) # [B, 1, C]
        
        # 2. Key, Value 생성: 3D 공간의 각 위치를 Key/Value로 변환
        kv = self.kv_conv(x).view(B, 2*C, -1).permute(0, 2, 1) # [B, D*H*W, 2*C]
        k, v = torch.chunk(kv, 2, dim=-1) # 각각 [B, D*H*W, C]

        # 3. Attention Score: "변이가 구조의 어느 위치와 관련 깊은가?"
        # [B, 1, C] @ [B, C, D*H*W] -> [B, 1, D*H*W]
        attn = torch.bmm(q, k.transpose(1, 2)) * self.scale
        attn = attn.softmax(dim=-1)
        
        # 4. Attention 적용
        # [B, 1, D*H*W] @ [B, D*H*W, C] -> [B, 1, C]
        out = torch.bmm(attn, v).view(B, C, 1, 1, 1)
        
        # 5. Gating: 구조 피처 맵에 어텐션 결과 반영
        return x * out.sigmoid()

class VoxelBranch(nn.Module):
    def __init__(self, in_ch=63, emb_dim=128):
        super().__init__()
        
        # 스테이지 1: 초기 구조 특징 추출
        self.stage1 = nn.Sequential(
            MBConv3D(in_ch, 32), MBConv3D(32, 48),
            MBConv3D(48, 64), MBConv3D(64, 64, stride=2) # 4x4x4 하향 샘플링
        )

        # --- [Option 2: Mid-Attention] ---
        # 64채널 시점에서 변이 정보 주입
        self.mut_mid_attn = StructuralMutationAttention(64, emb_dim // 2)
        
        # 스테이지 2: 심층 특징 추출
        self.stage2 = nn.Sequential(
            MBConv3D(64, 96), MBConv3D(96, 96),
            MBConv3D(96, 96), MBConv3D(96, 128),
            MBConv3D(128, emb_dim), MBConv3D(emb_dim, emb_dim)
        )

        self.coordatt = CoordAtt3D(emb_dim, emb_dim)
        self.pool = nn.AdaptiveAvgPool3d(1)

        # 임베딩 레이어
        self.ref_emb = nn.Embedding(21, emb_dim // 2)
        self.mut_emb = nn.Embedding(21, emb_dim // 2)
        
        # 최종 융합 헤드
        self.fusion = nn.Sequential(
            nn.Linear(emb_dim * 2, emb_dim),
            nn.BatchNorm1d(emb_dim),
            nn.SiLU(),
            nn.Linear(emb_dim, emb_dim)
        )

    def forward(self, x, ref_idx, mut_idx):
        # 1. 변이 임베딩 생성
        r_emb = self.ref_emb(ref_idx)
        m_emb = self.mut_emb(mut_idx)
        mut_context = torch.cat([r_emb, m_emb], dim=1) # [B, emb_dim]

        # 2. 스테이지 1 통과 (구조 정보)
        x = self.stage1(x)

        # 3. [Option 2 적용] 변이 정보를 기반으로 구조 피처 필터링
        # m_emb (64차원)를 Query로 사용하여 64채널의 x를 Attention
        x = self.mut_mid_attn(x, m_emb)

        # 4. 스테이지 2 통과
        x = self.stage2(x)
        struct_feat = self.pool(self.coordatt(x)).flatten(1)

        # 5. 최종 결합 (Late Fusion)
        combined = torch.cat([struct_feat, mut_context], dim=1)
        return self.fusion(combined)


import torch
import torch.nn as nn
from mamba_ssm import Mamba

# --- MSA (Sequence) Branch Components ---

class MSAInputEmbedding(nn.Module):
    """
    Converts raw MSA indices into continuous embedding space.
    Input: (B, L, D) -> Output: (B, L, D, C)
    """
    def __init__(self, vocab_size=21, dim=256):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings=vocab_size, embedding_dim=dim)

    def forward(self, x): 
        return self.embedding(x)  


class CrossAxialMambaMSA(nn.Module):
    """
    Hybrid block processing two axes:
    1. L-axis: Sequential context via Mamba (processed in parallel for all depths).
    2. D-axis: Evolutionary context via 1D-Conv (at the center mutation position).
    """
    def __init__(self, dim):
        super().__init__()
        self.norm_L = nn.RMSNorm(dim, eps=1e-8)
        self.norm_D = nn.RMSNorm(dim, eps=1e-8)

        self.mamba_L = Mamba(d_model=dim, expand=1)
        self.conv_D = nn.Sequential(
            nn.Conv1d(dim, dim, kernel_size=5, padding=2),
            nn.SiLU(),
            nn.Conv1d(dim, dim, kernel_size=5, padding=2),
            nn.SiLU()
        )

    def forward(self, x):  # x: (B, L, D, C)
        B, L, D, C = x.shape
        center_L = L // 2 
        
        # --- D-axis processing: 이제 모든 위치(L)에서 연산됨 ---
        res_d = self.norm_D(x).reshape(B * L, D, C).transpose(1, 2)
        d_out = self.conv_D(res_d).transpose(1, 2).view(B, L, D, C)

        # --- L-axis processing: Mamba ---
        x_l = self.norm_L(x).permute(0, 2, 1, 3).contiguous().view(B * D, L, C)
        l_out = self.mamba_L(x_l).view(B, D, L, C).permute(0, 2, 1, 3) 

        # --- Residual Connection: d_out이 이미 x와 같은 크기이므로 바로 더함 ---
        # d_full 부분을 삭제하고 d_out을 직접 더합니다.
        return x + d_out + l_out
    
class MSAEncoder(nn.Module):
    """Stack of Cross-Axial Mamba blocks for evolutionary feature extraction."""
    def __init__(self, num_layers=8, dim=256):
        super().__init__()
        self.embeddings = MSAInputEmbedding(dim=dim)
        self.blocks = nn.ModuleList([
            CrossAxialMambaMSA(dim) for _ in range(num_layers)
        ])
        self.norm_f = nn.RMSNorm(dim, eps=1e-8)

    def forward(self, x):  
        x = self.embeddings(x)  
        for block in self.blocks:
            x = block(x)
        return self.norm_f(x)  

class CenterAwarePooling(nn.Module):
    """
    Uses Multi-head Attention to aggregate global MSA context 
    using the center mutation site as the Query.
    """
    def __init__(self, dim, num_heads=8):
        super().__init__()
        self.attn = nn.MultiheadAttention(embed_dim=dim, num_heads=num_heads, batch_first=True)

        self.gate = nn.Sequential(
            nn.Linear(dim, dim // 2),
            nn.SiLU(),
            nn.Linear(dim // 2, 1)
        )
        
    def forward(self, x):  # x: (B, L, D, C)
        B, L, D, C = x.shape
        center_L = L // 2

        # Query: center residue profile [B*D, 1, C]
        query = x[:, center_L].reshape(B * D, 1, C)
        # Key/Value: entire window [B*D, L, C]
        keyval = x.permute(0, 2, 1, 3).reshape(B * D, L, C)

        attn_out, _ = self.attn(query, keyval, keyval)   # (B*D, 1, C)
        
    
        # 2. 서열별 특징 추출 [B, D, C]
        per_seq_feats = attn_out.view(B, D, C)
        
        # 3. [진짜 수정 포인트] Gated Attention Pooling
        # 각 Depth 서열이 얼마나 중요한지 점수를 매김 (Softmax)
        gate_weights = self.gate(per_seq_feats) # [B, D, 1]
        gate_weights = torch.softmax(gate_weights, dim=1) # 80개 서열의 중요도 합 = 1
        
        # 가중 평균 수행 (Weighted Sum)
        pooled = torch.sum(per_seq_feats * gate_weights, dim=1) # [B, C]

        return pooled
    
class MSABranch(nn.Module):
    """Complete MSA processing branch."""
    def __init__(self, num_layers=4, dim=128):
        super().__init__()
        self.encoder = MSAEncoder(num_layers=num_layers, dim=dim)
        self.pooling = CenterAwarePooling(dim, num_heads=4)
        self.refine = nn.Sequential(
            nn.Linear(dim, dim),
            nn.BatchNorm1d(dim),
            nn.SiLU()
        )

    def forward(self, x):  
        x = self.encoder(x)        
        x = self.pooling(x)        
        return self.refine(x)     
    
import numpy as np
import torch.nn.functional as F

# --- Main Multimodal Model ---
    
class EvoStructCLIP(nn.Module):
    """
    EvoStructCLIP: A Multimodal framework for Variant Effect Prediction.
    Integrates evolutionary information (MSA) and 3D structural context (Voxel).
    Uses Contrastive Learning (CLIP-style) and Classification.
    """
    def __init__(self, voxel_ch=63, mb_layers=12, embed_dim=128, use_concat=True):
        super().__init__()
        self.voxel_encoder = VoxelBranch(in_ch=voxel_ch, emb_dim=embed_dim)
        self.msa_encoder = MSABranch(num_layers=mb_layers, dim=embed_dim)
        self.use_concat = use_concat

        # CLIP temperature parameter
        self.logit_scale = nn.Parameter(torch.ones([]) * np.log(1 / 0.07))

    def forward(self, voxel, ref_idx, mut_idx, msa):
        # 1. Extract features from both modalities
        voxel_feat = self.voxel_encoder(voxel, ref_idx, mut_idx) # (B, 128)
        msa_feat = self.msa_encoder(msa)                       # (B, 128)

        # 2. Compute Contrastive Logits (CLIP-style)
        v_norm = F.normalize(voxel_feat, dim=-1, eps=1e-8)
        m_norm = F.normalize(msa_feat, dim=-1, eps=1e-8)

        scale = self.logit_scale.exp()
        logits_per_voxel = torch.matmul(v_norm, m_norm.t()) * scale
        logits_per_msa = logits_per_voxel.t() 

        return {
            "logits_per_msa": logits_per_msa,
            "logits_per_voxel": logits_per_voxel,
            "voxel_feat": voxel_feat,
            "msa_feat": msa_feat
        }

# %%
import torch
import torch.nn as nn

class Adapter(nn.Module):
    """CLIP 피처를 Regression task에 맞게 정제하는 어댑터"""
    def __init__(self, dim, bottleneck_dim=256):
        super().__init__()
        self.adapter = nn.Sequential(
            nn.Linear(dim, bottleneck_dim),
            nn.BatchNorm1d(bottleneck_dim),
            nn.SiLU(),
            nn.Linear(bottleneck_dim, dim),
            nn.SiLU(),
        )
        self.norm = nn.RMSNorm(dim, eps=1e-8)

    def forward(self, x):
        # Residual connection: 기존 CLIP 피처 + 변형된 피처
        return self.adapter(x)

class EvoStructAdapterRegressor(nn.Module):
    def __init__(self, clip_model_path, voxel_ch=45, embed_dim=128):
        super().__init__()
        # 1. 기존 CLIP 모델 로드 및 Frozen
        self.clip_model = EvoStructCLIP(voxel_ch=voxel_ch, mb_layers=6, embed_dim=embed_dim)

        if clip_model_path:
            ckpt = torch.load(clip_model_path, map_location="cpu")
            self.clip_model.load_state_dict(ckpt, strict=True)

            for param in self.clip_model.parameters():
                param.requires_grad = False
        
        # 2. 각 브랜치별 전용 어댑터 (타이밍: CLIP 인코딩 직후)
        self.voxel_adapter = Adapter(dim=embed_dim)
        self.msa_adapter = Adapter(dim=embed_dim)
        
        # 3. 추가적인 시퀀스 정보(Diff 등)를 위한 결합 레이어
        # (현재 extract_features에서 사용하던 mut_seq, wt_seq, diff 등을 모두 고려)
        # 만약 단순 concat이라면 128 * 2 = 256
        self.regressor_head = nn.Sequential(
            nn.Linear(embed_dim * 2, embed_dim),
            nn.BatchNorm1d(embed_dim),
            nn.SiLU(),
            nn.Linear(embed_dim, 1)
        )

    def forward(self, msa, voxel, ref_idx, mut_idx):
        # CLIP 인코더에서 피처 추출 (No Grad context 내부에서 동작 권장)
        with torch.no_grad():
            voxel_raw = self.clip_model.voxel_encoder(voxel, ref_idx, mut_idx)
            msa_raw = self.clip_model.msa_encoder(msa)
        
        # 어댑터 적용 (이 부분만 학습됨)
        voxel_adapted = self.voxel_adapter(voxel_raw)
        msa_adapted = self.msa_adapter(msa_raw)
        
        # Concat 및 최종 회귀
        fused = torch.cat([voxel_adapted, msa_adapted], dim=-1)
        return self.regressor_head(fused).squeeze(-1)

# %%
import torch.optim as optim
from scipy.stats import pearsonr
from tqdm.auto import tqdm
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import CosineAnnealingLR

def pearson_loss(x, y):
    mx = torch.mean(x)
    my = torch.mean(y)
    xm, ym = x - mx, y - my
    r_num = torch.sum(xm * ym)
    r_den = torch.sqrt(torch.sum(xm**2) * torch.sum(ym**2) + 1e-8)
    r = r_num / r_den
    return 1 - r  # 상관계수가 1에 가까울수록 Loss는 0

def train_one_fold(fold_idx, train_df, val_df, test_loader, msa_dict_path, voxel_cache_dir, clip_weight_path):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # 1. 데이터로더 구성 (학습 효율을 위해 num_workers 설정)
    train_ds = MultimodalDataset(train_df, voxel_cache_dir, msa_dict_path, voxel_aug=False, msa_aug=False, symmetry=True)
    val_ds   = MultimodalDataset(val_df, voxel_cache_dir, msa_dict_path,symmetry=False)
    train_loader = DataLoader(train_ds, batch_size=80, shuffle=True, num_workers=6, pin_memory=True)
    val_loader = DataLoader(val_ds, batch_size=16, shuffle=False, num_workers=4, pin_memory=True)
    
    # 2. 모델 및 최적화 설정
    model = EvoStructAdapterRegressor(clip_weight_path).to(device)
    criterion = nn.HuberLoss(delta=1.0) 
    optimizer = torch.optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=5e-4,  weight_decay=0.1)
    # 3. Cosine Annealing Scheduler 추가
    # T_max는 반주기 에폭 수입니다. 보통 전체 에폭 수와 같게 설정하여 끝까지 서서히 줄어들게 합니다.
    epochs = 10000
    scheduler = CosineAnnealingLR(optimizer, T_max=100  , eta_min=1e-6)
    
    # 4. Early Stopping 설정
    patience = 100 # 15 에폭 동안 Pearson 점수가 오르지 않으면 중단
    counter = 0
    best_pearson = -1.0
    best_pearson_test = -1.0
    

    for epoch in range(epochs):
        # --- Training Phase ---
        model.train()
        total_loss = 0
        for batch in train_loader:
            msa = batch["msa"].to(device)
            labels = batch["label"].to(device)
            voxel = batch["voxel"].to(device)
            ref_idx = batch["ref_idx"].to(device)
            mut_idx = batch["mut_idx"].to(device)
            
            optimizer.zero_grad()
            preds = model(msa, voxel, ref_idx, mut_idx)
            loss = criterion(preds, labels) + 0.5 * pearson_loss(preds, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        
        # --- Validation Phase ---
        model.eval()
        all_preds, all_labels = [], []
        with torch.no_grad():
            for batch in val_loader:
                msa = batch["msa"].to(device)
                labels = batch["label"].to(device)
                voxel = batch["voxel"].to(device)
                ref_idx = batch["ref_idx"].to(device)
                mut_idx = batch["mut_idx"].to(device)

                preds = model(msa, voxel, ref_idx, mut_idx) 
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        
        # Pearson 상관계수 계산
        fold_pearson, _ = pearsonr(all_labels, all_preds)
        
        # 스케줄러 스텝 (Cosine Decay 적용)
        scheduler.step()
        current_lr = optimizer.param_groups[0]['lr']
        
        # --- Early Stopping & Model Save Logic ---
        if fold_pearson > best_pearson:
            best_pearson = fold_pearson
            torch.save(model.state_dict(), f"best_reg_fold_{fold_idx}_0119.pth")
            counter = 0 # 개선되었으므로 카운터 리셋
        else:
            counter += 1 # 개선되지 않음
            
        print(f"Fold {fold_idx} | Ep {epoch+1:3d}/{epochs} | LR: {current_lr:.6f} | Loss: {total_loss/len(train_loader):.4f} | Pearson: {fold_pearson:.4f} | Best: {best_pearson:.4f}")
        
        if counter >= patience:
            print(f"!!! Early Stopping triggered at epoch {epoch+1} !!!")
            break

        # --- test Phase ---
        model.eval()
        all_preds, all_labels = [], []
        with torch.no_grad():
            for batch in test_loader:
                msa = batch["msa"].to(device)
                labels = batch["label"].to(device)
                voxel = batch["voxel"].to(device)
                ref_idx = batch["ref_idx"].to(device)
                mut_idx = batch["mut_idx"].to(device)

                preds = model(msa, voxel, ref_idx, mut_idx) 
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        
        # Pearson 상관계수 계산
        fold_pearson, _ = pearsonr(all_labels, all_preds)
        
        # --- Early Stopping & Model Save Logic ---
        if fold_pearson > best_pearson_test:
            best_pearson_test = fold_pearson
            torch.save(model.state_dict(), f"best_test_reg_fold_{fold_idx}_0119.pth")
            
        print(f"[Test] Fold {fold_idx} | Ep {epoch+1:3d}/{epochs} | Pearson: {fold_pearson:.4f} | Best: {best_pearson_test:.4f}")

    del model, optimizer, scheduler, train_loader, val_loader, test_loader
    return best_pearson

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"/mnt/c/Users/Kunny/Documents/GitHub/CAGI/EvoStructCLIP/Stability/S2450_Final_PDB_Mapped.tsv", sep="\t", )

# 경로 설정
msa_dict_path = "/mnt/e/CAGI_data/msa_dict_S2450.pkl"
voxel_cache_dir = "/mnt/e/CAGI_data/voxel_cache_S2450"
clip_weight_path = f"/mnt/e/CAGI_data/best_clip_model_260116.pth"
fold_list = sorted(df['CVFOLD'].unique())

final_results = []


#----- test -----
test_tsv_path = "/mnt/c/Users/Kunny/Documents/GitHub/CAGI/EvoStructCLIP/Stability/S669_Offset_Corrected.tsv"
msa_dict_path_test = "/mnt/e/CAGI_data/msa_dict_S669.pkl"
voxel_cache_dir_test = "/mnt/e/CAGI_data/voxel_cache_S669"

test_df = pd.read_csv(test_tsv_path, sep="\t")
test_ds = MultimodalDataset(test_df, voxel_cache_dir_test, msa_dict_path_test, symmetry=False)
test_loader = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2)

for f_idx in fold_list:
    print(f"\n--- Starting 5-Fold Cross Validation: Fold {f_idx} ---")
    val_df = df[df['CVFOLD'] == f_idx].copy()
    train_df = df[df['CVFOLD'] != f_idx].copy()
    
    best_score = train_one_fold(f_idx, train_df, val_df, test_loader, msa_dict_path, voxel_cache_dir, clip_weight_path)
    final_results.append(best_score)

print("\n" + "="*40)
print(f"5-Fold CV Average Pearson Correlation: {np.mean(final_results):.4f}")
print("="*40)
# Out:
# --- Starting 5-Fold Cross Validation: Fold 0 ---
# Fold 0 | Ep   1/10000 | LR: 0.000500 | Loss: 1.1313 | Pearson: 0.3686 | Best: 0.3686
# [Test] Fold 0 | Ep   1/10000 | Pearson: 0.1896 | Best: 0.1896
# Fold 0 | Ep   2/10000 | LR: 0.000500 | Loss: 1.0236 | Pearson: 0.3830 | Best: 0.3830
# [Test] Fold 0 | Ep   2/10000 | Pearson: 0.2729 | Best: 0.2729
# Fold 0 | Ep   3/10000 | LR: 0.000499 | Loss: 0.9962 | Pearson: 0.3889 | Best: 0.3889
# [Test] Fold 0 | Ep   3/10000 | Pearson: 0.2631 | Best: 0.2729
# Fold 0 | Ep   4/10000 | LR: 0.000498 | Loss: 0.9564 | Pearson: 0.3734 | Best: 0.3889
# [Test] Fold 0 | Ep   4/10000 | Pearson: 0.2793 | Best: 0.2793
# Fold 0 | Ep   5/10000 | LR: 0.000497 | Loss: 0.9365 | Pearson: 0.3343 | Best: 0.3889
# [Test] Fold 0 | Ep   5/10000 | Pearson: 0.2817 | Best: 0.2817
# Fold 0 | Ep   6/10000 | LR: 0.000496 | Loss: 0.9362 | Pearson: 0.3503 | Best: 0.3889
# [Test] Fold 0 | Ep   6/10000 | Pearson: 0.2856 | Best: 0.2856
# Fold 0 | Ep   7/10000 | LR: 0.000494 | Loss: 0.9043 | Pearson: 0.3047 | Best: 0.3889
# [Test] Fold 0 | Ep   7/10000 | Pearson: 0.2990 | Best: 0.2990
# Fold 0 | Ep   8/10000 | LR: 0.000492 | Loss: 0.9076 | Pearson: 0.3475 | Best: 0.3889
# [Test] Fold 0 | Ep   8/10000 | Pearson: 0.2962 | Best: 0.2990
# Fold 0 | Ep   9/10000 | LR: 0.000490 | Loss: 0.8824 | Pearson: 0.3603 | Best: 0.3889
# [Test] Fold 0 | Ep   9/10000 | Pearson: 0.3090 | Best: 0.3090
# Fold 0 | Ep  10/10000 | LR: 0.000488 | Loss: 0.8718 | Pearson: 0.3383 | Best: 0.3889
# [Test] Fold 0 | Ep  10/10000 | Pearson: 0.2736 | Best: 0.3090
# Fold 0 | Ep  11/10000 | LR: 0.000485 | Loss: 0.8526 | Pearson: 0.3033 | Best: 0.3889
# [Test] Fold 0 | Ep  11/10000 | Pearson: 0.2941 | Best: 0.3090
# Fold 0 | Ep  12/10000 | LR: 0.000482 | Loss: 0.8552 | Pearson: 0.3268 | Best: 0.3889
# [Test] Fold 0 | Ep  12/10000 | Pearson: 0.3210 | Best: 0.3210
# Fold 0 | Ep  13/10000 | LR: 0.000479 | Loss: 0.8479 | Pearson: 0.3126 | Best: 0.3889
# [Test] Fold 0 | Ep  13/10000 | Pearson: 0.3172 | Best: 0.3210
# Fold 0 | Ep  14/10000 | LR: 0.000476 | Loss: 0.8154 | Pearson: 0.3072 | Best: 0.3889
# [Test] Fold 0 | Ep  14/10000 | Pearson: 0.3278 | Best: 0.3278
# Fold 0 | Ep  15/10000 | LR: 0.000473 | Loss: 0.8133 | Pearson: 0.3398 | Best: 0.3889
# [Test] Fold 0 | Ep  15/10000 | Pearson: 0.3149 | Best: 0.3278
# Fold 0 | Ep  16/10000 | LR: 0.000469 | Loss: 0.8154 | Pearson: 0.2908 | Best: 0.3889
# [Test] Fold 0 | Ep  16/10000 | Pearson: 0.2892 | Best: 0.3278
# Fold 0 | Ep  17/10000 | LR: 0.000465 | Loss: 0.8016 | Pearson: 0.3164 | Best: 0.3889
# [Test] Fold 0 | Ep  17/10000 | Pearson: 0.2873 | Best: 0.3278
# Fold 0 | Ep  18/10000 | LR: 0.000461 | Loss: 0.7946 | Pearson: 0.3274 | Best: 0.3889
# [Test] Fold 0 | Ep  18/10000 | Pearson: 0.3398 | Best: 0.3398
# Fold 0 | Ep  19/10000 | LR: 0.000457 | Loss: 0.7731 | Pearson: 0.3161 | Best: 0.3889
# [Test] Fold 0 | Ep  19/10000 | Pearson: 0.3152 | Best: 0.3398
# Fold 0 | Ep  20/10000 | LR: 0.000452 | Loss: 0.7838 | Pearson: 0.3321 | Best: 0.3889
# [Test] Fold 0 | Ep  20/10000 | Pearson: 0.3010 | Best: 0.3398
# Fold 0 | Ep  21/10000 | LR: 0.000448 | Loss: 0.7715 | Pearson: 0.3070 | Best: 0.3889
# [Test] Fold 0 | Ep  21/10000 | Pearson: 0.3100 | Best: 0.3398
# Fold 0 | Ep  22/10000 | LR: 0.000443 | Loss: 0.7485 | Pearson: 0.2827 | Best: 0.3889
# [Test] Fold 0 | Ep  22/10000 | Pearson: 0.2821 | Best: 0.3398
# Fold 0 | Ep  23/10000 | LR: 0.000438 | Loss: 0.7576 | Pearson: 0.3061 | Best: 0.3889
# [Test] Fold 0 | Ep  23/10000 | Pearson: 0.3059 | Best: 0.3398
# Fold 0 | Ep  24/10000 | LR: 0.000432 | Loss: 0.7383 | Pearson: 0.3060 | Best: 0.3889
# [Test] Fold 0 | Ep  24/10000 | Pearson: 0.3409 | Best: 0.3409
# Fold 0 | Ep  25/10000 | LR: 0.000427 | Loss: 0.7335 | Pearson: 0.3008 | Best: 0.3889
# [Test] Fold 0 | Ep  25/10000 | Pearson: 0.3172 | Best: 0.3409
# Fold 0 | Ep  26/10000 | LR: 0.000421 | Loss: 0.7263 | Pearson: 0.3016 | Best: 0.3889
# [Test] Fold 0 | Ep  26/10000 | Pearson: 0.3036 | Best: 0.3409
# Fold 0 | Ep  27/10000 | LR: 0.000415 | Loss: 0.7120 | Pearson: 0.2612 | Best: 0.3889
# [Test] Fold 0 | Ep  27/10000 | Pearson: 0.3205 | Best: 0.3409
# Fold 0 | Ep  28/10000 | LR: 0.000410 | Loss: 0.7095 | Pearson: 0.3137 | Best: 0.3889
# [Test] Fold 0 | Ep  28/10000 | Pearson: 0.3165 | Best: 0.3409
# Fold 0 | Ep  29/10000 | LR: 0.000403 | Loss: 0.6851 | Pearson: 0.2935 | Best: 0.3889
# [Test] Fold 0 | Ep  29/10000 | Pearson: 0.3015 | Best: 0.3409
# Fold 0 | Ep  30/10000 | LR: 0.000397 | Loss: 0.6910 | Pearson: 0.2586 | Best: 0.3889
# [Test] Fold 0 | Ep  30/10000 | Pearson: 0.2565 | Best: 0.3409
# Fold 0 | Ep  31/10000 | LR: 0.000391 | Loss: 0.6991 | Pearson: 0.3083 | Best: 0.3889
# [Test] Fold 0 | Ep  31/10000 | Pearson: 0.3229 | Best: 0.3409
# Fold 0 | Ep  32/10000 | LR: 0.000384 | Loss: 0.6781 | Pearson: 0.2830 | Best: 0.3889
# [Test] Fold 0 | Ep  32/10000 | Pearson: 0.3131 | Best: 0.3409
# Fold 0 | Ep  33/10000 | LR: 0.000378 | Loss: 0.6758 | Pearson: 0.3099 | Best: 0.3889
# [Test] Fold 0 | Ep  33/10000 | Pearson: 0.3200 | Best: 0.3409
# Fold 0 | Ep  34/10000 | LR: 0.000371 | Loss: 0.6545 | Pearson: 0.3070 | Best: 0.3889
# [Test] Fold 0 | Ep  34/10000 | Pearson: 0.2953 | Best: 0.3409
# Fold 0 | Ep  35/10000 | LR: 0.000364 | Loss: 0.6580 | Pearson: 0.2711 | Best: 0.3889
# [Test] Fold 0 | Ep  35/10000 | Pearson: 0.3155 | Best: 0.3409
# Fold 0 | Ep  36/10000 | LR: 0.000357 | Loss: 0.6368 | Pearson: 0.2870 | Best: 0.3889
# [Test] Fold 0 | Ep  36/10000 | Pearson: 0.3044 | Best: 0.3409
# Fold 0 | Ep  37/10000 | LR: 0.000350 | Loss: 0.6353 | Pearson: 0.2751 | Best: 0.3889
# [Test] Fold 0 | Ep  37/10000 | Pearson: 0.2783 | Best: 0.3409
# Fold 0 | Ep  38/10000 | LR: 0.000342 | Loss: 0.6238 | Pearson: 0.2597 | Best: 0.3889
# [Test] Fold 0 | Ep  38/10000 | Pearson: 0.2900 | Best: 0.3409
# Fold 0 | Ep  39/10000 | LR: 0.000335 | Loss: 0.6108 | Pearson: 0.2631 | Best: 0.3889
# [Test] Fold 0 | Ep  39/10000 | Pearson: 0.3178 | Best: 0.3409
# Fold 0 | Ep  40/10000 | LR: 0.000328 | Loss: 0.6042 | Pearson: 0.2587 | Best: 0.3889
# [Test] Fold 0 | Ep  40/10000 | Pearson: 0.2862 | Best: 0.3409
# Fold 0 | Ep  41/10000 | LR: 0.000320 | Loss: 0.5922 | Pearson: 0.2839 | Best: 0.3889
# [Test] Fold 0 | Ep  41/10000 | Pearson: 0.2861 | Best: 0.3409
# Fold 0 | Ep  42/10000 | LR: 0.000313 | Loss: 0.6003 | Pearson: 0.3045 | Best: 0.3889
# [Test] Fold 0 | Ep  42/10000 | Pearson: 0.2947 | Best: 0.3409
# Fold 0 | Ep  43/10000 | LR: 0.000305 | Loss: 0.5884 | Pearson: 0.2888 | Best: 0.3889
# [Test] Fold 0 | Ep  43/10000 | Pearson: 0.3111 | Best: 0.3409
# Fold 0 | Ep  44/10000 | LR: 0.000297 | Loss: 0.5861 | Pearson: 0.2944 | Best: 0.3889
# [Test] Fold 0 | Ep  44/10000 | Pearson: 0.2879 | Best: 0.3409
# Fold 0 | Ep  45/10000 | LR: 0.000290 | Loss: 0.5556 | Pearson: 0.2702 | Best: 0.3889
# [Test] Fold 0 | Ep  45/10000 | Pearson: 0.2985 | Best: 0.3409
# Fold 0 | Ep  46/10000 | LR: 0.000282 | Loss: 0.5648 | Pearson: 0.2811 | Best: 0.3889
# [Test] Fold 0 | Ep  46/10000 | Pearson: 0.3048 | Best: 0.3409
# Fold 0 | Ep  47/10000 | LR: 0.000274 | Loss: 0.5646 | Pearson: 0.2816 | Best: 0.3889
# [Test] Fold 0 | Ep  47/10000 | Pearson: 0.2806 | Best: 0.3409
# Fold 0 | Ep  48/10000 | LR: 0.000266 | Loss: 0.5449 | Pearson: 0.2834 | Best: 0.3889
# [Test] Fold 0 | Ep  48/10000 | Pearson: 0.2776 | Best: 0.3409
# Fold 0 | Ep  49/10000 | LR: 0.000258 | Loss: 0.5464 | Pearson: 0.2842 | Best: 0.3889
# [Test] Fold 0 | Ep  49/10000 | Pearson: 0.2638 | Best: 0.3409
# Fold 0 | Ep  50/10000 | LR: 0.000251 | Loss: 0.5450 | Pearson: 0.3082 | Best: 0.3889
# [Test] Fold 0 | Ep  50/10000 | Pearson: 0.3051 | Best: 0.3409
# Fold 0 | Ep  51/10000 | LR: 0.000243 | Loss: 0.5354 | Pearson: 0.2702 | Best: 0.3889
# [Test] Fold 0 | Ep  51/10000 | Pearson: 0.2607 | Best: 0.3409
# Fold 0 | Ep  52/10000 | LR: 0.000235 | Loss: 0.5307 | Pearson: 0.2695 | Best: 0.3889
# [Test] Fold 0 | Ep  52/10000 | Pearson: 0.2808 | Best: 0.3409
# Fold 0 | Ep  53/10000 | LR: 0.000227 | Loss: 0.5061 | Pearson: 0.2877 | Best: 0.3889
# [Test] Fold 0 | Ep  53/10000 | Pearson: 0.2726 | Best: 0.3409
# Fold 0 | Ep  54/10000 | LR: 0.000219 | Loss: 0.5180 | Pearson: 0.2714 | Best: 0.3889
# [Test] Fold 0 | Ep  54/10000 | Pearson: 0.2979 | Best: 0.3409
# Fold 0 | Ep  55/10000 | LR: 0.000211 | Loss: 0.5110 | Pearson: 0.2792 | Best: 0.3889
# [Test] Fold 0 | Ep  55/10000 | Pearson: 0.2706 | Best: 0.3409
# Fold 0 | Ep  56/10000 | LR: 0.000204 | Loss: 0.4922 | Pearson: 0.2731 | Best: 0.3889
# [Test] Fold 0 | Ep  56/10000 | Pearson: 0.2753 | Best: 0.3409
# Fold 0 | Ep  57/10000 | LR: 0.000196 | Loss: 0.4922 | Pearson: 0.2709 | Best: 0.3889
# [Test] Fold 0 | Ep  57/10000 | Pearson: 0.2833 | Best: 0.3409
# Fold 0 | Ep  58/10000 | LR: 0.000188 | Loss: 0.4867 | Pearson: 0.2681 | Best: 0.3889
# [Test] Fold 0 | Ep  58/10000 | Pearson: 0.2853 | Best: 0.3409
# Fold 0 | Ep  59/10000 | LR: 0.000181 | Loss: 0.4810 | Pearson: 0.2660 | Best: 0.3889
# [Test] Fold 0 | Ep  59/10000 | Pearson: 0.2613 | Best: 0.3409
# Fold 0 | Ep  60/10000 | LR: 0.000173 | Loss: 0.4985 | Pearson: 0.2511 | Best: 0.3889
# [Test] Fold 0 | Ep  60/10000 | Pearson: 0.2754 | Best: 0.3409
# Fold 0 | Ep  61/10000 | LR: 0.000166 | Loss: 0.4727 | Pearson: 0.2579 | Best: 0.3889
# [Test] Fold 0 | Ep  61/10000 | Pearson: 0.2620 | Best: 0.3409
# Fold 0 | Ep  62/10000 | LR: 0.000159 | Loss: 0.4590 | Pearson: 0.2467 | Best: 0.3889
# [Test] Fold 0 | Ep  62/10000 | Pearson: 0.2462 | Best: 0.3409
# Fold 0 | Ep  63/10000 | LR: 0.000151 | Loss: 0.4633 | Pearson: 0.2496 | Best: 0.3889
# [Test] Fold 0 | Ep  63/10000 | Pearson: 0.2719 | Best: 0.3409
# Fold 0 | Ep  64/10000 | LR: 0.000144 | Loss: 0.4630 | Pearson: 0.2643 | Best: 0.3889
# [Test] Fold 0 | Ep  64/10000 | Pearson: 0.2437 | Best: 0.3409
# Fold 0 | Ep  65/10000 | LR: 0.000137 | Loss: 0.4567 | Pearson: 0.2419 | Best: 0.3889
# [Test] Fold 0 | Ep  65/10000 | Pearson: 0.2667 | Best: 0.3409
# Fold 0 | Ep  66/10000 | LR: 0.000130 | Loss: 0.4439 | Pearson: 0.2551 | Best: 0.3889
# [Test] Fold 0 | Ep  66/10000 | Pearson: 0.2690 | Best: 0.3409
# Fold 0 | Ep  67/10000 | LR: 0.000123 | Loss: 0.4447 | Pearson: 0.2541 | Best: 0.3889
# [Test] Fold 0 | Ep  67/10000 | Pearson: 0.2718 | Best: 0.3409
# Fold 0 | Ep  68/10000 | LR: 0.000117 | Loss: 0.4301 | Pearson: 0.2614 | Best: 0.3889
# [Test] Fold 0 | Ep  68/10000 | Pearson: 0.2709 | Best: 0.3409
# Fold 0 | Ep  69/10000 | LR: 0.000110 | Loss: 0.4404 | Pearson: 0.2609 | Best: 0.3889
# [Test] Fold 0 | Ep  69/10000 | Pearson: 0.2752 | Best: 0.3409
# Fold 0 | Ep  70/10000 | LR: 0.000104 | Loss: 0.4311 | Pearson: 0.2603 | Best: 0.3889
# [Test] Fold 0 | Ep  70/10000 | Pearson: 0.2599 | Best: 0.3409
# Fold 0 | Ep  71/10000 | LR: 0.000098 | Loss: 0.4283 | Pearson: 0.2559 | Best: 0.3889
# [Test] Fold 0 | Ep  71/10000 | Pearson: 0.2677 | Best: 0.3409
# Fold 0 | Ep  72/10000 | LR: 0.000091 | Loss: 0.4307 | Pearson: 0.2689 | Best: 0.3889
# [Test] Fold 0 | Ep  72/10000 | Pearson: 0.2618 | Best: 0.3409
# Fold 0 | Ep  73/10000 | LR: 0.000086 | Loss: 0.4106 | Pearson: 0.2467 | Best: 0.3889
# [Test] Fold 0 | Ep  73/10000 | Pearson: 0.2500 | Best: 0.3409
# Fold 0 | Ep  74/10000 | LR: 0.000080 | Loss: 0.4198 | Pearson: 0.2469 | Best: 0.3889
# [Test] Fold 0 | Ep  74/10000 | Pearson: 0.2540 | Best: 0.3409
# Fold 0 | Ep  75/10000 | LR: 0.000074 | Loss: 0.4036 | Pearson: 0.2441 | Best: 0.3889
# [Test] Fold 0 | Ep  75/10000 | Pearson: 0.2498 | Best: 0.3409
# Fold 0 | Ep  76/10000 | LR: 0.000069 | Loss: 0.4074 | Pearson: 0.2573 | Best: 0.3889
# [Test] Fold 0 | Ep  76/10000 | Pearson: 0.2541 | Best: 0.3409
# Fold 0 | Ep  77/10000 | LR: 0.000063 | Loss: 0.4063 | Pearson: 0.2606 | Best: 0.3889
# [Test] Fold 0 | Ep  77/10000 | Pearson: 0.2604 | Best: 0.3409
# Fold 0 | Ep  78/10000 | LR: 0.000058 | Loss: 0.4051 | Pearson: 0.2437 | Best: 0.3889
# [Test] Fold 0 | Ep  78/10000 | Pearson: 0.2521 | Best: 0.3409
# Fold 0 | Ep  79/10000 | LR: 0.000053 | Loss: 0.3979 | Pearson: 0.2599 | Best: 0.3889
# [Test] Fold 0 | Ep  79/10000 | Pearson: 0.2643 | Best: 0.3409
# Fold 0 | Ep  80/10000 | LR: 0.000049 | Loss: 0.3968 | Pearson: 0.2581 | Best: 0.3889
# [Test] Fold 0 | Ep  80/10000 | Pearson: 0.2641 | Best: 0.3409
# Fold 0 | Ep  81/10000 | LR: 0.000044 | Loss: 0.3949 | Pearson: 0.2494 | Best: 0.3889
# [Test] Fold 0 | Ep  81/10000 | Pearson: 0.2625 | Best: 0.3409
# Fold 0 | Ep  82/10000 | LR: 0.000040 | Loss: 0.3921 | Pearson: 0.2670 | Best: 0.3889
# [Test] Fold 0 | Ep  82/10000 | Pearson: 0.2658 | Best: 0.3409
# Fold 0 | Ep  83/10000 | LR: 0.000036 | Loss: 0.3947 | Pearson: 0.2634 | Best: 0.3889
# [Test] Fold 0 | Ep  83/10000 | Pearson: 0.2566 | Best: 0.3409
# Fold 0 | Ep  84/10000 | LR: 0.000032 | Loss: 0.3854 | Pearson: 0.2484 | Best: 0.3889
# [Test] Fold 0 | Ep  84/10000 | Pearson: 0.2591 | Best: 0.3409
# Fold 0 | Ep  85/10000 | LR: 0.000028 | Loss: 0.3817 | Pearson: 0.2507 | Best: 0.3889
# [Test] Fold 0 | Ep  85/10000 | Pearson: 0.2487 | Best: 0.3409
# Fold 0 | Ep  86/10000 | LR: 0.000025 | Loss: 0.3765 | Pearson: 0.2496 | Best: 0.3889
# [Test] Fold 0 | Ep  86/10000 | Pearson: 0.2503 | Best: 0.3409
# Fold 0 | Ep  87/10000 | LR: 0.000022 | Loss: 0.3839 | Pearson: 0.2589 | Best: 0.3889
# [Test] Fold 0 | Ep  87/10000 | Pearson: 0.2532 | Best: 0.3409
# Fold 0 | Ep  88/10000 | LR: 0.000019 | Loss: 0.3742 | Pearson: 0.2529 | Best: 0.3889
# [Test] Fold 0 | Ep  88/10000 | Pearson: 0.2482 | Best: 0.3409
# Fold 0 | Ep  89/10000 | LR: 0.000016 | Loss: 0.3873 | Pearson: 0.2609 | Best: 0.3889
# [Test] Fold 0 | Ep  89/10000 | Pearson: 0.2529 | Best: 0.3409
# Fold 0 | Ep  90/10000 | LR: 0.000013 | Loss: 0.3696 | Pearson: 0.2560 | Best: 0.3889
# [Test] Fold 0 | Ep  90/10000 | Pearson: 0.2496 | Best: 0.3409
# Fold 0 | Ep  91/10000 | LR: 0.000011 | Loss: 0.3771 | Pearson: 0.2565 | Best: 0.3889
# [Test] Fold 0 | Ep  91/10000 | Pearson: 0.2507 | Best: 0.3409
# Fold 0 | Ep  92/10000 | LR: 0.000009 | Loss: 0.3645 | Pearson: 0.2564 | Best: 0.3889
# [Test] Fold 0 | Ep  92/10000 | Pearson: 0.2478 | Best: 0.3409
# Fold 0 | Ep  93/10000 | LR: 0.000007 | Loss: 0.3607 | Pearson: 0.2585 | Best: 0.3889
# [Test] Fold 0 | Ep  93/10000 | Pearson: 0.2500 | Best: 0.3409
# Fold 0 | Ep  94/10000 | LR: 0.000005 | Loss: 0.3688 | Pearson: 0.2525 | Best: 0.3889
# [Test] Fold 0 | Ep  94/10000 | Pearson: 0.2461 | Best: 0.3409
# Fold 0 | Ep  95/10000 | LR: 0.000004 | Loss: 0.3690 | Pearson: 0.2551 | Best: 0.3889
# [Test] Fold 0 | Ep  95/10000 | Pearson: 0.2502 | Best: 0.3409
# Fold 0 | Ep  96/10000 | LR: 0.000003 | Loss: 0.3552 | Pearson: 0.2559 | Best: 0.3889
# [Test] Fold 0 | Ep  96/10000 | Pearson: 0.2493 | Best: 0.3409
# Fold 0 | Ep  97/10000 | LR: 0.000002 | Loss: 0.3824 | Pearson: 0.2486 | Best: 0.3889
# [Test] Fold 0 | Ep  97/10000 | Pearson: 0.2491 | Best: 0.3409
# Fold 0 | Ep  98/10000 | LR: 0.000001 | Loss: 0.3691 | Pearson: 0.2560 | Best: 0.3889
# [Test] Fold 0 | Ep  98/10000 | Pearson: 0.2520 | Best: 0.3409
# Fold 0 | Ep  99/10000 | LR: 0.000001 | Loss: 0.3668 | Pearson: 0.2558 | Best: 0.3889
# [Test] Fold 0 | Ep  99/10000 | Pearson: 0.2446 | Best: 0.3409
# Fold 0 | Ep 100/10000 | LR: 0.000001 | Loss: 0.3751 | Pearson: 0.2505 | Best: 0.3889
# [Test] Fold 0 | Ep 100/10000 | Pearson: 0.2442 | Best: 0.3409
# Fold 0 | Ep 101/10000 | LR: 0.000001 | Loss: 0.3695 | Pearson: 0.2547 | Best: 0.3889
# [Test] Fold 0 | Ep 101/10000 | Pearson: 0.2485 | Best: 0.3409
# Fold 0 | Ep 102/10000 | LR: 0.000001 | Loss: 0.3726 | Pearson: 0.2595 | Best: 0.3889
# [Test] Fold 0 | Ep 102/10000 | Pearson: 0.2497 | Best: 0.3409
# Fold 0 | Ep 103/10000 | LR: 0.000002 | Loss: 0.3665 | Pearson: 0.2599 | Best: 0.3889
# !!! Early Stopping triggered at epoch 103 !!!
#
# --- Starting 5-Fold Cross Validation: Fold 1 ---
# Fold 1 | Ep   1/10000 | LR: 0.000500 | Loss: 1.0923 | Pearson: 0.0394 | Best: 0.0394
# [Test] Fold 1 | Ep   1/10000 | Pearson: 0.1837 | Best: 0.1837
# Fold 1 | Ep   2/10000 | LR: 0.000500 | Loss: 0.9656 | Pearson: 0.2163 | Best: 0.2163
# [Test] Fold 1 | Ep   2/10000 | Pearson: 0.2646 | Best: 0.2646
# Fold 1 | Ep   3/10000 | LR: 0.000499 | Loss: 0.9501 | Pearson: 0.1953 | Best: 0.2163
# [Test] Fold 1 | Ep   3/10000 | Pearson: 0.2717 | Best: 0.2717
# Fold 1 | Ep   4/10000 | LR: 0.000498 | Loss: 0.9340 | Pearson: 0.1850 | Best: 0.2163
# [Test] Fold 1 | Ep   4/10000 | Pearson: 0.2529 | Best: 0.2717
# Fold 1 | Ep   5/10000 | LR: 0.000497 | Loss: 0.9126 | Pearson: 0.2607 | Best: 0.2607
# [Test] Fold 1 | Ep   5/10000 | Pearson: 0.2581 | Best: 0.2717
# Fold 1 | Ep   6/10000 | LR: 0.000496 | Loss: 0.8951 | Pearson: 0.2275 | Best: 0.2607
# [Test] Fold 1 | Ep   6/10000 | Pearson: 0.2644 | Best: 0.2717
# Fold 1 | Ep   7/10000 | LR: 0.000494 | Loss: 0.8778 | Pearson: 0.2821 | Best: 0.2821
# [Test] Fold 1 | Ep   7/10000 | Pearson: 0.2604 | Best: 0.2717
# Fold 1 | Ep   8/10000 | LR: 0.000492 | Loss: 0.8554 | Pearson: 0.2289 | Best: 0.2821
# [Test] Fold 1 | Ep   8/10000 | Pearson: 0.2784 | Best: 0.2784
# Fold 1 | Ep   9/10000 | LR: 0.000490 | Loss: 0.8639 | Pearson: 0.3011 | Best: 0.3011
# [Test] Fold 1 | Ep   9/10000 | Pearson: 0.2797 | Best: 0.2797
# Fold 1 | Ep  10/10000 | LR: 0.000488 | Loss: 0.8433 | Pearson: 0.2457 | Best: 0.3011
# [Test] Fold 1 | Ep  10/10000 | Pearson: 0.2809 | Best: 0.2809
# Fold 1 | Ep  11/10000 | LR: 0.000485 | Loss: 0.8366 | Pearson: 0.2755 | Best: 0.3011
# [Test] Fold 1 | Ep  11/10000 | Pearson: 0.2538 | Best: 0.2809
# Fold 1 | Ep  12/10000 | LR: 0.000482 | Loss: 0.8253 | Pearson: 0.2328 | Best: 0.3011
# [Test] Fold 1 | Ep  12/10000 | Pearson: 0.2653 | Best: 0.2809
# Fold 1 | Ep  13/10000 | LR: 0.000479 | Loss: 0.8107 | Pearson: 0.2936 | Best: 0.3011
# [Test] Fold 1 | Ep  13/10000 | Pearson: 0.2793 | Best: 0.2809
# Fold 1 | Ep  14/10000 | LR: 0.000476 | Loss: 0.7939 | Pearson: 0.2695 | Best: 0.3011
# [Test] Fold 1 | Ep  14/10000 | Pearson: 0.2854 | Best: 0.2854
# Fold 1 | Ep  15/10000 | LR: 0.000473 | Loss: 0.7784 | Pearson: 0.2537 | Best: 0.3011
# [Test] Fold 1 | Ep  15/10000 | Pearson: 0.2879 | Best: 0.2879
# Fold 1 | Ep  16/10000 | LR: 0.000469 | Loss: 0.7838 | Pearson: 0.2556 | Best: 0.3011
# [Test] Fold 1 | Ep  16/10000 | Pearson: 0.2724 | Best: 0.2879
# Fold 1 | Ep  17/10000 | LR: 0.000465 | Loss: 0.7543 | Pearson: 0.2953 | Best: 0.3011
# [Test] Fold 1 | Ep  17/10000 | Pearson: 0.2835 | Best: 0.2879
# Fold 1 | Ep  18/10000 | LR: 0.000461 | Loss: 0.7480 | Pearson: 0.2674 | Best: 0.3011
# [Test] Fold 1 | Ep  18/10000 | Pearson: 0.2954 | Best: 0.2954
# Fold 1 | Ep  19/10000 | LR: 0.000457 | Loss: 0.7248 | Pearson: 0.2359 | Best: 0.3011
# [Test] Fold 1 | Ep  19/10000 | Pearson: 0.2836 | Best: 0.2954
# Fold 1 | Ep  20/10000 | LR: 0.000452 | Loss: 0.7295 | Pearson: 0.2778 | Best: 0.3011
# [Test] Fold 1 | Ep  20/10000 | Pearson: 0.2628 | Best: 0.2954
# Fold 1 | Ep  21/10000 | LR: 0.000448 | Loss: 0.7144 | Pearson: 0.2811 | Best: 0.3011
# [Test] Fold 1 | Ep  21/10000 | Pearson: 0.2825 | Best: 0.2954
# Fold 1 | Ep  22/10000 | LR: 0.000443 | Loss: 0.7000 | Pearson: 0.2365 | Best: 0.3011
# [Test] Fold 1 | Ep  22/10000 | Pearson: 0.2533 | Best: 0.2954
# Fold 1 | Ep  23/10000 | LR: 0.000438 | Loss: 0.6901 | Pearson: 0.2724 | Best: 0.3011
# [Test] Fold 1 | Ep  23/10000 | Pearson: 0.2546 | Best: 0.2954
# Fold 1 | Ep  24/10000 | LR: 0.000432 | Loss: 0.7025 | Pearson: 0.2914 | Best: 0.3011
# [Test] Fold 1 | Ep  24/10000 | Pearson: 0.2531 | Best: 0.2954
# Fold 1 | Ep  25/10000 | LR: 0.000427 | Loss: 0.6784 | Pearson: 0.2573 | Best: 0.3011
# [Test] Fold 1 | Ep  25/10000 | Pearson: 0.2598 | Best: 0.2954
# Fold 1 | Ep  26/10000 | LR: 0.000421 | Loss: 0.6695 | Pearson: 0.2292 | Best: 0.3011
# [Test] Fold 1 | Ep  26/10000 | Pearson: 0.2454 | Best: 0.2954
# Fold 1 | Ep  27/10000 | LR: 0.000415 | Loss: 0.6665 | Pearson: 0.2942 | Best: 0.3011
# [Test] Fold 1 | Ep  27/10000 | Pearson: 0.2718 | Best: 0.2954
# Fold 1 | Ep  28/10000 | LR: 0.000410 | Loss: 0.6487 | Pearson: 0.2409 | Best: 0.3011
# [Test] Fold 1 | Ep  28/10000 | Pearson: 0.2515 | Best: 0.2954
# Fold 1 | Ep  29/10000 | LR: 0.000403 | Loss: 0.6559 | Pearson: 0.2532 | Best: 0.3011
# [Test] Fold 1 | Ep  29/10000 | Pearson: 0.2441 | Best: 0.2954
# Fold 1 | Ep  30/10000 | LR: 0.000397 | Loss: 0.6404 | Pearson: 0.2855 | Best: 0.3011
# [Test] Fold 1 | Ep  30/10000 | Pearson: 0.2512 | Best: 0.2954
# Fold 1 | Ep  31/10000 | LR: 0.000391 | Loss: 0.6272 | Pearson: 0.3116 | Best: 0.3116
# [Test] Fold 1 | Ep  31/10000 | Pearson: 0.2745 | Best: 0.2954
# Fold 1 | Ep  32/10000 | LR: 0.000384 | Loss: 0.6245 | Pearson: 0.2635 | Best: 0.3116
# [Test] Fold 1 | Ep  32/10000 | Pearson: 0.2291 | Best: 0.2954
# Fold 1 | Ep  33/10000 | LR: 0.000378 | Loss: 0.6160 | Pearson: 0.2305 | Best: 0.3116
# [Test] Fold 1 | Ep  33/10000 | Pearson: 0.2533 | Best: 0.2954
# Fold 1 | Ep  34/10000 | LR: 0.000371 | Loss: 0.6003 | Pearson: 0.2397 | Best: 0.3116
# [Test] Fold 1 | Ep  34/10000 | Pearson: 0.2622 | Best: 0.2954
# Fold 1 | Ep  35/10000 | LR: 0.000364 | Loss: 0.5944 | Pearson: 0.2789 | Best: 0.3116
# [Test] Fold 1 | Ep  35/10000 | Pearson: 0.2468 | Best: 0.2954
# Fold 1 | Ep  36/10000 | LR: 0.000357 | Loss: 0.5811 | Pearson: 0.2386 | Best: 0.3116
# [Test] Fold 1 | Ep  36/10000 | Pearson: 0.2516 | Best: 0.2954
# Fold 1 | Ep  37/10000 | LR: 0.000350 | Loss: 0.5789 | Pearson: 0.2282 | Best: 0.3116
# [Test] Fold 1 | Ep  37/10000 | Pearson: 0.2703 | Best: 0.2954
# Fold 1 | Ep  38/10000 | LR: 0.000342 | Loss: 0.5686 | Pearson: 0.2318 | Best: 0.3116
# [Test] Fold 1 | Ep  38/10000 | Pearson: 0.2195 | Best: 0.2954
# Fold 1 | Ep  39/10000 | LR: 0.000335 | Loss: 0.5561 | Pearson: 0.2588 | Best: 0.3116
# [Test] Fold 1 | Ep  39/10000 | Pearson: 0.2752 | Best: 0.2954
# Fold 1 | Ep  40/10000 | LR: 0.000328 | Loss: 0.5587 | Pearson: 0.2355 | Best: 0.3116
# [Test] Fold 1 | Ep  40/10000 | Pearson: 0.2490 | Best: 0.2954
# Fold 1 | Ep  41/10000 | LR: 0.000320 | Loss: 0.5610 | Pearson: 0.2010 | Best: 0.3116
# [Test] Fold 1 | Ep  41/10000 | Pearson: 0.2520 | Best: 0.2954
# Fold 1 | Ep  42/10000 | LR: 0.000313 | Loss: 0.5471 | Pearson: 0.2565 | Best: 0.3116
# [Test] Fold 1 | Ep  42/10000 | Pearson: 0.2707 | Best: 0.2954
# Fold 1 | Ep  43/10000 | LR: 0.000305 | Loss: 0.5442 | Pearson: 0.2344 | Best: 0.3116
# [Test] Fold 1 | Ep  43/10000 | Pearson: 0.2402 | Best: 0.2954
# Fold 1 | Ep  44/10000 | LR: 0.000297 | Loss: 0.5192 | Pearson: 0.2386 | Best: 0.3116
# [Test] Fold 1 | Ep  44/10000 | Pearson: 0.2501 | Best: 0.2954
# Fold 1 | Ep  45/10000 | LR: 0.000290 | Loss: 0.5149 | Pearson: 0.2335 | Best: 0.3116
# [Test] Fold 1 | Ep  45/10000 | Pearson: 0.2256 | Best: 0.2954
# Fold 1 | Ep  46/10000 | LR: 0.000282 | Loss: 0.5180 | Pearson: 0.2134 | Best: 0.3116
# [Test] Fold 1 | Ep  46/10000 | Pearson: 0.2362 | Best: 0.2954
# Fold 1 | Ep  47/10000 | LR: 0.000274 | Loss: 0.4939 | Pearson: 0.2079 | Best: 0.3116
# [Test] Fold 1 | Ep  47/10000 | Pearson: 0.2481 | Best: 0.2954
# Fold 1 | Ep  48/10000 | LR: 0.000266 | Loss: 0.5042 | Pearson: 0.2249 | Best: 0.3116
# [Test] Fold 1 | Ep  48/10000 | Pearson: 0.2634 | Best: 0.2954
# Fold 1 | Ep  49/10000 | LR: 0.000258 | Loss: 0.5044 | Pearson: 0.2516 | Best: 0.3116
# [Test] Fold 1 | Ep  49/10000 | Pearson: 0.2447 | Best: 0.2954
# Fold 1 | Ep  50/10000 | LR: 0.000251 | Loss: 0.4905 | Pearson: 0.2029 | Best: 0.3116
# [Test] Fold 1 | Ep  50/10000 | Pearson: 0.2528 | Best: 0.2954
# Fold 1 | Ep  51/10000 | LR: 0.000243 | Loss: 0.4783 | Pearson: 0.1955 | Best: 0.3116
# [Test] Fold 1 | Ep  51/10000 | Pearson: 0.2390 | Best: 0.2954
# Fold 1 | Ep  52/10000 | LR: 0.000235 | Loss: 0.4825 | Pearson: 0.2065 | Best: 0.3116
# [Test] Fold 1 | Ep  52/10000 | Pearson: 0.2170 | Best: 0.2954
# Fold 1 | Ep  53/10000 | LR: 0.000227 | Loss: 0.4658 | Pearson: 0.2082 | Best: 0.3116
# [Test] Fold 1 | Ep  53/10000 | Pearson: 0.2082 | Best: 0.2954
# Fold 1 | Ep  54/10000 | LR: 0.000219 | Loss: 0.4639 | Pearson: 0.2272 | Best: 0.3116
# [Test] Fold 1 | Ep  54/10000 | Pearson: 0.2477 | Best: 0.2954
# Fold 1 | Ep  55/10000 | LR: 0.000211 | Loss: 0.4461 | Pearson: 0.2363 | Best: 0.3116
# [Test] Fold 1 | Ep  55/10000 | Pearson: 0.2514 | Best: 0.2954
# Fold 1 | Ep  56/10000 | LR: 0.000204 | Loss: 0.4381 | Pearson: 0.2467 | Best: 0.3116
# [Test] Fold 1 | Ep  56/10000 | Pearson: 0.2407 | Best: 0.2954
# Fold 1 | Ep  57/10000 | LR: 0.000196 | Loss: 0.4605 | Pearson: 0.2365 | Best: 0.3116
# [Test] Fold 1 | Ep  57/10000 | Pearson: 0.2520 | Best: 0.2954
# Fold 1 | Ep  58/10000 | LR: 0.000188 | Loss: 0.4364 | Pearson: 0.2142 | Best: 0.3116
# [Test] Fold 1 | Ep  58/10000 | Pearson: 0.2300 | Best: 0.2954
# Fold 1 | Ep  59/10000 | LR: 0.000181 | Loss: 0.4325 | Pearson: 0.2104 | Best: 0.3116
# [Test] Fold 1 | Ep  59/10000 | Pearson: 0.2329 | Best: 0.2954
# Fold 1 | Ep  60/10000 | LR: 0.000173 | Loss: 0.4277 | Pearson: 0.1959 | Best: 0.3116
# [Test] Fold 1 | Ep  60/10000 | Pearson: 0.2211 | Best: 0.2954
# Fold 1 | Ep  61/10000 | LR: 0.000166 | Loss: 0.4103 | Pearson: 0.2038 | Best: 0.3116
# [Test] Fold 1 | Ep  61/10000 | Pearson: 0.2195 | Best: 0.2954
# Fold 1 | Ep  62/10000 | LR: 0.000159 | Loss: 0.4129 | Pearson: 0.2124 | Best: 0.3116
# [Test] Fold 1 | Ep  62/10000 | Pearson: 0.2459 | Best: 0.2954
# Fold 1 | Ep  63/10000 | LR: 0.000151 | Loss: 0.4088 | Pearson: 0.2334 | Best: 0.3116
# [Test] Fold 1 | Ep  63/10000 | Pearson: 0.2148 | Best: 0.2954
# Fold 1 | Ep  64/10000 | LR: 0.000144 | Loss: 0.4034 | Pearson: 0.2023 | Best: 0.3116
# [Test] Fold 1 | Ep  64/10000 | Pearson: 0.2298 | Best: 0.2954
# Fold 1 | Ep  65/10000 | LR: 0.000137 | Loss: 0.4011 | Pearson: 0.2076 | Best: 0.3116
# [Test] Fold 1 | Ep  65/10000 | Pearson: 0.2320 | Best: 0.2954
# Fold 1 | Ep  66/10000 | LR: 0.000130 | Loss: 0.4063 | Pearson: 0.1974 | Best: 0.3116
# [Test] Fold 1 | Ep  66/10000 | Pearson: 0.2106 | Best: 0.2954
# Fold 1 | Ep  67/10000 | LR: 0.000123 | Loss: 0.3952 | Pearson: 0.2155 | Best: 0.3116
# [Test] Fold 1 | Ep  67/10000 | Pearson: 0.2339 | Best: 0.2954
# Fold 1 | Ep  68/10000 | LR: 0.000117 | Loss: 0.3921 | Pearson: 0.1893 | Best: 0.3116
# [Test] Fold 1 | Ep  68/10000 | Pearson: 0.2377 | Best: 0.2954
# Fold 1 | Ep  69/10000 | LR: 0.000110 | Loss: 0.3909 | Pearson: 0.1988 | Best: 0.3116
# [Test] Fold 1 | Ep  69/10000 | Pearson: 0.2121 | Best: 0.2954
# Fold 1 | Ep  70/10000 | LR: 0.000104 | Loss: 0.3719 | Pearson: 0.2184 | Best: 0.3116
# [Test] Fold 1 | Ep  70/10000 | Pearson: 0.2239 | Best: 0.2954
# Fold 1 | Ep  71/10000 | LR: 0.000098 | Loss: 0.3898 | Pearson: 0.1919 | Best: 0.3116
# [Test] Fold 1 | Ep  71/10000 | Pearson: 0.2177 | Best: 0.2954
# Fold 1 | Ep  72/10000 | LR: 0.000091 | Loss: 0.3660 | Pearson: 0.1987 | Best: 0.3116
# [Test] Fold 1 | Ep  72/10000 | Pearson: 0.2189 | Best: 0.2954
# Fold 1 | Ep  73/10000 | LR: 0.000086 | Loss: 0.3583 | Pearson: 0.1953 | Best: 0.3116
# [Test] Fold 1 | Ep  73/10000 | Pearson: 0.2161 | Best: 0.2954
# Fold 1 | Ep  74/10000 | LR: 0.000080 | Loss: 0.3653 | Pearson: 0.1979 | Best: 0.3116
# [Test] Fold 1 | Ep  74/10000 | Pearson: 0.2325 | Best: 0.2954
# Fold 1 | Ep  75/10000 | LR: 0.000074 | Loss: 0.3603 | Pearson: 0.1977 | Best: 0.3116
# [Test] Fold 1 | Ep  75/10000 | Pearson: 0.2190 | Best: 0.2954
# Fold 1 | Ep  76/10000 | LR: 0.000069 | Loss: 0.3608 | Pearson: 0.1953 | Best: 0.3116
# [Test] Fold 1 | Ep  76/10000 | Pearson: 0.2230 | Best: 0.2954
# Fold 1 | Ep  77/10000 | LR: 0.000063 | Loss: 0.3633 | Pearson: 0.1868 | Best: 0.3116
# [Test] Fold 1 | Ep  77/10000 | Pearson: 0.2243 | Best: 0.2954
# Fold 1 | Ep  78/10000 | LR: 0.000058 | Loss: 0.3606 | Pearson: 0.1878 | Best: 0.3116
# [Test] Fold 1 | Ep  78/10000 | Pearson: 0.2150 | Best: 0.2954
# Fold 1 | Ep  79/10000 | LR: 0.000053 | Loss: 0.3512 | Pearson: 0.1861 | Best: 0.3116
# [Test] Fold 1 | Ep  79/10000 | Pearson: 0.2165 | Best: 0.2954
# Fold 1 | Ep  80/10000 | LR: 0.000049 | Loss: 0.3469 | Pearson: 0.2104 | Best: 0.3116
# [Test] Fold 1 | Ep  80/10000 | Pearson: 0.2273 | Best: 0.2954
# Fold 1 | Ep  81/10000 | LR: 0.000044 | Loss: 0.3404 | Pearson: 0.2056 | Best: 0.3116
# [Test] Fold 1 | Ep  81/10000 | Pearson: 0.2201 | Best: 0.2954
# Fold 1 | Ep  82/10000 | LR: 0.000040 | Loss: 0.3456 | Pearson: 0.1953 | Best: 0.3116
# [Test] Fold 1 | Ep  82/10000 | Pearson: 0.2258 | Best: 0.2954
# Fold 1 | Ep  83/10000 | LR: 0.000036 | Loss: 0.3433 | Pearson: 0.1996 | Best: 0.3116
# [Test] Fold 1 | Ep  83/10000 | Pearson: 0.2253 | Best: 0.2954
# Fold 1 | Ep  84/10000 | LR: 0.000032 | Loss: 0.3545 | Pearson: 0.1930 | Best: 0.3116
# [Test] Fold 1 | Ep  84/10000 | Pearson: 0.2261 | Best: 0.2954
# Fold 1 | Ep  85/10000 | LR: 0.000028 | Loss: 0.3338 | Pearson: 0.1993 | Best: 0.3116
# [Test] Fold 1 | Ep  85/10000 | Pearson: 0.2197 | Best: 0.2954
# Fold 1 | Ep  86/10000 | LR: 0.000025 | Loss: 0.3344 | Pearson: 0.1913 | Best: 0.3116
# [Test] Fold 1 | Ep  86/10000 | Pearson: 0.2224 | Best: 0.2954
# Fold 1 | Ep  87/10000 | LR: 0.000022 | Loss: 0.3455 | Pearson: 0.1993 | Best: 0.3116
# [Test] Fold 1 | Ep  87/10000 | Pearson: 0.2201 | Best: 0.2954
# Fold 1 | Ep  88/10000 | LR: 0.000019 | Loss: 0.3324 | Pearson: 0.2024 | Best: 0.3116
# [Test] Fold 1 | Ep  88/10000 | Pearson: 0.2191 | Best: 0.2954
# Fold 1 | Ep  89/10000 | LR: 0.000016 | Loss: 0.3351 | Pearson: 0.2000 | Best: 0.3116
# [Test] Fold 1 | Ep  89/10000 | Pearson: 0.2210 | Best: 0.2954
# Fold 1 | Ep  90/10000 | LR: 0.000013 | Loss: 0.3427 | Pearson: 0.1983 | Best: 0.3116
# [Test] Fold 1 | Ep  90/10000 | Pearson: 0.2185 | Best: 0.2954
# Fold 1 | Ep  91/10000 | LR: 0.000011 | Loss: 0.3445 | Pearson: 0.2042 | Best: 0.3116
# [Test] Fold 1 | Ep  91/10000 | Pearson: 0.2263 | Best: 0.2954
# Fold 1 | Ep  92/10000 | LR: 0.000009 | Loss: 0.3305 | Pearson: 0.2041 | Best: 0.3116
# [Test] Fold 1 | Ep  92/10000 | Pearson: 0.2241 | Best: 0.2954
# Fold 1 | Ep  93/10000 | LR: 0.000007 | Loss: 0.3337 | Pearson: 0.1997 | Best: 0.3116
# [Test] Fold 1 | Ep  93/10000 | Pearson: 0.2173 | Best: 0.2954
# Fold 1 | Ep  94/10000 | LR: 0.000005 | Loss: 0.3204 | Pearson: 0.1984 | Best: 0.3116
# [Test] Fold 1 | Ep  94/10000 | Pearson: 0.2233 | Best: 0.2954
# Fold 1 | Ep  95/10000 | LR: 0.000004 | Loss: 0.3268 | Pearson: 0.1977 | Best: 0.3116
# [Test] Fold 1 | Ep  95/10000 | Pearson: 0.2229 | Best: 0.2954
# Fold 1 | Ep  96/10000 | LR: 0.000003 | Loss: 0.3249 | Pearson: 0.1886 | Best: 0.3116
# [Test] Fold 1 | Ep  96/10000 | Pearson: 0.2176 | Best: 0.2954
# Fold 1 | Ep  97/10000 | LR: 0.000002 | Loss: 0.3334 | Pearson: 0.1981 | Best: 0.3116
# [Test] Fold 1 | Ep  97/10000 | Pearson: 0.2240 | Best: 0.2954
# Fold 1 | Ep  98/10000 | LR: 0.000001 | Loss: 0.3317 | Pearson: 0.1953 | Best: 0.3116
# [Test] Fold 1 | Ep  98/10000 | Pearson: 0.2175 | Best: 0.2954
# Fold 1 | Ep  99/10000 | LR: 0.000001 | Loss: 0.3280 | Pearson: 0.1936 | Best: 0.3116
# [Test] Fold 1 | Ep  99/10000 | Pearson: 0.2162 | Best: 0.2954
# Fold 1 | Ep 100/10000 | LR: 0.000001 | Loss: 0.3264 | Pearson: 0.1997 | Best: 0.3116
# [Test] Fold 1 | Ep 100/10000 | Pearson: 0.2250 | Best: 0.2954
# Fold 1 | Ep 101/10000 | LR: 0.000001 | Loss: 0.3303 | Pearson: 0.1972 | Best: 0.3116
# [Test] Fold 1 | Ep 101/10000 | Pearson: 0.2182 | Best: 0.2954
# Fold 1 | Ep 102/10000 | LR: 0.000001 | Loss: 0.3286 | Pearson: 0.1904 | Best: 0.3116
# [Test] Fold 1 | Ep 102/10000 | Pearson: 0.2216 | Best: 0.2954
# Fold 1 | Ep 103/10000 | LR: 0.000002 | Loss: 0.3274 | Pearson: 0.2027 | Best: 0.3116
# [Test] Fold 1 | Ep 103/10000 | Pearson: 0.2259 | Best: 0.2954
# Fold 1 | Ep 104/10000 | LR: 0.000003 | Loss: 0.3303 | Pearson: 0.1991 | Best: 0.3116
# [Test] Fold 1 | Ep 104/10000 | Pearson: 0.2200 | Best: 0.2954
# Fold 1 | Ep 105/10000 | LR: 0.000004 | Loss: 0.3251 | Pearson: 0.1920 | Best: 0.3116
# [Test] Fold 1 | Ep 105/10000 | Pearson: 0.2249 | Best: 0.2954
# Fold 1 | Ep 106/10000 | LR: 0.000005 | Loss: 0.3362 | Pearson: 0.1961 | Best: 0.3116
# [Test] Fold 1 | Ep 106/10000 | Pearson: 0.2150 | Best: 0.2954
# Fold 1 | Ep 107/10000 | LR: 0.000007 | Loss: 0.3308 | Pearson: 0.1960 | Best: 0.3116
# [Test] Fold 1 | Ep 107/10000 | Pearson: 0.2213 | Best: 0.2954
# Fold 1 | Ep 108/10000 | LR: 0.000009 | Loss: 0.3200 | Pearson: 0.1889 | Best: 0.3116
# [Test] Fold 1 | Ep 108/10000 | Pearson: 0.2232 | Best: 0.2954
# Fold 1 | Ep 109/10000 | LR: 0.000011 | Loss: 0.3299 | Pearson: 0.1921 | Best: 0.3116
# [Test] Fold 1 | Ep 109/10000 | Pearson: 0.2218 | Best: 0.2954
# Fold 1 | Ep 110/10000 | LR: 0.000013 | Loss: 0.3243 | Pearson: 0.1926 | Best: 0.3116
# [Test] Fold 1 | Ep 110/10000 | Pearson: 0.2193 | Best: 0.2954
# Fold 1 | Ep 111/10000 | LR: 0.000016 | Loss: 0.3363 | Pearson: 0.1991 | Best: 0.3116
# [Test] Fold 1 | Ep 111/10000 | Pearson: 0.2231 | Best: 0.2954
# Fold 1 | Ep 112/10000 | LR: 0.000019 | Loss: 0.3300 | Pearson: 0.1971 | Best: 0.3116
# [Test] Fold 1 | Ep 112/10000 | Pearson: 0.2223 | Best: 0.2954
# Fold 1 | Ep 113/10000 | LR: 0.000022 | Loss: 0.3217 | Pearson: 0.1926 | Best: 0.3116
# [Test] Fold 1 | Ep 113/10000 | Pearson: 0.2203 | Best: 0.2954
# Fold 1 | Ep 114/10000 | LR: 0.000025 | Loss: 0.3218 | Pearson: 0.1976 | Best: 0.3116
# [Test] Fold 1 | Ep 114/10000 | Pearson: 0.2189 | Best: 0.2954
# Fold 1 | Ep 115/10000 | LR: 0.000028 | Loss: 0.3340 | Pearson: 0.1887 | Best: 0.3116
# [Test] Fold 1 | Ep 115/10000 | Pearson: 0.2245 | Best: 0.2954
# Fold 1 | Ep 116/10000 | LR: 0.000032 | Loss: 0.3433 | Pearson: 0.1905 | Best: 0.3116
# [Test] Fold 1 | Ep 116/10000 | Pearson: 0.2158 | Best: 0.2954
# Fold 1 | Ep 117/10000 | LR: 0.000036 | Loss: 0.3196 | Pearson: 0.1877 | Best: 0.3116
# [Test] Fold 1 | Ep 117/10000 | Pearson: 0.2167 | Best: 0.2954
# Fold 1 | Ep 118/10000 | LR: 0.000040 | Loss: 0.3303 | Pearson: 0.1975 | Best: 0.3116
# [Test] Fold 1 | Ep 118/10000 | Pearson: 0.2128 | Best: 0.2954
# Fold 1 | Ep 119/10000 | LR: 0.000044 | Loss: 0.3328 | Pearson: 0.1903 | Best: 0.3116
# [Test] Fold 1 | Ep 119/10000 | Pearson: 0.2224 | Best: 0.2954
# Fold 1 | Ep 120/10000 | LR: 0.000049 | Loss: 0.3257 | Pearson: 0.1951 | Best: 0.3116
# [Test] Fold 1 | Ep 120/10000 | Pearson: 0.2177 | Best: 0.2954
# Fold 1 | Ep 121/10000 | LR: 0.000053 | Loss: 0.3311 | Pearson: 0.1897 | Best: 0.3116
# [Test] Fold 1 | Ep 121/10000 | Pearson: 0.2208 | Best: 0.2954
# Fold 1 | Ep 122/10000 | LR: 0.000058 | Loss: 0.3258 | Pearson: 0.1929 | Best: 0.3116
# [Test] Fold 1 | Ep 122/10000 | Pearson: 0.2144 | Best: 0.2954
# Fold 1 | Ep 123/10000 | LR: 0.000063 | Loss: 0.3360 | Pearson: 0.1795 | Best: 0.3116
# [Test] Fold 1 | Ep 123/10000 | Pearson: 0.2184 | Best: 0.2954
# Fold 1 | Ep 124/10000 | LR: 0.000069 | Loss: 0.3501 | Pearson: 0.1965 | Best: 0.3116
# [Test] Fold 1 | Ep 124/10000 | Pearson: 0.2270 | Best: 0.2954
# Fold 1 | Ep 125/10000 | LR: 0.000074 | Loss: 0.3369 | Pearson: 0.1831 | Best: 0.3116
# [Test] Fold 1 | Ep 125/10000 | Pearson: 0.2157 | Best: 0.2954
# Fold 1 | Ep 126/10000 | LR: 0.000080 | Loss: 0.3366 | Pearson: 0.1926 | Best: 0.3116
# [Test] Fold 1 | Ep 126/10000 | Pearson: 0.2288 | Best: 0.2954
# Fold 1 | Ep 127/10000 | LR: 0.000086 | Loss: 0.3502 | Pearson: 0.2076 | Best: 0.3116
# [Test] Fold 1 | Ep 127/10000 | Pearson: 0.2274 | Best: 0.2954
# Fold 1 | Ep 128/10000 | LR: 0.000091 | Loss: 0.3401 | Pearson: 0.1918 | Best: 0.3116
# [Test] Fold 1 | Ep 128/10000 | Pearson: 0.2135 | Best: 0.2954
# Fold 1 | Ep 129/10000 | LR: 0.000098 | Loss: 0.3418 | Pearson: 0.1871 | Best: 0.3116
# [Test] Fold 1 | Ep 129/10000 | Pearson: 0.2198 | Best: 0.2954
# Fold 1 | Ep 130/10000 | LR: 0.000104 | Loss: 0.3387 | Pearson: 0.1937 | Best: 0.3116
# [Test] Fold 1 | Ep 130/10000 | Pearson: 0.2332 | Best: 0.2954
# Fold 1 | Ep 131/10000 | LR: 0.000110 | Loss: 0.3432 | Pearson: 0.1864 | Best: 0.3116
# !!! Early Stopping triggered at epoch 131 !!!
#
# --- Starting 5-Fold Cross Validation: Fold 2 ---
# Fold 2 | Ep   1/10000 | LR: 0.000500 | Loss: 1.0978 | Pearson: 0.3480 | Best: 0.3480
# [Test] Fold 2 | Ep   1/10000 | Pearson: 0.2000 | Best: 0.2000
# Fold 2 | Ep   2/10000 | LR: 0.000500 | Loss: 0.9779 | Pearson: 0.3698 | Best: 0.3698
# [Test] Fold 2 | Ep   2/10000 | Pearson: 0.2448 | Best: 0.2448
# Fold 2 | Ep   3/10000 | LR: 0.000499 | Loss: 0.9631 | Pearson: 0.3995 | Best: 0.3995
# [Test] Fold 2 | Ep   3/10000 | Pearson: 0.2513 | Best: 0.2513
# Fold 2 | Ep   4/10000 | LR: 0.000498 | Loss: 0.9325 | Pearson: 0.3873 | Best: 0.3995
# [Test] Fold 2 | Ep   4/10000 | Pearson: 0.2610 | Best: 0.2610
# Fold 2 | Ep   5/10000 | LR: 0.000497 | Loss: 0.9245 | Pearson: 0.4038 | Best: 0.4038
# [Test] Fold 2 | Ep   5/10000 | Pearson: 0.2705 | Best: 0.2705
# Fold 2 | Ep   6/10000 | LR: 0.000496 | Loss: 0.9097 | Pearson: 0.3629 | Best: 0.4038
# [Test] Fold 2 | Ep   6/10000 | Pearson: 0.2830 | Best: 0.2830
# Fold 2 | Ep   7/10000 | LR: 0.000494 | Loss: 0.8816 | Pearson: 0.3642 | Best: 0.4038
# [Test] Fold 2 | Ep   7/10000 | Pearson: 0.2867 | Best: 0.2867
# Fold 2 | Ep   8/10000 | LR: 0.000492 | Loss: 0.8661 | Pearson: 0.3839 | Best: 0.4038
# [Test] Fold 2 | Ep   8/10000 | Pearson: 0.2659 | Best: 0.2867
# Fold 2 | Ep   9/10000 | LR: 0.000490 | Loss: 0.8534 | Pearson: 0.3796 | Best: 0.4038
# [Test] Fold 2 | Ep   9/10000 | Pearson: 0.2810 | Best: 0.2867
# Fold 2 | Ep  10/10000 | LR: 0.000488 | Loss: 0.8452 | Pearson: 0.3441 | Best: 0.4038
# [Test] Fold 2 | Ep  10/10000 | Pearson: 0.2942 | Best: 0.2942
# Fold 2 | Ep  11/10000 | LR: 0.000485 | Loss: 0.8462 | Pearson: 0.3801 | Best: 0.4038
# [Test] Fold 2 | Ep  11/10000 | Pearson: 0.2621 | Best: 0.2942
# Fold 2 | Ep  12/10000 | LR: 0.000482 | Loss: 0.8314 | Pearson: 0.3471 | Best: 0.4038
# [Test] Fold 2 | Ep  12/10000 | Pearson: 0.2799 | Best: 0.2942
# Fold 2 | Ep  13/10000 | LR: 0.000479 | Loss: 0.8223 | Pearson: 0.3377 | Best: 0.4038
# [Test] Fold 2 | Ep  13/10000 | Pearson: 0.2601 | Best: 0.2942
# Fold 2 | Ep  14/10000 | LR: 0.000476 | Loss: 0.8088 | Pearson: 0.3642 | Best: 0.4038
# [Test] Fold 2 | Ep  14/10000 | Pearson: 0.2596 | Best: 0.2942
# Fold 2 | Ep  15/10000 | LR: 0.000473 | Loss: 0.8019 | Pearson: 0.3423 | Best: 0.4038
# [Test] Fold 2 | Ep  15/10000 | Pearson: 0.2491 | Best: 0.2942
# Fold 2 | Ep  16/10000 | LR: 0.000469 | Loss: 0.7841 | Pearson: 0.3434 | Best: 0.4038
# [Test] Fold 2 | Ep  16/10000 | Pearson: 0.2734 | Best: 0.2942
# Fold 2 | Ep  17/10000 | LR: 0.000465 | Loss: 0.7903 | Pearson: 0.3139 | Best: 0.4038
# [Test] Fold 2 | Ep  17/10000 | Pearson: 0.2485 | Best: 0.2942
# Fold 2 | Ep  18/10000 | LR: 0.000461 | Loss: 0.7629 | Pearson: 0.3369 | Best: 0.4038
# [Test] Fold 2 | Ep  18/10000 | Pearson: 0.2719 | Best: 0.2942
# Fold 2 | Ep  19/10000 | LR: 0.000457 | Loss: 0.7493 | Pearson: 0.2668 | Best: 0.4038
# [Test] Fold 2 | Ep  19/10000 | Pearson: 0.2502 | Best: 0.2942
# Fold 2 | Ep  20/10000 | LR: 0.000452 | Loss: 0.7673 | Pearson: 0.3660 | Best: 0.4038
# [Test] Fold 2 | Ep  20/10000 | Pearson: 0.2392 | Best: 0.2942
# Fold 2 | Ep  21/10000 | LR: 0.000448 | Loss: 0.7418 | Pearson: 0.2894 | Best: 0.4038
# [Test] Fold 2 | Ep  21/10000 | Pearson: 0.2475 | Best: 0.2942
# Fold 2 | Ep  22/10000 | LR: 0.000443 | Loss: 0.7293 | Pearson: 0.2865 | Best: 0.4038
# [Test] Fold 2 | Ep  22/10000 | Pearson: 0.2351 | Best: 0.2942
# Fold 2 | Ep  23/10000 | LR: 0.000438 | Loss: 0.7324 | Pearson: 0.2894 | Best: 0.4038
# [Test] Fold 2 | Ep  23/10000 | Pearson: 0.2372 | Best: 0.2942
# Fold 2 | Ep  24/10000 | LR: 0.000432 | Loss: 0.7201 | Pearson: 0.3399 | Best: 0.4038
# [Test] Fold 2 | Ep  24/10000 | Pearson: 0.2415 | Best: 0.2942
# Fold 2 | Ep  25/10000 | LR: 0.000427 | Loss: 0.7175 | Pearson: 0.2411 | Best: 0.4038
# [Test] Fold 2 | Ep  25/10000 | Pearson: 0.2120 | Best: 0.2942
# Fold 2 | Ep  26/10000 | LR: 0.000421 | Loss: 0.7022 | Pearson: 0.2889 | Best: 0.4038
# [Test] Fold 2 | Ep  26/10000 | Pearson: 0.2427 | Best: 0.2942
# Fold 2 | Ep  27/10000 | LR: 0.000415 | Loss: 0.6894 | Pearson: 0.2821 | Best: 0.4038
# [Test] Fold 2 | Ep  27/10000 | Pearson: 0.2075 | Best: 0.2942
# Fold 2 | Ep  28/10000 | LR: 0.000410 | Loss: 0.7007 | Pearson: 0.2824 | Best: 0.4038
# [Test] Fold 2 | Ep  28/10000 | Pearson: 0.2434 | Best: 0.2942
# Fold 2 | Ep  29/10000 | LR: 0.000403 | Loss: 0.6790 | Pearson: 0.2490 | Best: 0.4038
# [Test] Fold 2 | Ep  29/10000 | Pearson: 0.2465 | Best: 0.2942
# Fold 2 | Ep  30/10000 | LR: 0.000397 | Loss: 0.6646 | Pearson: 0.2914 | Best: 0.4038
# [Test] Fold 2 | Ep  30/10000 | Pearson: 0.2354 | Best: 0.2942
# Fold 2 | Ep  31/10000 | LR: 0.000391 | Loss: 0.6709 | Pearson: 0.2057 | Best: 0.4038
# [Test] Fold 2 | Ep  31/10000 | Pearson: 0.2103 | Best: 0.2942
# Fold 2 | Ep  32/10000 | LR: 0.000384 | Loss: 0.6539 | Pearson: 0.2840 | Best: 0.4038
# [Test] Fold 2 | Ep  32/10000 | Pearson: 0.2022 | Best: 0.2942
# Fold 2 | Ep  33/10000 | LR: 0.000378 | Loss: 0.6516 | Pearson: 0.2406 | Best: 0.4038
# [Test] Fold 2 | Ep  33/10000 | Pearson: 0.2192 | Best: 0.2942
# Fold 2 | Ep  34/10000 | LR: 0.000371 | Loss: 0.6452 | Pearson: 0.2831 | Best: 0.4038
# [Test] Fold 2 | Ep  34/10000 | Pearson: 0.2509 | Best: 0.2942
# Fold 2 | Ep  35/10000 | LR: 0.000364 | Loss: 0.6347 | Pearson: 0.2510 | Best: 0.4038
# [Test] Fold 2 | Ep  35/10000 | Pearson: 0.2295 | Best: 0.2942
# Fold 2 | Ep  36/10000 | LR: 0.000357 | Loss: 0.6245 | Pearson: 0.2652 | Best: 0.4038
# [Test] Fold 2 | Ep  36/10000 | Pearson: 0.2229 | Best: 0.2942
# Fold 2 | Ep  37/10000 | LR: 0.000350 | Loss: 0.6210 | Pearson: 0.2768 | Best: 0.4038
# [Test] Fold 2 | Ep  37/10000 | Pearson: 0.1957 | Best: 0.2942
# Fold 2 | Ep  38/10000 | LR: 0.000342 | Loss: 0.6073 | Pearson: 0.2381 | Best: 0.4038
# [Test] Fold 2 | Ep  38/10000 | Pearson: 0.2335 | Best: 0.2942
# Fold 2 | Ep  39/10000 | LR: 0.000335 | Loss: 0.6078 | Pearson: 0.2310 | Best: 0.4038
# [Test] Fold 2 | Ep  39/10000 | Pearson: 0.1906 | Best: 0.2942
# Fold 2 | Ep  40/10000 | LR: 0.000328 | Loss: 0.5916 | Pearson: 0.2881 | Best: 0.4038
# [Test] Fold 2 | Ep  40/10000 | Pearson: 0.2264 | Best: 0.2942
# Fold 2 | Ep  41/10000 | LR: 0.000320 | Loss: 0.5832 | Pearson: 0.2423 | Best: 0.4038
# [Test] Fold 2 | Ep  41/10000 | Pearson: 0.2268 | Best: 0.2942
# Fold 2 | Ep  42/10000 | LR: 0.000313 | Loss: 0.5770 | Pearson: 0.2414 | Best: 0.4038
# [Test] Fold 2 | Ep  42/10000 | Pearson: 0.2186 | Best: 0.2942
# Fold 2 | Ep  43/10000 | LR: 0.000305 | Loss: 0.5640 | Pearson: 0.2331 | Best: 0.4038
# [Test] Fold 2 | Ep  43/10000 | Pearson: 0.2156 | Best: 0.2942
# Fold 2 | Ep  44/10000 | LR: 0.000297 | Loss: 0.5651 | Pearson: 0.2142 | Best: 0.4038
# [Test] Fold 2 | Ep  44/10000 | Pearson: 0.1850 | Best: 0.2942
# Fold 2 | Ep  45/10000 | LR: 0.000290 | Loss: 0.5493 | Pearson: 0.2431 | Best: 0.4038
# [Test] Fold 2 | Ep  45/10000 | Pearson: 0.1927 | Best: 0.2942
# Fold 2 | Ep  46/10000 | LR: 0.000282 | Loss: 0.5453 | Pearson: 0.2807 | Best: 0.4038
# [Test] Fold 2 | Ep  46/10000 | Pearson: 0.1953 | Best: 0.2942
# Fold 2 | Ep  47/10000 | LR: 0.000274 | Loss: 0.5461 | Pearson: 0.2160 | Best: 0.4038
# [Test] Fold 2 | Ep  47/10000 | Pearson: 0.2131 | Best: 0.2942
# Fold 2 | Ep  48/10000 | LR: 0.000266 | Loss: 0.5423 | Pearson: 0.1934 | Best: 0.4038
# [Test] Fold 2 | Ep  48/10000 | Pearson: 0.1844 | Best: 0.2942
# Fold 2 | Ep  49/10000 | LR: 0.000258 | Loss: 0.5303 | Pearson: 0.2256 | Best: 0.4038
# [Test] Fold 2 | Ep  49/10000 | Pearson: 0.2001 | Best: 0.2942
# Fold 2 | Ep  50/10000 | LR: 0.000251 | Loss: 0.5181 | Pearson: 0.2275 | Best: 0.4038
# [Test] Fold 2 | Ep  50/10000 | Pearson: 0.2049 | Best: 0.2942
# Fold 2 | Ep  51/10000 | LR: 0.000243 | Loss: 0.5251 | Pearson: 0.2510 | Best: 0.4038
# [Test] Fold 2 | Ep  51/10000 | Pearson: 0.2100 | Best: 0.2942
# Fold 2 | Ep  52/10000 | LR: 0.000235 | Loss: 0.5216 | Pearson: 0.2350 | Best: 0.4038
# [Test] Fold 2 | Ep  52/10000 | Pearson: 0.1906 | Best: 0.2942
# Fold 2 | Ep  53/10000 | LR: 0.000227 | Loss: 0.5077 | Pearson: 0.2748 | Best: 0.4038
# [Test] Fold 2 | Ep  53/10000 | Pearson: 0.1799 | Best: 0.2942
# Fold 2 | Ep  54/10000 | LR: 0.000219 | Loss: 0.5131 | Pearson: 0.2405 | Best: 0.4038
# [Test] Fold 2 | Ep  54/10000 | Pearson: 0.1887 | Best: 0.2942
# Fold 2 | Ep  55/10000 | LR: 0.000211 | Loss: 0.4984 | Pearson: 0.2368 | Best: 0.4038
# [Test] Fold 2 | Ep  55/10000 | Pearson: 0.1961 | Best: 0.2942
# Fold 2 | Ep  56/10000 | LR: 0.000204 | Loss: 0.4921 | Pearson: 0.2457 | Best: 0.4038
# [Test] Fold 2 | Ep  56/10000 | Pearson: 0.1845 | Best: 0.2942
# Fold 2 | Ep  57/10000 | LR: 0.000196 | Loss: 0.4897 | Pearson: 0.2288 | Best: 0.4038
# [Test] Fold 2 | Ep  57/10000 | Pearson: 0.1915 | Best: 0.2942
# Fold 2 | Ep  58/10000 | LR: 0.000188 | Loss: 0.4811 | Pearson: 0.2003 | Best: 0.4038
# [Test] Fold 2 | Ep  58/10000 | Pearson: 0.1875 | Best: 0.2942
# Fold 2 | Ep  59/10000 | LR: 0.000181 | Loss: 0.4677 | Pearson: 0.2199 | Best: 0.4038
# [Test] Fold 2 | Ep  59/10000 | Pearson: 0.1981 | Best: 0.2942
# Fold 2 | Ep  60/10000 | LR: 0.000173 | Loss: 0.4709 | Pearson: 0.2169 | Best: 0.4038
# [Test] Fold 2 | Ep  60/10000 | Pearson: 0.1993 | Best: 0.2942
# Fold 2 | Ep  61/10000 | LR: 0.000166 | Loss: 0.4627 | Pearson: 0.2086 | Best: 0.4038
# [Test] Fold 2 | Ep  61/10000 | Pearson: 0.1962 | Best: 0.2942
# Fold 2 | Ep  62/10000 | LR: 0.000159 | Loss: 0.4508 | Pearson: 0.1868 | Best: 0.4038
# [Test] Fold 2 | Ep  62/10000 | Pearson: 0.1543 | Best: 0.2942
# Fold 2 | Ep  63/10000 | LR: 0.000151 | Loss: 0.4452 | Pearson: 0.1958 | Best: 0.4038
# [Test] Fold 2 | Ep  63/10000 | Pearson: 0.1855 | Best: 0.2942
# Fold 2 | Ep  64/10000 | LR: 0.000144 | Loss: 0.4412 | Pearson: 0.2253 | Best: 0.4038
# [Test] Fold 2 | Ep  64/10000 | Pearson: 0.1947 | Best: 0.2942
# Fold 2 | Ep  65/10000 | LR: 0.000137 | Loss: 0.4421 | Pearson: 0.1913 | Best: 0.4038
# [Test] Fold 2 | Ep  65/10000 | Pearson: 0.1673 | Best: 0.2942
# Fold 2 | Ep  66/10000 | LR: 0.000130 | Loss: 0.4363 | Pearson: 0.2083 | Best: 0.4038
# [Test] Fold 2 | Ep  66/10000 | Pearson: 0.1753 | Best: 0.2942
# Fold 2 | Ep  67/10000 | LR: 0.000123 | Loss: 0.4348 | Pearson: 0.2157 | Best: 0.4038
# [Test] Fold 2 | Ep  67/10000 | Pearson: 0.1722 | Best: 0.2942
# Fold 2 | Ep  68/10000 | LR: 0.000117 | Loss: 0.4172 | Pearson: 0.2040 | Best: 0.4038
# [Test] Fold 2 | Ep  68/10000 | Pearson: 0.1773 | Best: 0.2942
# Fold 2 | Ep  69/10000 | LR: 0.000110 | Loss: 0.4221 | Pearson: 0.2001 | Best: 0.4038
# [Test] Fold 2 | Ep  69/10000 | Pearson: 0.1867 | Best: 0.2942
# Fold 2 | Ep  70/10000 | LR: 0.000104 | Loss: 0.4110 | Pearson: 0.1860 | Best: 0.4038
# [Test] Fold 2 | Ep  70/10000 | Pearson: 0.1540 | Best: 0.2942
# Fold 2 | Ep  71/10000 | LR: 0.000098 | Loss: 0.4206 | Pearson: 0.1949 | Best: 0.4038
# [Test] Fold 2 | Ep  71/10000 | Pearson: 0.1813 | Best: 0.2942
# Fold 2 | Ep  72/10000 | LR: 0.000091 | Loss: 0.4175 | Pearson: 0.2320 | Best: 0.4038
# [Test] Fold 2 | Ep  72/10000 | Pearson: 0.1681 | Best: 0.2942
# Fold 2 | Ep  73/10000 | LR: 0.000086 | Loss: 0.4089 | Pearson: 0.2000 | Best: 0.4038
# [Test] Fold 2 | Ep  73/10000 | Pearson: 0.1883 | Best: 0.2942
# Fold 2 | Ep  74/10000 | LR: 0.000080 | Loss: 0.4060 | Pearson: 0.1905 | Best: 0.4038
# [Test] Fold 2 | Ep  74/10000 | Pearson: 0.1752 | Best: 0.2942
# Fold 2 | Ep  75/10000 | LR: 0.000074 | Loss: 0.4063 | Pearson: 0.2100 | Best: 0.4038
# [Test] Fold 2 | Ep  75/10000 | Pearson: 0.1916 | Best: 0.2942
# Fold 2 | Ep  76/10000 | LR: 0.000069 | Loss: 0.3938 | Pearson: 0.1881 | Best: 0.4038
# [Test] Fold 2 | Ep  76/10000 | Pearson: 0.1737 | Best: 0.2942
# Fold 2 | Ep  77/10000 | LR: 0.000063 | Loss: 0.3886 | Pearson: 0.2065 | Best: 0.4038
# [Test] Fold 2 | Ep  77/10000 | Pearson: 0.1671 | Best: 0.2942
# Fold 2 | Ep  78/10000 | LR: 0.000058 | Loss: 0.3921 | Pearson: 0.1981 | Best: 0.4038
# [Test] Fold 2 | Ep  78/10000 | Pearson: 0.1671 | Best: 0.2942
# Fold 2 | Ep  79/10000 | LR: 0.000053 | Loss: 0.3858 | Pearson: 0.1882 | Best: 0.4038
# [Test] Fold 2 | Ep  79/10000 | Pearson: 0.1670 | Best: 0.2942
# Fold 2 | Ep  80/10000 | LR: 0.000049 | Loss: 0.3845 | Pearson: 0.2048 | Best: 0.4038
# [Test] Fold 2 | Ep  80/10000 | Pearson: 0.1652 | Best: 0.2942
# Fold 2 | Ep  81/10000 | LR: 0.000044 | Loss: 0.3785 | Pearson: 0.2120 | Best: 0.4038
# [Test] Fold 2 | Ep  81/10000 | Pearson: 0.1824 | Best: 0.2942
# Fold 2 | Ep  82/10000 | LR: 0.000040 | Loss: 0.3766 | Pearson: 0.1898 | Best: 0.4038
# [Test] Fold 2 | Ep  82/10000 | Pearson: 0.1625 | Best: 0.2942
# Fold 2 | Ep  83/10000 | LR: 0.000036 | Loss: 0.3723 | Pearson: 0.1979 | Best: 0.4038
# [Test] Fold 2 | Ep  83/10000 | Pearson: 0.1784 | Best: 0.2942
# Fold 2 | Ep  84/10000 | LR: 0.000032 | Loss: 0.3773 | Pearson: 0.1947 | Best: 0.4038
# [Test] Fold 2 | Ep  84/10000 | Pearson: 0.1752 | Best: 0.2942
# Fold 2 | Ep  85/10000 | LR: 0.000028 | Loss: 0.3794 | Pearson: 0.1901 | Best: 0.4038
# [Test] Fold 2 | Ep  85/10000 | Pearson: 0.1767 | Best: 0.2942
# Fold 2 | Ep  86/10000 | LR: 0.000025 | Loss: 0.3733 | Pearson: 0.2105 | Best: 0.4038
# [Test] Fold 2 | Ep  86/10000 | Pearson: 0.1761 | Best: 0.2942
# Fold 2 | Ep  87/10000 | LR: 0.000022 | Loss: 0.3786 | Pearson: 0.2078 | Best: 0.4038
# [Test] Fold 2 | Ep  87/10000 | Pearson: 0.1788 | Best: 0.2942
# Fold 2 | Ep  88/10000 | LR: 0.000019 | Loss: 0.3669 | Pearson: 0.2033 | Best: 0.4038
# [Test] Fold 2 | Ep  88/10000 | Pearson: 0.1791 | Best: 0.2942
# Fold 2 | Ep  89/10000 | LR: 0.000016 | Loss: 0.3712 | Pearson: 0.2003 | Best: 0.4038
# [Test] Fold 2 | Ep  89/10000 | Pearson: 0.1737 | Best: 0.2942
# Fold 2 | Ep  90/10000 | LR: 0.000013 | Loss: 0.3708 | Pearson: 0.2067 | Best: 0.4038
# [Test] Fold 2 | Ep  90/10000 | Pearson: 0.1811 | Best: 0.2942
# Fold 2 | Ep  91/10000 | LR: 0.000011 | Loss: 0.3638 | Pearson: 0.2043 | Best: 0.4038
# [Test] Fold 2 | Ep  91/10000 | Pearson: 0.1859 | Best: 0.2942
# Fold 2 | Ep  92/10000 | LR: 0.000009 | Loss: 0.3611 | Pearson: 0.1876 | Best: 0.4038
# ...
# Fold 3 | Ep  44/10000 | LR: 0.000297 | Loss: 0.5875 | Pearson: 0.3492 | Best: 0.4395
# [Test] Fold 3 | Ep  44/10000 | Pearson: 0.2255 | Best: 0.3200
# Fold 3 | Ep  45/10000 | LR: 0.000290 | Loss: 0.5708 | Pearson: 0.3368 | Best: 0.4395
# [Test] Fold 3 | Ep  45/10000 | Pearson: 0.2405 | Best: 0.3200
# Fold 3 | Ep  46/10000 | LR: 0.000282 | Loss: 0.5563 | Pearson: 0.3460 | Best: 0.4395
# [Test] Fold 3 | Ep  46/10000 | Pearson: 0.2322 | Best: 0.3200
# Fold 3 | Ep  47/10000 | LR: 0.000274 | Loss: 0.5593 | Pearson: 0.3195 | Best: 0.4395
# [Test] Fold 3 | Ep  47/10000 | Pearson: 0.1986 | Best: 0.3200
# Fold 3 | Ep  48/10000 | LR: 0.000266 | Loss: 0.5614 | Pearson: 0.3238 | Best: 0.4395
# [Test] Fold 3 | Ep  48/10000 | Pearson: 0.2161 | Best: 0.3200
# Fold 3 | Ep  49/10000 | LR: 0.000258 | Loss: 0.5619 | Pearson: 0.3149 | Best: 0.4395
# [Test] Fold 3 | Ep  49/10000 | Pearson: 0.2079 | Best: 0.3200
# Fold 3 | Ep  50/10000 | LR: 0.000251 | Loss: 0.5390 | Pearson: 0.3851 | Best: 0.4395
# [Test] Fold 3 | Ep  50/10000 | Pearson: 0.2413 | Best: 0.3200
# Fold 3 | Ep  51/10000 | LR: 0.000243 | Loss: 0.5292 | Pearson: 0.3253 | Best: 0.4395
# [Test] Fold 3 | Ep  51/10000 | Pearson: 0.2385 | Best: 0.3200
# Fold 3 | Ep  52/10000 | LR: 0.000235 | Loss: 0.5183 | Pearson: 0.3428 | Best: 0.4395
# [Test] Fold 3 | Ep  52/10000 | Pearson: 0.2392 | Best: 0.3200
# Fold 3 | Ep  53/10000 | LR: 0.000227 | Loss: 0.5183 | Pearson: 0.3505 | Best: 0.4395
# [Test] Fold 3 | Ep  53/10000 | Pearson: 0.2168 | Best: 0.3200
# Fold 3 | Ep  54/10000 | LR: 0.000219 | Loss: 0.5122 | Pearson: 0.3631 | Best: 0.4395
# [Test] Fold 3 | Ep  54/10000 | Pearson: 0.2210 | Best: 0.3200
# Fold 3 | Ep  55/10000 | LR: 0.000211 | Loss: 0.5004 | Pearson: 0.3367 | Best: 0.4395
# [Test] Fold 3 | Ep  55/10000 | Pearson: 0.2046 | Best: 0.3200
# Fold 3 | Ep  56/10000 | LR: 0.000204 | Loss: 0.4897 | Pearson: 0.3256 | Best: 0.4395
# [Test] Fold 3 | Ep  56/10000 | Pearson: 0.1945 | Best: 0.3200
# Fold 3 | Ep  57/10000 | LR: 0.000196 | Loss: 0.4972 | Pearson: 0.3543 | Best: 0.4395
# [Test] Fold 3 | Ep  57/10000 | Pearson: 0.2283 | Best: 0.3200
# Fold 3 | Ep  58/10000 | LR: 0.000188 | Loss: 0.4886 | Pearson: 0.3396 | Best: 0.4395
# [Test] Fold 3 | Ep  58/10000 | Pearson: 0.1907 | Best: 0.3200
# Fold 3 | Ep  59/10000 | LR: 0.000181 | Loss: 0.4851 | Pearson: 0.3597 | Best: 0.4395
# [Test] Fold 3 | Ep  59/10000 | Pearson: 0.2078 | Best: 0.3200
# Fold 3 | Ep  60/10000 | LR: 0.000173 | Loss: 0.4683 | Pearson: 0.3452 | Best: 0.4395
# [Test] Fold 3 | Ep  60/10000 | Pearson: 0.2229 | Best: 0.3200
# Fold 3 | Ep  61/10000 | LR: 0.000166 | Loss: 0.4755 | Pearson: 0.3298 | Best: 0.4395
# [Test] Fold 3 | Ep  61/10000 | Pearson: 0.1846 | Best: 0.3200
# Fold 3 | Ep  62/10000 | LR: 0.000159 | Loss: 0.4714 | Pearson: 0.3291 | Best: 0.4395
# [Test] Fold 3 | Ep  62/10000 | Pearson: 0.2114 | Best: 0.3200
# Fold 3 | Ep  63/10000 | LR: 0.000151 | Loss: 0.4710 | Pearson: 0.3334 | Best: 0.4395
# [Test] Fold 3 | Ep  63/10000 | Pearson: 0.2144 | Best: 0.3200
# Fold 3 | Ep  64/10000 | LR: 0.000144 | Loss: 0.4639 | Pearson: 0.3173 | Best: 0.4395
# [Test] Fold 3 | Ep  64/10000 | Pearson: 0.2059 | Best: 0.3200
# Fold 3 | Ep  65/10000 | LR: 0.000137 | Loss: 0.4498 | Pearson: 0.3425 | Best: 0.4395
# [Test] Fold 3 | Ep  65/10000 | Pearson: 0.2172 | Best: 0.3200
# Fold 3 | Ep  66/10000 | LR: 0.000130 | Loss: 0.4466 | Pearson: 0.3337 | Best: 0.4395
# [Test] Fold 3 | Ep  66/10000 | Pearson: 0.2105 | Best: 0.3200
# Fold 3 | Ep  67/10000 | LR: 0.000123 | Loss: 0.4453 | Pearson: 0.3488 | Best: 0.4395
# [Test] Fold 3 | Ep  67/10000 | Pearson: 0.2082 | Best: 0.3200
# Fold 3 | Ep  68/10000 | LR: 0.000117 | Loss: 0.4358 | Pearson: 0.3310 | Best: 0.4395
# [Test] Fold 3 | Ep  68/10000 | Pearson: 0.1958 | Best: 0.3200
# Fold 3 | Ep  69/10000 | LR: 0.000110 | Loss: 0.4351 | Pearson: 0.3405 | Best: 0.4395
# [Test] Fold 3 | Ep  69/10000 | Pearson: 0.1970 | Best: 0.3200
# Fold 3 | Ep  70/10000 | LR: 0.000104 | Loss: 0.4385 | Pearson: 0.3297 | Best: 0.4395
# [Test] Fold 3 | Ep  70/10000 | Pearson: 0.1942 | Best: 0.3200
# Fold 3 | Ep  71/10000 | LR: 0.000098 | Loss: 0.4141 | Pearson: 0.3505 | Best: 0.4395
# [Test] Fold 3 | Ep  71/10000 | Pearson: 0.1958 | Best: 0.3200
# Fold 3 | Ep  72/10000 | LR: 0.000091 | Loss: 0.4215 | Pearson: 0.3268 | Best: 0.4395
# [Test] Fold 3 | Ep  72/10000 | Pearson: 0.1846 | Best: 0.3200
# Fold 3 | Ep  73/10000 | LR: 0.000086 | Loss: 0.4205 | Pearson: 0.3415 | Best: 0.4395
# [Test] Fold 3 | Ep  73/10000 | Pearson: 0.1966 | Best: 0.3200
# Fold 3 | Ep  74/10000 | LR: 0.000080 | Loss: 0.4202 | Pearson: 0.3366 | Best: 0.4395
# [Test] Fold 3 | Ep  74/10000 | Pearson: 0.1837 | Best: 0.3200
# Fold 3 | Ep  75/10000 | LR: 0.000074 | Loss: 0.4051 | Pearson: 0.3306 | Best: 0.4395
# [Test] Fold 3 | Ep  75/10000 | Pearson: 0.1934 | Best: 0.3200
# Fold 3 | Ep  76/10000 | LR: 0.000069 | Loss: 0.4018 | Pearson: 0.3346 | Best: 0.4395
# [Test] Fold 3 | Ep  76/10000 | Pearson: 0.2015 | Best: 0.3200
# Fold 3 | Ep  77/10000 | LR: 0.000063 | Loss: 0.4065 | Pearson: 0.3184 | Best: 0.4395
# [Test] Fold 3 | Ep  77/10000 | Pearson: 0.1857 | Best: 0.3200
# Fold 3 | Ep  78/10000 | LR: 0.000058 | Loss: 0.4083 | Pearson: 0.3380 | Best: 0.4395
# [Test] Fold 3 | Ep  78/10000 | Pearson: 0.1886 | Best: 0.3200
# Fold 3 | Ep  79/10000 | LR: 0.000053 | Loss: 0.3947 | Pearson: 0.3319 | Best: 0.4395
# [Test] Fold 3 | Ep  79/10000 | Pearson: 0.1878 | Best: 0.3200
# Fold 3 | Ep  80/10000 | LR: 0.000049 | Loss: 0.3918 | Pearson: 0.3385 | Best: 0.4395
# [Test] Fold 3 | Ep  80/10000 | Pearson: 0.1807 | Best: 0.3200
# Fold 3 | Ep  81/10000 | LR: 0.000044 | Loss: 0.3908 | Pearson: 0.3393 | Best: 0.4395
# [Test] Fold 3 | Ep  81/10000 | Pearson: 0.1921 | Best: 0.3200
# Fold 3 | Ep  82/10000 | LR: 0.000040 | Loss: 0.3845 | Pearson: 0.3413 | Best: 0.4395
# [Test] Fold 3 | Ep  82/10000 | Pearson: 0.1858 | Best: 0.3200
# Fold 3 | Ep  83/10000 | LR: 0.000036 | Loss: 0.3916 | Pearson: 0.3379 | Best: 0.4395
# [Test] Fold 3 | Ep  83/10000 | Pearson: 0.1866 | Best: 0.3200
# Fold 3 | Ep  84/10000 | LR: 0.000032 | Loss: 0.3856 | Pearson: 0.3326 | Best: 0.4395
# [Test] Fold 3 | Ep  84/10000 | Pearson: 0.1859 | Best: 0.3200
# Fold 3 | Ep  85/10000 | LR: 0.000028 | Loss: 0.3916 | Pearson: 0.3390 | Best: 0.4395
# [Test] Fold 3 | Ep  85/10000 | Pearson: 0.1896 | Best: 0.3200
# Fold 3 | Ep  86/10000 | LR: 0.000025 | Loss: 0.3904 | Pearson: 0.3480 | Best: 0.4395
# [Test] Fold 3 | Ep  86/10000 | Pearson: 0.1987 | Best: 0.3200
# Fold 3 | Ep  87/10000 | LR: 0.000022 | Loss: 0.3744 | Pearson: 0.3415 | Best: 0.4395
# [Test] Fold 3 | Ep  87/10000 | Pearson: 0.1955 | Best: 0.3200
# Fold 3 | Ep  88/10000 | LR: 0.000019 | Loss: 0.3866 | Pearson: 0.3400 | Best: 0.4395
# [Test] Fold 3 | Ep  88/10000 | Pearson: 0.1854 | Best: 0.3200
# Fold 3 | Ep  89/10000 | LR: 0.000016 | Loss: 0.3724 | Pearson: 0.3309 | Best: 0.4395
# [Test] Fold 3 | Ep  89/10000 | Pearson: 0.1898 | Best: 0.3200
# Fold 3 | Ep  90/10000 | LR: 0.000013 | Loss: 0.3739 | Pearson: 0.3359 | Best: 0.4395
# [Test] Fold 3 | Ep  90/10000 | Pearson: 0.1873 | Best: 0.3200
# Fold 3 | Ep  91/10000 | LR: 0.000011 | Loss: 0.3793 | Pearson: 0.3373 | Best: 0.4395
# [Test] Fold 3 | Ep  91/10000 | Pearson: 0.1862 | Best: 0.3200
# Fold 3 | Ep  92/10000 | LR: 0.000009 | Loss: 0.3793 | Pearson: 0.3383 | Best: 0.4395
# [Test] Fold 3 | Ep  92/10000 | Pearson: 0.1824 | Best: 0.3200
# Fold 3 | Ep  93/10000 | LR: 0.000007 | Loss: 0.3657 | Pearson: 0.3403 | Best: 0.4395
# [Test] Fold 3 | Ep  93/10000 | Pearson: 0.1880 | Best: 0.3200
# Fold 3 | Ep  94/10000 | LR: 0.000005 | Loss: 0.3736 | Pearson: 0.3389 | Best: 0.4395
# [Test] Fold 3 | Ep  94/10000 | Pearson: 0.1905 | Best: 0.3200
# Fold 3 | Ep  95/10000 | LR: 0.000004 | Loss: 0.3724 | Pearson: 0.3365 | Best: 0.4395
# [Test] Fold 3 | Ep  95/10000 | Pearson: 0.1847 | Best: 0.3200
# Fold 3 | Ep  96/10000 | LR: 0.000003 | Loss: 0.3730 | Pearson: 0.3356 | Best: 0.4395
# [Test] Fold 3 | Ep  96/10000 | Pearson: 0.1873 | Best: 0.3200
# Fold 3 | Ep  97/10000 | LR: 0.000002 | Loss: 0.3707 | Pearson: 0.3379 | Best: 0.4395
# [Test] Fold 3 | Ep  97/10000 | Pearson: 0.1947 | Best: 0.3200
# Fold 3 | Ep  98/10000 | LR: 0.000001 | Loss: 0.3723 | Pearson: 0.3363 | Best: 0.4395
# [Test] Fold 3 | Ep  98/10000 | Pearson: 0.1859 | Best: 0.3200
# Fold 3 | Ep  99/10000 | LR: 0.000001 | Loss: 0.3691 | Pearson: 0.3359 | Best: 0.4395
# [Test] Fold 3 | Ep  99/10000 | Pearson: 0.1890 | Best: 0.3200
# Fold 3 | Ep 100/10000 | LR: 0.000001 | Loss: 0.3665 | Pearson: 0.3420 | Best: 0.4395
# [Test] Fold 3 | Ep 100/10000 | Pearson: 0.1928 | Best: 0.3200
# Fold 3 | Ep 101/10000 | LR: 0.000001 | Loss: 0.3643 | Pearson: 0.3345 | Best: 0.4395
# [Test] Fold 3 | Ep 101/10000 | Pearson: 0.1818 | Best: 0.3200
# Fold 3 | Ep 102/10000 | LR: 0.000001 | Loss: 0.3656 | Pearson: 0.3345 | Best: 0.4395
# [Test] Fold 3 | Ep 102/10000 | Pearson: 0.1914 | Best: 0.3200
# Fold 3 | Ep 103/10000 | LR: 0.000002 | Loss: 0.3667 | Pearson: 0.3358 | Best: 0.4395
# [Test] Fold 3 | Ep 103/10000 | Pearson: 0.1920 | Best: 0.3200
# Fold 3 | Ep 104/10000 | LR: 0.000003 | Loss: 0.3706 | Pearson: 0.3314 | Best: 0.4395
# [Test] Fold 3 | Ep 104/10000 | Pearson: 0.1887 | Best: 0.3200
# Fold 3 | Ep 105/10000 | LR: 0.000004 | Loss: 0.3616 | Pearson: 0.3313 | Best: 0.4395
# [Test] Fold 3 | Ep 105/10000 | Pearson: 0.1952 | Best: 0.3200
# Fold 3 | Ep 106/10000 | LR: 0.000005 | Loss: 0.3667 | Pearson: 0.3369 | Best: 0.4395
# [Test] Fold 3 | Ep 106/10000 | Pearson: 0.1889 | Best: 0.3200
# Fold 3 | Ep 107/10000 | LR: 0.000007 | Loss: 0.3642 | Pearson: 0.3391 | Best: 0.4395
# [Test] Fold 3 | Ep 107/10000 | Pearson: 0.1823 | Best: 0.3200
# Fold 3 | Ep 108/10000 | LR: 0.000009 | Loss: 0.3566 | Pearson: 0.3394 | Best: 0.4395
# [Test] Fold 3 | Ep 108/10000 | Pearson: 0.1938 | Best: 0.3200
# Fold 3 | Ep 109/10000 | LR: 0.000011 | Loss: 0.3625 | Pearson: 0.3411 | Best: 0.4395
# !!! Early Stopping triggered at epoch 109 !!!
#
# --- Starting 5-Fold Cross Validation: Fold 4 ---
# Fold 4 | Ep   1/10000 | LR: 0.000500 | Loss: 1.1217 | Pearson: 0.2785 | Best: 0.2785
# [Test] Fold 4 | Ep   1/10000 | Pearson: 0.2239 | Best: 0.2239
# Fold 4 | Ep   2/10000 | LR: 0.000500 | Loss: 1.0093 | Pearson: 0.2688 | Best: 0.2785
# [Test] Fold 4 | Ep   2/10000 | Pearson: 0.2793 | Best: 0.2793
# Fold 4 | Ep   3/10000 | LR: 0.000499 | Loss: 0.9887 | Pearson: 0.2989 | Best: 0.2989
# [Test] Fold 4 | Ep   3/10000 | Pearson: 0.2532 | Best: 0.2793
# Fold 4 | Ep   4/10000 | LR: 0.000498 | Loss: 0.9777 | Pearson: 0.2489 | Best: 0.2989
# [Test] Fold 4 | Ep   4/10000 | Pearson: 0.2765 | Best: 0.2793
# Fold 4 | Ep   5/10000 | LR: 0.000497 | Loss: 0.9543 | Pearson: 0.3227 | Best: 0.3227
# [Test] Fold 4 | Ep   5/10000 | Pearson: 0.2752 | Best: 0.2793
# Fold 4 | Ep   6/10000 | LR: 0.000496 | Loss: 0.9397 | Pearson: 0.3047 | Best: 0.3227
# [Test] Fold 4 | Ep   6/10000 | Pearson: 0.2566 | Best: 0.2793
# Fold 4 | Ep   7/10000 | LR: 0.000494 | Loss: 0.9192 | Pearson: 0.2947 | Best: 0.3227
# [Test] Fold 4 | Ep   7/10000 | Pearson: 0.2502 | Best: 0.2793
# Fold 4 | Ep   8/10000 | LR: 0.000492 | Loss: 0.9101 | Pearson: 0.3327 | Best: 0.3327
# [Test] Fold 4 | Ep   8/10000 | Pearson: 0.2661 | Best: 0.2793
# Fold 4 | Ep   9/10000 | LR: 0.000490 | Loss: 0.9010 | Pearson: 0.3801 | Best: 0.3801
# [Test] Fold 4 | Ep   9/10000 | Pearson: 0.3091 | Best: 0.3091
# Fold 4 | Ep  10/10000 | LR: 0.000488 | Loss: 0.8977 | Pearson: 0.3243 | Best: 0.3801
# [Test] Fold 4 | Ep  10/10000 | Pearson: 0.2826 | Best: 0.3091
# Fold 4 | Ep  11/10000 | LR: 0.000485 | Loss: 0.8831 | Pearson: 0.3515 | Best: 0.3801
# [Test] Fold 4 | Ep  11/10000 | Pearson: 0.2668 | Best: 0.3091
# Fold 4 | Ep  12/10000 | LR: 0.000482 | Loss: 0.8816 | Pearson: 0.3026 | Best: 0.3801
# [Test] Fold 4 | Ep  12/10000 | Pearson: 0.2996 | Best: 0.3091
# Fold 4 | Ep  13/10000 | LR: 0.000479 | Loss: 0.8510 | Pearson: 0.3995 | Best: 0.3995
# [Test] Fold 4 | Ep  13/10000 | Pearson: 0.3127 | Best: 0.3127
# Fold 4 | Ep  14/10000 | LR: 0.000476 | Loss: 0.8461 | Pearson: 0.3452 | Best: 0.3995
# [Test] Fold 4 | Ep  14/10000 | Pearson: 0.2987 | Best: 0.3127
# Fold 4 | Ep  15/10000 | LR: 0.000473 | Loss: 0.8424 | Pearson: 0.3464 | Best: 0.3995
# [Test] Fold 4 | Ep  15/10000 | Pearson: 0.2737 | Best: 0.3127
# Fold 4 | Ep  16/10000 | LR: 0.000469 | Loss: 0.8298 | Pearson: 0.2605 | Best: 0.3995
# [Test] Fold 4 | Ep  16/10000 | Pearson: 0.2721 | Best: 0.3127
# Fold 4 | Ep  17/10000 | LR: 0.000465 | Loss: 0.8202 | Pearson: 0.2911 | Best: 0.3995
# [Test] Fold 4 | Ep  17/10000 | Pearson: 0.2683 | Best: 0.3127
# Fold 4 | Ep  18/10000 | LR: 0.000461 | Loss: 0.8269 | Pearson: 0.3777 | Best: 0.3995
# [Test] Fold 4 | Ep  18/10000 | Pearson: 0.2845 | Best: 0.3127
# Fold 4 | Ep  19/10000 | LR: 0.000457 | Loss: 0.8044 | Pearson: 0.3051 | Best: 0.3995
# [Test] Fold 4 | Ep  19/10000 | Pearson: 0.2542 | Best: 0.3127
# Fold 4 | Ep  20/10000 | LR: 0.000452 | Loss: 0.7911 | Pearson: 0.3930 | Best: 0.3995
# [Test] Fold 4 | Ep  20/10000 | Pearson: 0.2668 | Best: 0.3127
# Fold 4 | Ep  21/10000 | LR: 0.000448 | Loss: 0.7927 | Pearson: 0.3567 | Best: 0.3995
# [Test] Fold 4 | Ep  21/10000 | Pearson: 0.2618 | Best: 0.3127
# Fold 4 | Ep  22/10000 | LR: 0.000443 | Loss: 0.7877 | Pearson: 0.3081 | Best: 0.3995
# [Test] Fold 4 | Ep  22/10000 | Pearson: 0.2784 | Best: 0.3127
# Fold 4 | Ep  23/10000 | LR: 0.000438 | Loss: 0.7624 | Pearson: 0.3882 | Best: 0.3995
# [Test] Fold 4 | Ep  23/10000 | Pearson: 0.2799 | Best: 0.3127
# Fold 4 | Ep  24/10000 | LR: 0.000432 | Loss: 0.7626 | Pearson: 0.3575 | Best: 0.3995
# [Test] Fold 4 | Ep  24/10000 | Pearson: 0.2456 | Best: 0.3127
# Fold 4 | Ep  25/10000 | LR: 0.000427 | Loss: 0.7538 | Pearson: 0.3684 | Best: 0.3995
# [Test] Fold 4 | Ep  25/10000 | Pearson: 0.2803 | Best: 0.3127
# Fold 4 | Ep  26/10000 | LR: 0.000421 | Loss: 0.7396 | Pearson: 0.3707 | Best: 0.3995
# [Test] Fold 4 | Ep  26/10000 | Pearson: 0.2622 | Best: 0.3127
# Fold 4 | Ep  27/10000 | LR: 0.000415 | Loss: 0.7382 | Pearson: 0.3581 | Best: 0.3995
# [Test] Fold 4 | Ep  27/10000 | Pearson: 0.2568 | Best: 0.3127
# Fold 4 | Ep  28/10000 | LR: 0.000410 | Loss: 0.7251 | Pearson: 0.3809 | Best: 0.3995
# [Test] Fold 4 | Ep  28/10000 | Pearson: 0.2898 | Best: 0.3127
# Fold 4 | Ep  29/10000 | LR: 0.000403 | Loss: 0.7133 | Pearson: 0.3473 | Best: 0.3995
# [Test] Fold 4 | Ep  29/10000 | Pearson: 0.2659 | Best: 0.3127
# Fold 4 | Ep  30/10000 | LR: 0.000397 | Loss: 0.7126 | Pearson: 0.3671 | Best: 0.3995
# [Test] Fold 4 | Ep  30/10000 | Pearson: 0.2757 | Best: 0.3127
# Fold 4 | Ep  31/10000 | LR: 0.000391 | Loss: 0.6920 | Pearson: 0.3486 | Best: 0.3995
# [Test] Fold 4 | Ep  31/10000 | Pearson: 0.2723 | Best: 0.3127
# Fold 4 | Ep  32/10000 | LR: 0.000384 | Loss: 0.6926 | Pearson: 0.3891 | Best: 0.3995
# [Test] Fold 4 | Ep  32/10000 | Pearson: 0.2516 | Best: 0.3127
# Fold 4 | Ep  33/10000 | LR: 0.000378 | Loss: 0.6853 | Pearson: 0.3259 | Best: 0.3995
# [Test] Fold 4 | Ep  33/10000 | Pearson: 0.2702 | Best: 0.3127
# Fold 4 | Ep  34/10000 | LR: 0.000371 | Loss: 0.6730 | Pearson: 0.3076 | Best: 0.3995
# [Test] Fold 4 | Ep  34/10000 | Pearson: 0.2419 | Best: 0.3127
# Fold 4 | Ep  35/10000 | LR: 0.000364 | Loss: 0.6732 | Pearson: 0.2814 | Best: 0.3995
# [Test] Fold 4 | Ep  35/10000 | Pearson: 0.2481 | Best: 0.3127
# Fold 4 | Ep  36/10000 | LR: 0.000357 | Loss: 0.6556 | Pearson: 0.3355 | Best: 0.3995
# [Test] Fold 4 | Ep  36/10000 | Pearson: 0.2777 | Best: 0.3127
# Fold 4 | Ep  37/10000 | LR: 0.000350 | Loss: 0.6547 | Pearson: 0.3618 | Best: 0.3995
# [Test] Fold 4 | Ep  37/10000 | Pearson: 0.2913 | Best: 0.3127
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 28
#      25     val_df = df[df['CVFOLD'] == f_idx].copy()
#      26     train_df = df[df['CVFOLD'] != f_idx].copy()
# ---> 28     best_score = train_one_fold(f_idx, train_df, val_df, test_loader, msa_dict_path, voxel_cache_dir, clip_weight_path)
#      29     final_results.append(best_score)
#      31 print("\n" + "="*40)
#
# Cell In[11], line 57, in train_one_fold(fold_idx, train_df, val_df, test_loader, msa_dict_path, voxel_cache_dir, clip_weight_path)
#      55     loss.backward()
#      56     optimizer.step()
# ---> 57     total_loss += loss.item()
#      59 # --- Validation Phase ---
#      60 model.eval()
#
# KeyboardInterrupt:
