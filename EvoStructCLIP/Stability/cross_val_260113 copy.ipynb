# %%
import os
import pickle
import torch
from torch.utils.data import Dataset
import random

AA_TO_INDEX = {
    'A': 0, 'C': 1, 'D': 2, 'E': 3, 'F': 4,
    'G': 5, 'H': 6, 'I': 7, 'K': 8, 'L': 9,
    'M': 10, 'N': 11, 'P': 12, 'Q': 13, 'R': 14,
    'S': 15, 'T': 16, 'V': 17, 'W': 18, 'Y': 19,
    '-': 20, 'X': 20  # padding 또는 unknown
}

def random_voxel_rotate(voxel):
    # voxel: Tensor [C, D, H, W]
    if random.random() < 0.5:  # 50% 확률로 회전 적용
        axes = [(2, 3), (1, 3), (1, 2)]  # (H, W), (D, W), (D, H)
        k = random.choice([1, 2, 3])  # 실제 회전만 (0 제외)
        axis = random.choice(axes)
        voxel = torch.rot90(voxel, k=k, dims=axis)
    return voxel

def random_voxel_flip(voxel):
    if random.random() < 0.5:
        voxel = torch.flip(voxel, dims=[1])  # D-axis flip
    if random.random() < 0.5:
        voxel = torch.flip(voxel, dims=[2])  # H-axis flip
    if random.random() < 0.5:
        voxel = torch.flip(voxel, dims=[3])  # W-axis flip
    return voxel

class VoxelDataset(Dataset):
    def __init__(self, df, voxel_cache_dir, aug=False, symmetry=False):
        self.df = df.reset_index(drop=True)
        self.voxel_cache_dir = voxel_cache_dir
        self.aug = aug
        self.symmetry = symmetry

    def __len__(self):
        return len(self.df) * 2 if self.symmetry else len(self.df)

    def __getitem__(self, idx):

        if self.symmetry:
            real_idx = idx // 2
            is_reverse = idx % 2  # 0이면 정방향, 1이면 역방향
        else:
            real_idx = idx
            is_reverse = 0

        row = self.df.iloc[real_idx]
        uid = row["PDB"]
        mut_pos = row["MAPPED_PDB_POS"]
        wt = row["WT"]
        mut = row["MT"]
        label = row["DDG"]

        key = f"{uid}_{mut_pos}"
        voxel_path = os.path.join(self.voxel_cache_dir, f"{key}.pkl")

        # Load voxel
        with open(voxel_path, "rb") as f:
            data = pickle.load(f)
            feature = data["feature"]  # shape: (1, 7, 7, 7, 63)

        # Preprocess
        feature_tensor = torch.from_numpy(feature).permute(0, 4, 1, 2, 3).float().squeeze(0)  # (63, 7, 7, 7)

        if self.aug:
            feature_tensor = random_voxel_rotate(feature_tensor)
            feature_tensor = random_voxel_flip(feature_tensor)
        
        if is_reverse == 0:
            # Convert WT/Mut AA to index
            ref_idx = torch.tensor(AA_TO_INDEX.get(str(wt), 20), dtype=torch.long)
            mut_idx = torch.tensor(AA_TO_INDEX.get(str(mut), 20), dtype=torch.long)
            target_label = label
        else:
            mut_idx = torch.tensor(AA_TO_INDEX.get(str(wt), 20), dtype=torch.long)
            ref_idx = torch.tensor(AA_TO_INDEX.get(str(mut), 20), dtype=torch.long)
            target_label = -label

        return feature_tensor, ref_idx, mut_idx, torch.tensor(target_label).float()
    
class MSADataset(Dataset):
    def __init__(self, df, msa_dict_path, max_depth=80, win_size=61, aug=False, symmetry=False):
        with open(msa_dict_path, "rb") as f:
            self.msa_dict = pickle.load(f)
        self.df = df
        self.max_depth = max_depth
        self.win_size = win_size
        self.half_win = win_size // 2  # 중심에서 양쪽 길이
        self.aug = aug
        self.symmetry = symmetry
        
    def __len__(self):
        return len(self.df) * 2 if self.symmetry else len(self.df)

    def __getitem__(self, idx):

        if self.symmetry:
            real_idx = idx // 2
            is_reverse = idx % 2  # 0이면 정방향, 1이면 역방향
        else:
            real_idx = idx
            is_reverse = 0

        row = self.df.iloc[real_idx]
        uid = row["PDB"]
        mut_pos = int(row["POS"]) - 1  # 1-based → 0-based
        mut = row["MT"].upper()
        label = row["DDG"]

        msa_seqs = [seq for _, seq in self.msa_dict[uid][:self.max_depth]]
        query_seq = msa_seqs[0]  # 보통 첫 줄이 ref seq

        # 변이 반영된 mut_seq 생성
        mut_seq = list(query_seq)
        if 0 <= mut_pos < len(mut_seq):
            mut_seq[mut_pos] = mut

        # --- 핵심 로직: 1, 2행 구성 ---
        if is_reverse == 0:
            # 정방향 (Mut -> WT): 기존 방식
            seqs_to_use = [mut_seq, list(query_seq)]
            target_label = label
        else:
            # 역방향 (WT -> Mut): 대칭 증강
            seqs_to_use = [list(query_seq), mut_seq]
            target_label = -label  # 라벨 부호 반전
            
        if len(msa_seqs) > 1:
            seqs_to_use += [list(seq) for seq in msa_seqs[1:self.max_depth - 2]]

        if self.aug:
            msa_part = seqs_to_use[2:]  # 변이+ref 제외
            random.shuffle(msa_part)   # 순서 섞기
            seqs_to_use = seqs_to_use[:2] + msa_part

        centered_msa = []
        for seq in seqs_to_use:
            window = []
            for i in range(self.win_size):
                seq_idx = mut_pos - self.half_win + i
                if 0 <= seq_idx < len(seq):
                    aa = seq[seq_idx]
                else:
                    aa = '-'
                window.append(AA_TO_INDEX.get(aa, 20))
            centered_msa.append(window)

        # depth padding
        while len(centered_msa) < self.max_depth:
            centered_msa.append([20] * self.win_size)  # 20은 패딩 인덱스

        msa_tensor = torch.tensor(centered_msa[:self.max_depth]).long()  # [D, L]
        msa_tensor = msa_tensor.transpose(0, 1)  # [L, D]

        return {
            "msa": msa_tensor,  # [L, D]
            "label": torch.tensor(target_label).float()
        }

class MultimodalDataset(Dataset):
    def __init__(self, df, voxel_cache_dir, msa_dict_path, 
                 voxel_aug=False, msa_aug=False, max_depth=80, win_size=61, symmetry=False):
        self.df = df.reset_index(drop=True)
        self.voxel_dataset = VoxelDataset(df, voxel_cache_dir, aug=voxel_aug, symmetry=symmetry)
        self.msa_dataset = MSADataset(df, msa_dict_path, max_depth=max_depth, win_size=win_size, aug=msa_aug, symmetry=symmetry)
        self.symmetry = symmetry
        
    def __len__(self):
        return len(self.df) * 2 if self.symmetry else len(self.df)

    def __getitem__(self, idx):
        voxel_feat, ref_idx, mut_idx, label = self.voxel_dataset[idx]
        msa_data = self.msa_dataset[idx]  # returns dict with "msa", "label"
        msa_tensor = msa_data["msa"]
        
        # 라벨 일치 확인 (안전용)
        assert label == msa_data["label"], "Mismatch in label!"

        return {
            "voxel": voxel_feat,      # [63, 7, 7, 7]
            "ref_idx": ref_idx,
            "mut_idx": mut_idx,
            "msa": msa_tensor,        # [L=61, D]
            "label": label
        }

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
    
import torch

# %%
import torch
import torch.nn as nn

# --- Voxel (Structural) Branch Components ---

class SqueezeExcitation3D(nn.Module):
    """3D SE block for channel-wise attention in voxel space."""
    def __init__(self, in_channels, reduction=24):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool3d(1)
        self.se = nn.Sequential(
            nn.Conv3d(in_channels, in_channels // reduction, kernel_size=1),
            nn.SiLU(),
            nn.Conv3d(in_channels // reduction, in_channels, kernel_size=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return x * self.se(self.pool(x))

class MBConv3D(nn.Module):
    """3D Inverted Residual Block (MobileNetV3 style) for efficient structural learning."""
    def __init__(self, in_ch, out_ch, expand_ratio=6, kernel_size=3, stride=1, se_reduction=16):
        super().__init__()
        mid_ch = in_ch * expand_ratio
        self.use_res_connect = (stride == 1 and in_ch == out_ch)

        self.expand = nn.Sequential(
            nn.Conv3d(in_ch, mid_ch, kernel_size=1, bias=False),
            nn.BatchNorm3d(mid_ch),
            nn.SiLU()
        ) if expand_ratio != 1 else nn.Identity()

        self.depthwise = nn.Sequential(
            nn.Conv3d(mid_ch, mid_ch, kernel_size=kernel_size, stride=stride,
                      padding=kernel_size//2, groups=mid_ch, bias=False),
            nn.BatchNorm3d(mid_ch),
            nn.SiLU()
        )

        self.se = SqueezeExcitation3D(mid_ch, reduction=se_reduction)
        self.project = nn.Sequential(
            nn.Conv3d(mid_ch, out_ch, kernel_size=1, bias=False),
            nn.BatchNorm3d(out_ch)
        )

    def forward(self, x):
        identity = x
        out = self.project(self.se(self.depthwise(self.expand(x))))

        return out + identity if self.use_res_connect else out


class h_sigmoid(nn.Module):
    def __init__(self, inplace=True):
        super().__init__()
        self.relu = nn.ReLU6(inplace=inplace)

    def forward(self, x):
        return self.relu(x + 3) / 6

class h_swish(nn.Module):
    def __init__(self, inplace=True):
        super().__init__()
        self.sigmoid = h_sigmoid(inplace=inplace)

    def forward(self, x):
        return x * self.sigmoid(x)

class CoordAtt3D(nn.Module):
    """3D Coordinate Attention for capturing long-range spatial dependencies along D, H, W axes."""
    def __init__(self, inp, oup, reduction=16):
        super().__init__()
        self.pool_d = nn.AdaptiveAvgPool3d((None, 1, 1))  
        self.pool_h = nn.AdaptiveAvgPool3d((1, None, 1)) 
        self.pool_w = nn.AdaptiveAvgPool3d((1, 1, None))  

        mip = max(8, inp // reduction)
        self.conv1 = nn.Conv3d(inp, mip, kernel_size=1, stride=1)
        self.bn1 = nn.BatchNorm3d(mip)
        self.act = h_swish()

        self.conv_d = nn.Conv3d(mip, oup, kernel_size=1, stride=1)
        self.conv_h = nn.Conv3d(mip, oup, kernel_size=1, stride=1)
        self.conv_w = nn.Conv3d(mip, oup, kernel_size=1, stride=1)

    def forward(self, x):
        identity = x
        B, C, D, H, W = x.size()

        # Pooling along axes
        x_d = self.pool_d(x)
        x_h = self.pool_h(x).permute(0, 1, 3, 2, 4)
        x_w = self.pool_w(x).permute(0, 1, 4, 2, 3)

        # Concatenate and encode spatial info
        y = self.act(self.bn1(self.conv1(torch.cat([x_d, x_h, x_w], dim=2))))
        y_d, y_h, y_w = torch.split(y, [D, H, W], dim=2)

        # Restore dimensions and apply sigmoid
        a_d = self.conv_d(y_d).sigmoid()
        a_h = self.conv_h(y_h.permute(0, 1, 3, 2, 4)).sigmoid()
        a_w = self.conv_w(y_w.permute(0, 1, 3, 4, 2)).sigmoid()
        
        return identity * a_d * a_h * a_w


class StructuralMutationAttention(nn.Module):
    """
    Option 2: 변이 정보(Mutation)를 Query로 하여 
    구조 피처(Voxel)의 중요한 부분을 선택적으로 강조하는 어텐션
    """
    def __init__(self, feat_dim, mut_dim):
        super().__init__()
        self.mut_to_query = nn.Linear(mut_dim, feat_dim)
        self.kv_conv = nn.Conv3d(feat_dim, feat_dim * 2, kernel_size=1)
        self.scale = feat_dim ** -0.5
        self.final_conv = nn.Conv3d(feat_dim, feat_dim, kernel_size=1)

    def forward(self, x, mut_emb):
        # x: [B, C, D, H, W] (구조 피처 맵)
        # mut_emb: [B, mut_dim] (변이 아미노산 임베딩)
        B, C, D, H, W = x.shape
        
        # 1. Query 생성: 변이 정보를 구조 피처와 같은 차원으로 매핑
        q = self.mut_to_query(mut_emb).view(B, 1, C) # [B, 1, C]
        
        # 2. Key, Value 생성: 3D 공간의 각 위치를 Key/Value로 변환
        kv = self.kv_conv(x).view(B, 2*C, -1).permute(0, 2, 1) # [B, D*H*W, 2*C]
        k, v = torch.chunk(kv, 2, dim=-1) # 각각 [B, D*H*W, C]

        # 3. Attention Score: "변이가 구조의 어느 위치와 관련 깊은가?"
        # [B, 1, C] @ [B, C, D*H*W] -> [B, 1, D*H*W]
        attn = torch.bmm(q, k.transpose(1, 2)) * self.scale
        attn = attn.softmax(dim=-1)
        
        # 4. Attention 적용
        # [B, 1, D*H*W] @ [B, D*H*W, C] -> [B, 1, C]
        out = torch.bmm(attn, v).view(B, C, 1, 1, 1)
        
        # 5. Gating: 구조 피처 맵에 어텐션 결과 반영
        return x * out.sigmoid()

class VoxelBranch(nn.Module):
    def __init__(self, in_ch=63, emb_dim=128):
        super().__init__()
        
        # 스테이지 1: 초기 구조 특징 추출
        self.stage1 = nn.Sequential(
            MBConv3D(in_ch, 32), MBConv3D(32, 48),
            MBConv3D(48, 64), MBConv3D(64, 64, stride=2) # 4x4x4 하향 샘플링
        )

        # --- [Option 2: Mid-Attention] ---
        # 64채널 시점에서 변이 정보 주입
        self.mut_mid_attn = StructuralMutationAttention(64, emb_dim // 2)
        
        # 스테이지 2: 심층 특징 추출
        self.stage2 = nn.Sequential(
            MBConv3D(64, 96), MBConv3D(96, 96),
            MBConv3D(96, 96), MBConv3D(96, 128),
            MBConv3D(128, emb_dim), MBConv3D(emb_dim, emb_dim)
        )

        self.coordatt = CoordAtt3D(emb_dim, emb_dim)
        self.pool = nn.AdaptiveAvgPool3d(1)

        # 임베딩 레이어
        self.ref_emb = nn.Embedding(21, emb_dim // 2)
        self.mut_emb = nn.Embedding(21, emb_dim // 2)
        
        # 최종 융합 헤드
        self.fusion = nn.Sequential(
            nn.Linear(emb_dim * 2, emb_dim),
            nn.BatchNorm1d(emb_dim),
            nn.SiLU(),
            nn.Linear(emb_dim, emb_dim)
        )

    def forward(self, x, ref_idx, mut_idx):
        # 1. 변이 임베딩 생성
        r_emb = self.ref_emb(ref_idx)
        m_emb = self.mut_emb(mut_idx)
        mut_context = torch.cat([r_emb, m_emb], dim=1) # [B, emb_dim]

        # 2. 스테이지 1 통과 (구조 정보)
        x = self.stage1(x)

        # 3. [Option 2 적용] 변이 정보를 기반으로 구조 피처 필터링
        # m_emb (64차원)를 Query로 사용하여 64채널의 x를 Attention
        x = self.mut_mid_attn(x, m_emb)

        # 4. 스테이지 2 통과
        x = self.stage2(x)
        struct_feat = self.pool(self.coordatt(x)).flatten(1)

        # 5. 최종 결합 (Late Fusion)
        combined = torch.cat([struct_feat, mut_context], dim=1)
        return self.fusion(combined)


import torch
import torch.nn as nn
from mamba_ssm import Mamba

# --- MSA (Sequence) Branch Components ---

class MSAInputEmbedding(nn.Module):
    """
    Converts raw MSA indices into continuous embedding space.
    Input: (B, L, D) -> Output: (B, L, D, C)
    """
    def __init__(self, vocab_size=21, dim=256):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings=vocab_size, embedding_dim=dim)

    def forward(self, x): 
        return self.embedding(x)  


class CrossAxialMambaMSA(nn.Module):
    """
    Hybrid block processing two axes:
    1. L-axis: Sequential context via Mamba (processed in parallel for all depths).
    2. D-axis: Evolutionary context via 1D-Conv (at the center mutation position).
    """
    def __init__(self, dim):
        super().__init__()
        self.norm_L = nn.RMSNorm(dim, eps=1e-8)
        self.norm_D = nn.RMSNorm(dim, eps=1e-8)

        self.mamba_L = Mamba(d_model=dim, expand=1)
        self.conv_D = nn.Sequential(
            nn.Conv1d(dim, dim, kernel_size=5, padding=2),
            nn.SiLU(),
            nn.Conv1d(dim, dim, kernel_size=5, padding=2),
            nn.SiLU()
        )

    def forward(self, x):  # x: (B, L, D, C)
        B, L, D, C = x.shape
        center_L = L // 2 
        
        # --- D-axis processing: 이제 모든 위치(L)에서 연산됨 ---
        res_d = self.norm_D(x).reshape(B * L, D, C).transpose(1, 2)
        d_out = self.conv_D(res_d).transpose(1, 2).view(B, L, D, C)

        # --- L-axis processing: Mamba ---
        x_l = self.norm_L(x).permute(0, 2, 1, 3).contiguous().view(B * D, L, C)
        l_out = self.mamba_L(x_l).view(B, D, L, C).permute(0, 2, 1, 3) 

        # --- Residual Connection: d_out이 이미 x와 같은 크기이므로 바로 더함 ---
        # d_full 부분을 삭제하고 d_out을 직접 더합니다.
        return x + d_out + l_out
    
class MSAEncoder(nn.Module):
    """Stack of Cross-Axial Mamba blocks for evolutionary feature extraction."""
    def __init__(self, num_layers=8, dim=256):
        super().__init__()
        self.embeddings = MSAInputEmbedding(dim=dim)
        self.blocks = nn.ModuleList([
            CrossAxialMambaMSA(dim) for _ in range(num_layers)
        ])
        self.norm_f = nn.RMSNorm(dim, eps=1e-8)

    def forward(self, x):  
        x = self.embeddings(x)  
        for block in self.blocks:
            x = block(x)
        return self.norm_f(x)  

class CenterAwarePooling(nn.Module):
    """
    Uses Multi-head Attention to aggregate global MSA context 
    using the center mutation site as the Query.
    """
    def __init__(self, dim, num_heads=8):
        super().__init__()
        self.attn = nn.MultiheadAttention(embed_dim=dim, num_heads=num_heads, batch_first=True)

        self.gate = nn.Sequential(
            nn.Linear(dim, dim // 2),
            nn.SiLU(),
            nn.Linear(dim // 2, 1)
        )
        
    def forward(self, x):  # x: (B, L, D, C)
        B, L, D, C = x.shape
        center_L = L // 2

        # Query: center residue profile [B*D, 1, C]
        query = x[:, center_L].reshape(B * D, 1, C)
        # Key/Value: entire window [B*D, L, C]
        keyval = x.permute(0, 2, 1, 3).reshape(B * D, L, C)

        attn_out, _ = self.attn(query, keyval, keyval)   # (B*D, 1, C)
        
    
        # 2. 서열별 특징 추출 [B, D, C]
        per_seq_feats = attn_out.view(B, D, C)
        
        # 3. [진짜 수정 포인트] Gated Attention Pooling
        # 각 Depth 서열이 얼마나 중요한지 점수를 매김 (Softmax)
        gate_weights = self.gate(per_seq_feats) # [B, D, 1]
        gate_weights = torch.softmax(gate_weights, dim=1) # 80개 서열의 중요도 합 = 1
        
        # 가중 평균 수행 (Weighted Sum)
        pooled = torch.sum(per_seq_feats * gate_weights, dim=1) # [B, C]

        return pooled
    
class MSABranch(nn.Module):
    """Complete MSA processing branch."""
    def __init__(self, num_layers=4, dim=128):
        super().__init__()
        self.encoder = MSAEncoder(num_layers=num_layers, dim=dim)
        self.pooling = CenterAwarePooling(dim, num_heads=4)
        self.refine = nn.Sequential(
            nn.Linear(dim, dim),
            nn.BatchNorm1d(dim),
            nn.SiLU()
        )

    def forward(self, x):  
        x = self.encoder(x)        
        x = self.pooling(x)        
        return self.refine(x)     
    
import numpy as np
import torch.nn.functional as F

# --- Main Multimodal Model ---
    
class EvoStructCLIP(nn.Module):
    """
    EvoStructCLIP: A Multimodal framework for Variant Effect Prediction.
    Integrates evolutionary information (MSA) and 3D structural context (Voxel).
    Uses Contrastive Learning (CLIP-style) and Classification.
    """
    def __init__(self, voxel_ch=63, mb_layers=12, embed_dim=128, use_concat=True):
        super().__init__()
        self.voxel_encoder = VoxelBranch(in_ch=voxel_ch, emb_dim=embed_dim)
        self.msa_encoder = MSABranch(num_layers=mb_layers, dim=embed_dim)
        self.use_concat = use_concat

        # CLIP temperature parameter
        self.logit_scale = nn.Parameter(torch.ones([]) * np.log(1 / 0.07))

        fused_dim = embed_dim * 2 if use_concat else embed_dim
        self.classifier = nn.Sequential(
            nn.Linear(fused_dim, embed_dim),
            nn.BatchNorm1d(embed_dim),
            nn.SiLU(),
            nn.Linear(embed_dim, 1)
        )

    def forward(self, voxel, ref_idx, mut_idx, msa):
        # 1. Extract features from both modalities
        voxel_feat = self.voxel_encoder(voxel, ref_idx, mut_idx) # (B, 128)
        msa_feat = self.msa_encoder(msa)                       # (B, 128)

        # 2. Compute Contrastive Logits (CLIP-style)
        v_norm = F.normalize(voxel_feat, dim=-1, eps=1e-8)
        m_norm = F.normalize(msa_feat, dim=-1, eps=1e-8)

        scale = self.logit_scale.exp()
        logits_per_voxel = torch.matmul(v_norm, m_norm.t()) * scale
        logits_per_msa = logits_per_voxel.t() 

        # 3. Final Classification Output
        fused = torch.cat([voxel_feat, msa_feat], dim=-1) if self.use_concat else voxel_feat + msa_feat
        logits = self.classifier(fused)

        return {
            "logits": logits,
            "logits_per_msa": logits_per_msa,
            "logits_per_voxel": logits_per_voxel,
            "voxel_feat": voxel_feat,
            "msa_feat": msa_feat
        }

# %%
import torch
import torch.nn as nn


class StabilityRegressor(nn.Module):
    def __init__(self, clip_model_path, voxel_ch=46, embed_dim=128):
        super().__init__()
        
        # 1. 사전 학습된 EvoStructCLIP 로드
        base_model = EvoStructCLIP(voxel_ch=voxel_ch, mb_layers=6, embed_dim=embed_dim)
        ckpt = torch.load(clip_model_path, map_location="cpu")
        base_model.load_state_dict(ckpt, strict=True)
        
        self.msa_branch = base_model.msa_encoder 
        self.voxel_branch = base_model.voxel_encoder
        
        # 가중치 해제 (0.6+ 성능을 위해 Fine-tuning 허용)
        for param in self.voxel_branch.parameters():
            param.requires_grad = True
        for param in self.msa_branch.parameters():
            param.requires_grad = True
        
        self.raw_norm = nn.LayerNorm(embed_dim)
        
        
        # 3. 최종 회귀 헤드 (입력 차원: embed_dim * 5)
        self.regressor = nn.Sequential(
            nn.Linear(embed_dim * 5, 256),
            nn.BatchNorm1d(256),
            nn.SiLU(),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.SiLU(),
            nn.Linear(128, 1)
        )

    def forward(self, msa, voxel, ref_idx, mut_idx):
        # --- (A) MSA Branch 특징 추출 ---
        # 1) 전체 MSA를 요약한 Global 특징 (기존 로직 유지)
        global_msa_feat = self.msa_branch(msa)
        
        # 2) Mutant/Wild-type 국소 임베딩 쏙쏙 뽑기
        # msa_branch 내부의 encoder를 직접 호출하여 중간 임베딩 획득
        x_msa_encoded = self.msa_branch.encoder(msa) # [B, L, D, C]
        B, L, D, C = x_msa_encoded.shape
        center_L = L // 2 # 변이 지점 (중앙)
        
        # 0번 서열(Mut)과 1번 서열(WT)의 중앙 위치 특징 추출
        # x_msa_encoded[:, center_L] -> [B, D, C]
        mut_seq_feat = self.raw_norm(x_msa_encoded[:, center_L, 0, :]) # [B, C]
        wt_seq_feat = self.raw_norm(x_msa_encoded[:, center_L, 1, :])  # [B, C]
        
        # 3) 명시적 차이(Delta) 피처 계산
        diff_feat = mut_seq_feat - wt_seq_feat

        # --- (B) Voxel Branch 특징 추출 ---
        voxel_feat = self.voxel_branch(voxel, ref_idx, mut_idx) # [B, 128]

        # --- (C) 특징 통합 및 Attention ---
        # 5개의 핵심 특징을 층층이 쌓음
        features = torch.stack([
            global_msa_feat, 
            mut_seq_feat, 
            wt_seq_feat, 
            diff_feat,
            voxel_feat
        ], dim=1) # [B, 5, 128]
    

        B = features.shape[0]
        # 최종 결합 및 회귀
        combined = features.reshape(B, -1) # [B, 640]
        return self.regressor(combined).squeeze(-1)

# %%
import torch.optim as optim
from scipy.stats import pearsonr
from tqdm.auto import tqdm
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import CosineAnnealingLR


def train_one_fold(fold_idx, train_df, val_df, test_loader, msa_dict_path, voxel_cache_dir, clip_weight_path):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # 1. 데이터로더 구성 (학습 효율을 위해 num_workers 설정)
    train_ds = MultimodalDataset(train_df, voxel_cache_dir, msa_dict_path, voxel_aug=False, msa_aug=False, symmetry=True)
    val_ds   = MultimodalDataset(val_df, voxel_cache_dir, msa_dict_path,symmetry=False)
    train_loader = DataLoader(train_ds, batch_size=24, shuffle=True, num_workers=6, pin_memory=True)
    val_loader = DataLoader(val_ds, batch_size=16, shuffle=False, num_workers=4, pin_memory=True)
    
    
    # 2. 모델 및 최적화 설정
    model = StabilityRegressor(clip_weight_path).to(device)
    criterion = nn.L1Loss()
    optimizer = optim.AdamW([
        {'params': model.msa_branch.parameters(), 'lr': 1e-3},    # 진화 정보: 아주 미세하게 조정
        {'params': model.voxel_branch.parameters(), 'lr':1e-3},  # 구조 정보: 약간의 적응 필요``
        {'params': model.regressor.parameters(), 'lr': 1e-3}     # 회귀 헤드: 빠르게 학습
    ], weight_decay=0.05)
    
    # 3. Cosine Annealing Scheduler 추가
    # T_max는 반주기 에폭 수입니다. 보통 전체 에폭 수와 같게 설정하여 끝까지 서서히 줄어들게 합니다.
    epochs = 10000
    scheduler = CosineAnnealingLR(optimizer, T_max=200, eta_min=1e-6)
    
    # 4. Early Stopping 설정
    patience = 100 # 15 에폭 동안 Pearson 점수가 오르지 않으면 중단
    counter = 0
    best_pearson = -1.0
    best_pearson_test = -1.0
    

    for epoch in range(epochs):
        # --- Training Phase ---
        model.train()
        total_loss = 0
        for batch in train_loader:
            msa = batch["msa"].to(device)
            labels = batch["label"].to(device)
            voxel = batch["voxel"].to(device)
            ref_idx = batch["ref_idx"].to(device)
            mut_idx = batch["mut_idx"].to(device)
            
            optimizer.zero_grad()
            preds = model(msa, voxel, ref_idx, mut_idx)
            loss = criterion(preds, labels) 
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        
        # --- Validation Phase ---
        model.eval()
        all_preds, all_labels = [], []
        with torch.no_grad():
            for batch in val_loader:
                msa = batch["msa"].to(device)
                labels = batch["label"].to(device)
                voxel = batch["voxel"].to(device)
                ref_idx = batch["ref_idx"].to(device)
                mut_idx = batch["mut_idx"].to(device)

                preds = model(msa, voxel, ref_idx, mut_idx) 
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        
        # Pearson 상관계수 계산
        fold_pearson, _ = pearsonr(all_labels, all_preds)
        
        # 스케줄러 스텝 (Cosine Decay 적용)
        scheduler.step()
        current_lr = optimizer.param_groups[0]['lr']
        
        # --- Early Stopping & Model Save Logic ---
        if fold_pearson > best_pearson:
            best_pearson = fold_pearson
            torch.save(model.state_dict(), f"best_reg_fold_{fold_idx}_0113.pth")
            counter = 0 # 개선되었으므로 카운터 리셋
        else:
            counter += 1 # 개선되지 않음
            
        print(f"Fold {fold_idx} | Ep {epoch+1:3d}/{epochs} | LR: {current_lr:.6f} | Loss: {total_loss/len(train_loader):.4f} | Pearson: {fold_pearson:.4f} | Best: {best_pearson:.4f}")
        
        if counter >= patience:
            print(f"!!! Early Stopping triggered at epoch {epoch+1} !!!")
            break

        # --- test Phase ---
        model.eval()
        all_preds, all_labels = [], []
        with torch.no_grad():
            for batch in test_loader:
                msa = batch["msa"].to(device)
                labels = batch["label"].to(device)
                voxel = batch["voxel"].to(device)
                ref_idx = batch["ref_idx"].to(device)
                mut_idx = batch["mut_idx"].to(device)

                preds = model(msa, voxel, ref_idx, mut_idx) 
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        
        # Pearson 상관계수 계산
        fold_pearson, _ = pearsonr(all_labels, all_preds)
        
        # --- Early Stopping & Model Save Logic ---
        if fold_pearson > best_pearson_test:
            best_pearson_test = fold_pearson
            torch.save(model.state_dict(), f"best_test_reg_fold_{fold_idx}_0113.pth")
            
        print(f"[Test] Fold {fold_idx} | Ep {epoch+1:3d}/{epochs} | Pearson: {fold_pearson:.4f} | Best: {best_pearson_test:.4f}")
        


    del model, optimizer, scheduler, train_loader, val_loader, test_loader
    return best_pearson

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"/mnt/c/Users/Kunny/Documents/GitHub/CAGI/EvoStructCLIP/Stability/S2450_Final_PDB_Mapped.tsv", sep="\t", )

# 경로 설정
msa_dict_path = "/mnt/e/CAGI_data/msa_dict_S2450.pkl"
voxel_cache_dir = "/mnt/e/CAGI_data/voxel_cache_S2450"
clip_weight_path = "/mnt/e/CAGI_data/best_cls_model_260108.pth"
fold_list = sorted(df['CVFOLD'].unique())

final_results = []


#----- test -----
test_tsv_path = "/mnt/c/Users/Kunny/Documents/GitHub/CAGI/EvoStructCLIP/Stability/S669_Offset_Corrected.tsv"
msa_dict_path_test = "/mnt/e/CAGI_data/msa_dict_S669.pkl"
voxel_cache_dir_test = "/mnt/e/CAGI_data/voxel_cache_S669"

test_df = pd.read_csv(test_tsv_path, sep="\t")
test_ds = MultimodalDataset(test_df, voxel_cache_dir_test, msa_dict_path_test, symmetry=False)
test_loader = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=4)

for f_idx in fold_list:
    print(f"\n--- Starting 5-Fold Cross Validation: Fold {f_idx} ---")
    val_df = df[df['CVFOLD'] == f_idx].copy()
    train_df = df[df['CVFOLD'] != f_idx].copy()
    
    best_score = train_one_fold(f_idx, train_df, val_df, test_loader, msa_dict_path, voxel_cache_dir, clip_weight_path)
    final_results.append(best_score)

print("\n" + "="*40)
print(f"5-Fold CV Average Pearson Correlation: {np.mean(final_results):.4f}")
print("="*40)
# Out:
# --- Starting 5-Fold Cross Validation: Fold 0 ---
# Fold 0 | Ep   1/10000 | LR: 0.001000 | Loss: 1.0593 | Pearson: 0.3677 | Best: 0.3677
# [Test] Fold 0 | Ep   1/10000 | Pearson: 0.3142 | Best: 0.3142
# Fold 0 | Ep   2/10000 | LR: 0.001000 | Loss: 0.8151 | Pearson: 0.4536 | Best: 0.4536
# [Test] Fold 0 | Ep   2/10000 | Pearson: 0.3612 | Best: 0.3612
# Fold 0 | Ep   3/10000 | LR: 0.000999 | Loss: 0.7222 | Pearson: 0.4255 | Best: 0.4536
# [Test] Fold 0 | Ep   3/10000 | Pearson: 0.3460 | Best: 0.3612
# Fold 0 | Ep   4/10000 | LR: 0.000999 | Loss: 0.8049 | Pearson: 0.4501 | Best: 0.4536
# [Test] Fold 0 | Ep   4/10000 | Pearson: 0.3078 | Best: 0.3612
# Fold 0 | Ep   5/10000 | LR: 0.000998 | Loss: 0.6308 | Pearson: 0.4781 | Best: 0.4781
# [Test] Fold 0 | Ep   5/10000 | Pearson: 0.3739 | Best: 0.3739
# Fold 0 | Ep   6/10000 | LR: 0.000998 | Loss: 0.5879 | Pearson: 0.4689 | Best: 0.4781
# [Test] Fold 0 | Ep   6/10000 | Pearson: 0.3728 | Best: 0.3739
# Fold 0 | Ep   7/10000 | LR: 0.000997 | Loss: 0.5362 | Pearson: 0.4301 | Best: 0.4781
# [Test] Fold 0 | Ep   7/10000 | Pearson: 0.3226 | Best: 0.3739
# Fold 0 | Ep   8/10000 | LR: 0.000996 | Loss: 0.4948 | Pearson: 0.4342 | Best: 0.4781
# [Test] Fold 0 | Ep   8/10000 | Pearson: 0.3133 | Best: 0.3739
# Fold 0 | Ep   9/10000 | LR: 0.000995 | Loss: 0.4755 | Pearson: 0.4363 | Best: 0.4781
# [Test] Fold 0 | Ep   9/10000 | Pearson: 0.3262 | Best: 0.3739
# Fold 0 | Ep  10/10000 | LR: 0.000994 | Loss: 0.4699 | Pearson: 0.4452 | Best: 0.4781
# [Test] Fold 0 | Ep  10/10000 | Pearson: 0.3374 | Best: 0.3739
# Fold 0 | Ep  11/10000 | LR: 0.000993 | Loss: 0.4702 | Pearson: 0.4345 | Best: 0.4781
# [Test] Fold 0 | Ep  11/10000 | Pearson: 0.3323 | Best: 0.3739
# Fold 0 | Ep  12/10000 | LR: 0.000991 | Loss: 0.4513 | Pearson: 0.4261 | Best: 0.4781
# [Test] Fold 0 | Ep  12/10000 | Pearson: 0.3269 | Best: 0.3739
# Fold 0 | Ep  13/10000 | LR: 0.000990 | Loss: 0.4332 | Pearson: 0.4704 | Best: 0.4781
# [Test] Fold 0 | Ep  13/10000 | Pearson: 0.3872 | Best: 0.3872
# Fold 0 | Ep  14/10000 | LR: 0.000988 | Loss: 0.4131 | Pearson: 0.4456 | Best: 0.4781
# [Test] Fold 0 | Ep  14/10000 | Pearson: 0.3475 | Best: 0.3872
# Fold 0 | Ep  15/10000 | LR: 0.000986 | Loss: 0.4222 | Pearson: 0.4331 | Best: 0.4781
# [Test] Fold 0 | Ep  15/10000 | Pearson: 0.3260 | Best: 0.3872
# Fold 0 | Ep  16/10000 | LR: 0.000984 | Loss: 0.4178 | Pearson: 0.4303 | Best: 0.4781
# [Test] Fold 0 | Ep  16/10000 | Pearson: 0.3327 | Best: 0.3872
# Fold 0 | Ep  17/10000 | LR: 0.000982 | Loss: 0.3839 | Pearson: 0.4201 | Best: 0.4781
# [Test] Fold 0 | Ep  17/10000 | Pearson: 0.3124 | Best: 0.3872
# Fold 0 | Ep  18/10000 | LR: 0.000980 | Loss: 0.3894 | Pearson: 0.4181 | Best: 0.4781
# [Test] Fold 0 | Ep  18/10000 | Pearson: 0.3127 | Best: 0.3872
# Fold 0 | Ep  19/10000 | LR: 0.000978 | Loss: 0.4227 | Pearson: 0.4516 | Best: 0.4781
# [Test] Fold 0 | Ep  19/10000 | Pearson: 0.3530 | Best: 0.3872
# Fold 0 | Ep  20/10000 | LR: 0.000976 | Loss: 0.3859 | Pearson: 0.4317 | Best: 0.4781
# [Test] Fold 0 | Ep  20/10000 | Pearson: 0.3449 | Best: 0.3872
# Fold 0 | Ep  21/10000 | LR: 0.000973 | Loss: 0.4217 | Pearson: 0.4538 | Best: 0.4781
# [Test] Fold 0 | Ep  21/10000 | Pearson: 0.3511 | Best: 0.3872
# Fold 0 | Ep  22/10000 | LR: 0.000970 | Loss: 0.4013 | Pearson: 0.4430 | Best: 0.4781
# [Test] Fold 0 | Ep  22/10000 | Pearson: 0.3535 | Best: 0.3872
# Fold 0 | Ep  23/10000 | LR: 0.000968 | Loss: 0.3944 | Pearson: 0.4418 | Best: 0.4781
# [Test] Fold 0 | Ep  23/10000 | Pearson: 0.3428 | Best: 0.3872
# Fold 0 | Ep  24/10000 | LR: 0.000965 | Loss: 0.3910 | Pearson: 0.4295 | Best: 0.4781
# [Test] Fold 0 | Ep  24/10000 | Pearson: 0.3545 | Best: 0.3872
# Fold 0 | Ep  25/10000 | LR: 0.000962 | Loss: 0.3832 | Pearson: 0.4205 | Best: 0.4781
# [Test] Fold 0 | Ep  25/10000 | Pearson: 0.3473 | Best: 0.3872
# Fold 0 | Ep  26/10000 | LR: 0.000959 | Loss: 0.4064 | Pearson: 0.4532 | Best: 0.4781
# [Test] Fold 0 | Ep  26/10000 | Pearson: 0.3493 | Best: 0.3872
# Fold 0 | Ep  27/10000 | LR: 0.000956 | Loss: 0.4060 | Pearson: 0.4459 | Best: 0.4781
# [Test] Fold 0 | Ep  27/10000 | Pearson: 0.3254 | Best: 0.3872
# Fold 0 | Ep  28/10000 | LR: 0.000952 | Loss: 0.3834 | Pearson: 0.4631 | Best: 0.4781
# [Test] Fold 0 | Ep  28/10000 | Pearson: 0.3624 | Best: 0.3872
# Fold 0 | Ep  29/10000 | LR: 0.000949 | Loss: 0.3652 | Pearson: 0.4799 | Best: 0.4799
# [Test] Fold 0 | Ep  29/10000 | Pearson: 0.3712 | Best: 0.3872
# Fold 0 | Ep  30/10000 | LR: 0.000946 | Loss: 0.3825 | Pearson: 0.4565 | Best: 0.4799
# [Test] Fold 0 | Ep  30/10000 | Pearson: 0.3331 | Best: 0.3872
# Fold 0 | Ep  31/10000 | LR: 0.000942 | Loss: 0.3537 | Pearson: 0.4801 | Best: 0.4801
# [Test] Fold 0 | Ep  31/10000 | Pearson: 0.3275 | Best: 0.3872
# Fold 0 | Ep  32/10000 | LR: 0.000938 | Loss: 0.3915 | Pearson: 0.4367 | Best: 0.4801
# [Test] Fold 0 | Ep  32/10000 | Pearson: 0.3354 | Best: 0.3872
# Fold 0 | Ep  33/10000 | LR: 0.000934 | Loss: 0.3725 | Pearson: 0.4133 | Best: 0.4801
# [Test] Fold 0 | Ep  33/10000 | Pearson: 0.3301 | Best: 0.3872
# Fold 0 | Ep  34/10000 | LR: 0.000930 | Loss: 0.3606 | Pearson: 0.4335 | Best: 0.4801
# [Test] Fold 0 | Ep  34/10000 | Pearson: 0.3190 | Best: 0.3872
# Fold 0 | Ep  35/10000 | LR: 0.000926 | Loss: 0.3701 | Pearson: 0.4598 | Best: 0.4801
# [Test] Fold 0 | Ep  35/10000 | Pearson: 0.3401 | Best: 0.3872
# Fold 0 | Ep  36/10000 | LR: 0.000922 | Loss: 0.3535 | Pearson: 0.4398 | Best: 0.4801
# [Test] Fold 0 | Ep  36/10000 | Pearson: 0.3465 | Best: 0.3872
# Fold 0 | Ep  37/10000 | LR: 0.000918 | Loss: 0.3478 | Pearson: 0.4472 | Best: 0.4801
# [Test] Fold 0 | Ep  37/10000 | Pearson: 0.3090 | Best: 0.3872
# Fold 0 | Ep  38/10000 | LR: 0.000914 | Loss: 0.3325 | Pearson: 0.4339 | Best: 0.4801
# [Test] Fold 0 | Ep  38/10000 | Pearson: 0.2988 | Best: 0.3872
# Fold 0 | Ep  39/10000 | LR: 0.000909 | Loss: 0.3466 | Pearson: 0.4504 | Best: 0.4801
# [Test] Fold 0 | Ep  39/10000 | Pearson: 0.3299 | Best: 0.3872
# Fold 0 | Ep  40/10000 | LR: 0.000905 | Loss: 0.3455 | Pearson: 0.4609 | Best: 0.4801
# [Test] Fold 0 | Ep  40/10000 | Pearson: 0.3284 | Best: 0.3872
# Fold 0 | Ep  41/10000 | LR: 0.000900 | Loss: 0.3424 | Pearson: 0.4633 | Best: 0.4801
# [Test] Fold 0 | Ep  41/10000 | Pearson: 0.3315 | Best: 0.3872
# Fold 0 | Ep  42/10000 | LR: 0.000895 | Loss: 0.3249 | Pearson: 0.4584 | Best: 0.4801
# [Test] Fold 0 | Ep  42/10000 | Pearson: 0.3029 | Best: 0.3872
# Fold 0 | Ep  43/10000 | LR: 0.000890 | Loss: 0.3404 | Pearson: 0.4466 | Best: 0.4801
# [Test] Fold 0 | Ep  43/10000 | Pearson: 0.3501 | Best: 0.3872
# Fold 0 | Ep  44/10000 | LR: 0.000885 | Loss: 0.3417 | Pearson: 0.4318 | Best: 0.4801
# [Test] Fold 0 | Ep  44/10000 | Pearson: 0.3160 | Best: 0.3872
# Fold 0 | Ep  45/10000 | LR: 0.000880 | Loss: 0.3560 | Pearson: 0.4362 | Best: 0.4801
# [Test] Fold 0 | Ep  45/10000 | Pearson: 0.3633 | Best: 0.3872
# Fold 0 | Ep  46/10000 | LR: 0.000875 | Loss: 0.3477 | Pearson: 0.4164 | Best: 0.4801
# [Test] Fold 0 | Ep  46/10000 | Pearson: 0.3345 | Best: 0.3872
# Fold 0 | Ep  47/10000 | LR: 0.000870 | Loss: 0.3286 | Pearson: 0.4262 | Best: 0.4801
# [Test] Fold 0 | Ep  47/10000 | Pearson: 0.3487 | Best: 0.3872
# Fold 0 | Ep  48/10000 | LR: 0.000865 | Loss: 0.3256 | Pearson: 0.3953 | Best: 0.4801
# [Test] Fold 0 | Ep  48/10000 | Pearson: 0.3137 | Best: 0.3872
# Fold 0 | Ep  49/10000 | LR: 0.000859 | Loss: 0.3213 | Pearson: 0.4185 | Best: 0.4801
# [Test] Fold 0 | Ep  49/10000 | Pearson: 0.3257 | Best: 0.3872
# Fold 0 | Ep  50/10000 | LR: 0.000854 | Loss: 0.3322 | Pearson: 0.4401 | Best: 0.4801
# [Test] Fold 0 | Ep  50/10000 | Pearson: 0.3060 | Best: 0.3872
# Fold 0 | Ep  51/10000 | LR: 0.000848 | Loss: 0.3123 | Pearson: 0.4185 | Best: 0.4801
# [Test] Fold 0 | Ep  51/10000 | Pearson: 0.3201 | Best: 0.3872
# Fold 0 | Ep  52/10000 | LR: 0.000842 | Loss: 0.3135 | Pearson: 0.4185 | Best: 0.4801
# [Test] Fold 0 | Ep  52/10000 | Pearson: 0.3254 | Best: 0.3872
# Fold 0 | Ep  53/10000 | LR: 0.000837 | Loss: 0.3185 | Pearson: 0.4493 | Best: 0.4801
# [Test] Fold 0 | Ep  53/10000 | Pearson: 0.3267 | Best: 0.3872
# Fold 0 | Ep  54/10000 | LR: 0.000831 | Loss: 0.3020 | Pearson: 0.4332 | Best: 0.4801
# [Test] Fold 0 | Ep  54/10000 | Pearson: 0.3233 | Best: 0.3872
# Fold 0 | Ep  55/10000 | LR: 0.000825 | Loss: 0.2863 | Pearson: 0.4406 | Best: 0.4801
# [Test] Fold 0 | Ep  55/10000 | Pearson: 0.3338 | Best: 0.3872
# Fold 0 | Ep  56/10000 | LR: 0.000819 | Loss: 0.2937 | Pearson: 0.4332 | Best: 0.4801
# [Test] Fold 0 | Ep  56/10000 | Pearson: 0.3047 | Best: 0.3872
# Fold 0 | Ep  57/10000 | LR: 0.000813 | Loss: 0.3247 | Pearson: 0.3983 | Best: 0.4801
# [Test] Fold 0 | Ep  57/10000 | Pearson: 0.3171 | Best: 0.3872
# Fold 0 | Ep  58/10000 | LR: 0.000807 | Loss: 0.3139 | Pearson: 0.4036 | Best: 0.4801
# [Test] Fold 0 | Ep  58/10000 | Pearson: 0.3166 | Best: 0.3872
# Fold 0 | Ep  59/10000 | LR: 0.000800 | Loss: 0.2944 | Pearson: 0.4049 | Best: 0.4801
# [Test] Fold 0 | Ep  59/10000 | Pearson: 0.3304 | Best: 0.3872
# Fold 0 | Ep  60/10000 | LR: 0.000794 | Loss: 0.3415 | Pearson: 0.3831 | Best: 0.4801
# [Test] Fold 0 | Ep  60/10000 | Pearson: 0.3378 | Best: 0.3872
# Fold 0 | Ep  61/10000 | LR: 0.000788 | Loss: 0.2996 | Pearson: 0.4082 | Best: 0.4801
# [Test] Fold 0 | Ep  61/10000 | Pearson: 0.3042 | Best: 0.3872
# Fold 0 | Ep  62/10000 | LR: 0.000781 | Loss: 0.2920 | Pearson: 0.4080 | Best: 0.4801
# [Test] Fold 0 | Ep  62/10000 | Pearson: 0.3186 | Best: 0.3872
# Fold 0 | Ep  63/10000 | LR: 0.000775 | Loss: 0.2848 | Pearson: 0.3905 | Best: 0.4801
# [Test] Fold 0 | Ep  63/10000 | Pearson: 0.3147 | Best: 0.3872
# Fold 0 | Ep  64/10000 | LR: 0.000768 | Loss: 0.2647 | Pearson: 0.3867 | Best: 0.4801
# [Test] Fold 0 | Ep  64/10000 | Pearson: 0.3325 | Best: 0.3872
# Fold 0 | Ep  65/10000 | LR: 0.000761 | Loss: 0.2918 | Pearson: 0.3865 | Best: 0.4801
# [Test] Fold 0 | Ep  65/10000 | Pearson: 0.3205 | Best: 0.3872
# Fold 0 | Ep  66/10000 | LR: 0.000755 | Loss: 0.2869 | Pearson: 0.4038 | Best: 0.4801
# [Test] Fold 0 | Ep  66/10000 | Pearson: 0.3229 | Best: 0.3872
# Fold 0 | Ep  67/10000 | LR: 0.000748 | Loss: 0.2519 | Pearson: 0.3856 | Best: 0.4801
# [Test] Fold 0 | Ep  67/10000 | Pearson: 0.3124 | Best: 0.3872
# Fold 0 | Ep  68/10000 | LR: 0.000741 | Loss: 0.2817 | Pearson: 0.3948 | Best: 0.4801
# [Test] Fold 0 | Ep  68/10000 | Pearson: 0.2913 | Best: 0.3872
# Fold 0 | Ep  69/10000 | LR: 0.000734 | Loss: 0.2644 | Pearson: 0.3759 | Best: 0.4801
# [Test] Fold 0 | Ep  69/10000 | Pearson: 0.2873 | Best: 0.3872
# Fold 0 | Ep  70/10000 | LR: 0.000727 | Loss: 0.2607 | Pearson: 0.3975 | Best: 0.4801
# [Test] Fold 0 | Ep  70/10000 | Pearson: 0.2939 | Best: 0.3872
# Fold 0 | Ep  71/10000 | LR: 0.000720 | Loss: 0.2516 | Pearson: 0.3777 | Best: 0.4801
# [Test] Fold 0 | Ep  71/10000 | Pearson: 0.2794 | Best: 0.3872
# Fold 0 | Ep  72/10000 | LR: 0.000713 | Loss: 0.2748 | Pearson: 0.3627 | Best: 0.4801
# [Test] Fold 0 | Ep  72/10000 | Pearson: 0.2763 | Best: 0.3872
# Fold 0 | Ep  73/10000 | LR: 0.000706 | Loss: 0.2357 | Pearson: 0.3906 | Best: 0.4801
# [Test] Fold 0 | Ep  73/10000 | Pearson: 0.3053 | Best: 0.3872
# Fold 0 | Ep  74/10000 | LR: 0.000699 | Loss: 0.2579 | Pearson: 0.3949 | Best: 0.4801
# [Test] Fold 0 | Ep  74/10000 | Pearson: 0.2752 | Best: 0.3872
# Fold 0 | Ep  75/10000 | LR: 0.000692 | Loss: 0.2492 | Pearson: 0.3749 | Best: 0.4801
# [Test] Fold 0 | Ep  75/10000 | Pearson: 0.2864 | Best: 0.3872
# Fold 0 | Ep  76/10000 | LR: 0.000684 | Loss: 0.2312 | Pearson: 0.3879 | Best: 0.4801
# [Test] Fold 0 | Ep  76/10000 | Pearson: 0.3060 | Best: 0.3872
# Fold 0 | Ep  77/10000 | LR: 0.000677 | Loss: 0.2221 | Pearson: 0.4071 | Best: 0.4801
# [Test] Fold 0 | Ep  77/10000 | Pearson: 0.2996 | Best: 0.3872
# Fold 0 | Ep  78/10000 | LR: 0.000670 | Loss: 0.2209 | Pearson: 0.3969 | Best: 0.4801
# [Test] Fold 0 | Ep  78/10000 | Pearson: 0.2923 | Best: 0.3872
# Fold 0 | Ep  79/10000 | LR: 0.000662 | Loss: 0.2303 | Pearson: 0.3985 | Best: 0.4801
# [Test] Fold 0 | Ep  79/10000 | Pearson: 0.3065 | Best: 0.3872
# Fold 0 | Ep  80/10000 | LR: 0.000655 | Loss: 0.2170 | Pearson: 0.4110 | Best: 0.4801
# [Test] Fold 0 | Ep  80/10000 | Pearson: 0.2683 | Best: 0.3872
# Fold 0 | Ep  81/10000 | LR: 0.000647 | Loss: 0.2387 | Pearson: 0.3933 | Best: 0.4801
# [Test] Fold 0 | Ep  81/10000 | Pearson: 0.2766 | Best: 0.3872
# Fold 0 | Ep  82/10000 | LR: 0.000640 | Loss: 0.2198 | Pearson: 0.3798 | Best: 0.4801
# [Test] Fold 0 | Ep  82/10000 | Pearson: 0.2683 | Best: 0.3872
# Fold 0 | Ep  83/10000 | LR: 0.000632 | Loss: 0.2259 | Pearson: 0.4082 | Best: 0.4801
# [Test] Fold 0 | Ep  83/10000 | Pearson: 0.2824 | Best: 0.3872
# Fold 0 | Ep  84/10000 | LR: 0.000625 | Loss: 0.2266 | Pearson: 0.4165 | Best: 0.4801
# [Test] Fold 0 | Ep  84/10000 | Pearson: 0.3040 | Best: 0.3872
# Fold 0 | Ep  85/10000 | LR: 0.000617 | Loss: 0.2145 | Pearson: 0.4084 | Best: 0.4801
# [Test] Fold 0 | Ep  85/10000 | Pearson: 0.3036 | Best: 0.3872
# Fold 0 | Ep  86/10000 | LR: 0.000609 | Loss: 0.2283 | Pearson: 0.4003 | Best: 0.4801
# [Test] Fold 0 | Ep  86/10000 | Pearson: 0.3037 | Best: 0.3872
# Fold 0 | Ep  87/10000 | LR: 0.000602 | Loss: 0.2068 | Pearson: 0.4170 | Best: 0.4801
# [Test] Fold 0 | Ep  87/10000 | Pearson: 0.3079 | Best: 0.3872
# Fold 0 | Ep  88/10000 | LR: 0.000594 | Loss: 0.2319 | Pearson: 0.3971 | Best: 0.4801
# [Test] Fold 0 | Ep  88/10000 | Pearson: 0.2704 | Best: 0.3872
# Fold 0 | Ep  89/10000 | LR: 0.000586 | Loss: 0.2017 | Pearson: 0.3972 | Best: 0.4801
# [Test] Fold 0 | Ep  89/10000 | Pearson: 0.2733 | Best: 0.3872
# Fold 0 | Ep  90/10000 | LR: 0.000579 | Loss: 0.2040 | Pearson: 0.3751 | Best: 0.4801
# [Test] Fold 0 | Ep  90/10000 | Pearson: 0.2698 | Best: 0.3872
# Fold 0 | Ep  91/10000 | LR: 0.000571 | Loss: 0.2017 | Pearson: 0.3890 | Best: 0.4801
# [Test] Fold 0 | Ep  91/10000 | Pearson: 0.2714 | Best: 0.3872
# Fold 0 | Ep  92/10000 | LR: 0.000563 | Loss: 0.2010 | Pearson: 0.4157 | Best: 0.4801
# [Test] Fold 0 | Ep  92/10000 | Pearson: 0.2732 | Best: 0.3872
# Fold 0 | Ep  93/10000 | LR: 0.000555 | Loss: 0.2025 | Pearson: 0.4067 | Best: 0.4801
# [Test] Fold 0 | Ep  93/10000 | Pearson: 0.2853 | Best: 0.3872
# Fold 0 | Ep  94/10000 | LR: 0.000548 | Loss: 0.1881 | Pearson: 0.3832 | Best: 0.4801
# [Test] Fold 0 | Ep  94/10000 | Pearson: 0.2716 | Best: 0.3872
# Fold 0 | Ep  95/10000 | LR: 0.000540 | Loss: 0.1810 | Pearson: 0.3805 | Best: 0.4801
# [Test] Fold 0 | Ep  95/10000 | Pearson: 0.2934 | Best: 0.3872
# Fold 0 | Ep  96/10000 | LR: 0.000532 | Loss: 0.1897 | Pearson: 0.3917 | Best: 0.4801
# [Test] Fold 0 | Ep  96/10000 | Pearson: 0.2920 | Best: 0.3872
# Fold 0 | Ep  97/10000 | LR: 0.000524 | Loss: 0.1743 | Pearson: 0.3766 | Best: 0.4801
# [Test] Fold 0 | Ep  97/10000 | Pearson: 0.2851 | Best: 0.3872
# Fold 0 | Ep  98/10000 | LR: 0.000516 | Loss: 0.1848 | Pearson: 0.3874 | Best: 0.4801
# [Test] Fold 0 | Ep  98/10000 | Pearson: 0.2953 | Best: 0.3872
# Fold 0 | Ep  99/10000 | LR: 0.000508 | Loss: 0.1815 | Pearson: 0.3842 | Best: 0.4801
# [Test] Fold 0 | Ep  99/10000 | Pearson: 0.2836 | Best: 0.3872
# Fold 0 | Ep 100/10000 | LR: 0.000501 | Loss: 0.1949 | Pearson: 0.3876 | Best: 0.4801
# [Test] Fold 0 | Ep 100/10000 | Pearson: 0.2882 | Best: 0.3872
# Fold 0 | Ep 101/10000 | LR: 0.000493 | Loss: 0.1772 | Pearson: 0.4018 | Best: 0.4801
# [Test] Fold 0 | Ep 101/10000 | Pearson: 0.2744 | Best: 0.3872
# Fold 0 | Ep 102/10000 | LR: 0.000485 | Loss: 0.1730 | Pearson: 0.3901 | Best: 0.4801
# [Test] Fold 0 | Ep 102/10000 | Pearson: 0.2849 | Best: 0.3872
# Fold 0 | Ep 103/10000 | LR: 0.000477 | Loss: 0.1782 | Pearson: 0.3967 | Best: 0.4801
# [Test] Fold 0 | Ep 103/10000 | Pearson: 0.2854 | Best: 0.3872
# Fold 0 | Ep 104/10000 | LR: 0.000469 | Loss: 0.1790 | Pearson: 0.4099 | Best: 0.4801
# [Test] Fold 0 | Ep 104/10000 | Pearson: 0.2803 | Best: 0.3872
# Fold 0 | Ep 105/10000 | LR: 0.000461 | Loss: 0.1626 | Pearson: 0.3960 | Best: 0.4801
# [Test] Fold 0 | Ep 105/10000 | Pearson: 0.2881 | Best: 0.3872
# Fold 0 | Ep 106/10000 | LR: 0.000453 | Loss: 0.1636 | Pearson: 0.3895 | Best: 0.4801
# [Test] Fold 0 | Ep 106/10000 | Pearson: 0.2921 | Best: 0.3872
# Fold 0 | Ep 107/10000 | LR: 0.000446 | Loss: 0.1721 | Pearson: 0.3845 | Best: 0.4801
# [Test] Fold 0 | Ep 107/10000 | Pearson: 0.2554 | Best: 0.3872
# Fold 0 | Ep 108/10000 | LR: 0.000438 | Loss: 0.1628 | Pearson: 0.3829 | Best: 0.4801
# [Test] Fold 0 | Ep 108/10000 | Pearson: 0.2726 | Best: 0.3872
# Fold 0 | Ep 109/10000 | LR: 0.000430 | Loss: 0.1568 | Pearson: 0.4027 | Best: 0.4801
# [Test] Fold 0 | Ep 109/10000 | Pearson: 0.2609 | Best: 0.3872
# Fold 0 | Ep 110/10000 | LR: 0.000422 | Loss: 0.1516 | Pearson: 0.3962 | Best: 0.4801
# [Test] Fold 0 | Ep 110/10000 | Pearson: 0.2784 | Best: 0.3872
# Fold 0 | Ep 111/10000 | LR: 0.000415 | Loss: 0.1640 | Pearson: 0.4059 | Best: 0.4801
# [Test] Fold 0 | Ep 111/10000 | Pearson: 0.2656 | Best: 0.3872
# Fold 0 | Ep 112/10000 | LR: 0.000407 | Loss: 0.1630 | Pearson: 0.3846 | Best: 0.4801
# [Test] Fold 0 | Ep 112/10000 | Pearson: 0.2819 | Best: 0.3872
# Fold 0 | Ep 113/10000 | LR: 0.000399 | Loss: 0.1485 | Pearson: 0.3999 | Best: 0.4801
# [Test] Fold 0 | Ep 113/10000 | Pearson: 0.2774 | Best: 0.3872
# Fold 0 | Ep 114/10000 | LR: 0.000392 | Loss: 0.1423 | Pearson: 0.4007 | Best: 0.4801
# [Test] Fold 0 | Ep 114/10000 | Pearson: 0.2977 | Best: 0.3872
# Fold 0 | Ep 115/10000 | LR: 0.000384 | Loss: 0.1511 | Pearson: 0.3693 | Best: 0.4801
# [Test] Fold 0 | Ep 115/10000 | Pearson: 0.2477 | Best: 0.3872
# Fold 0 | Ep 116/10000 | LR: 0.000376 | Loss: 0.1418 | Pearson: 0.3735 | Best: 0.4801
# [Test] Fold 0 | Ep 116/10000 | Pearson: 0.2686 | Best: 0.3872
# Fold 0 | Ep 117/10000 | LR: 0.000369 | Loss: 0.1407 | Pearson: 0.3915 | Best: 0.4801
# [Test] Fold 0 | Ep 117/10000 | Pearson: 0.2738 | Best: 0.3872
# Fold 0 | Ep 118/10000 | LR: 0.000361 | Loss: 0.1516 | Pearson: 0.3956 | Best: 0.4801
# [Test] Fold 0 | Ep 118/10000 | Pearson: 0.2905 | Best: 0.3872
# Fold 0 | Ep 119/10000 | LR: 0.000354 | Loss: 0.1339 | Pearson: 0.3920 | Best: 0.4801
# [Test] Fold 0 | Ep 119/10000 | Pearson: 0.2716 | Best: 0.3872
# Fold 0 | Ep 120/10000 | LR: 0.000346 | Loss: 0.1436 | Pearson: 0.4197 | Best: 0.4801
# [Test] Fold 0 | Ep 120/10000 | Pearson: 0.2738 | Best: 0.3872
# Fold 0 | Ep 121/10000 | LR: 0.000339 | Loss: 0.1427 | Pearson: 0.4039 | Best: 0.4801
# [Test] Fold 0 | Ep 121/10000 | Pearson: 0.2972 | Best: 0.3872
# Fold 0 | Ep 122/10000 | LR: 0.000331 | Loss: 0.1289 | Pearson: 0.4024 | Best: 0.4801
# [Test] Fold 0 | Ep 122/10000 | Pearson: 0.2808 | Best: 0.3872
# Fold 0 | Ep 123/10000 | LR: 0.000324 | Loss: 0.1344 | Pearson: 0.4055 | Best: 0.4801
# [Test] Fold 0 | Ep 123/10000 | Pearson: 0.2933 | Best: 0.3872
# Fold 0 | Ep 124/10000 | LR: 0.000317 | Loss: 0.1364 | Pearson: 0.4243 | Best: 0.4801
# [Test] Fold 0 | Ep 124/10000 | Pearson: 0.2949 | Best: 0.3872
# Fold 0 | Ep 125/10000 | LR: 0.000309 | Loss: 0.1319 | Pearson: 0.4055 | Best: 0.4801
# [Test] Fold 0 | Ep 125/10000 | Pearson: 0.3059 | Best: 0.3872
# Fold 0 | Ep 126/10000 | LR: 0.000302 | Loss: 0.1170 | Pearson: 0.4134 | Best: 0.4801
# [Test] Fold 0 | Ep 126/10000 | Pearson: 0.2958 | Best: 0.3872
# Fold 0 | Ep 127/10000 | LR: 0.000295 | Loss: 0.1146 | Pearson: 0.4002 | Best: 0.4801
# [Test] Fold 0 | Ep 127/10000 | Pearson: 0.2853 | Best: 0.3872
# Fold 0 | Ep 128/10000 | LR: 0.000288 | Loss: 0.1247 | Pearson: 0.4120 | Best: 0.4801
# [Test] Fold 0 | Ep 128/10000 | Pearson: 0.2884 | Best: 0.3872
# Fold 0 | Ep 129/10000 | LR: 0.000281 | Loss: 0.1267 | Pearson: 0.4154 | Best: 0.4801
# [Test] Fold 0 | Ep 129/10000 | Pearson: 0.2866 | Best: 0.3872
# Fold 0 | Ep 130/10000 | LR: 0.000274 | Loss: 0.1154 | Pearson: 0.3942 | Best: 0.4801
# [Test] Fold 0 | Ep 130/10000 | Pearson: 0.2757 | Best: 0.3872
# Fold 0 | Ep 131/10000 | LR: 0.000267 | Loss: 0.1256 | Pearson: 0.4186 | Best: 0.4801
# !!! Early Stopping triggered at epoch 131 !!!
#
# --- Starting 5-Fold Cross Validation: Fold 1 ---
# Fold 1 | Ep   1/10000 | LR: 0.001000 | Loss: 1.0571 | Pearson: 0.3911 | Best: 0.3911
# [Test] Fold 1 | Ep   1/10000 | Pearson: 0.3612 | Best: 0.3612
# Fold 1 | Ep   2/10000 | LR: 0.001000 | Loss: 0.8374 | Pearson: 0.4085 | Best: 0.4085
# [Test] Fold 1 | Ep   2/10000 | Pearson: 0.3613 | Best: 0.3613
# Fold 1 | Ep   3/10000 | LR: 0.000999 | Loss: 0.6942 | Pearson: 0.4771 | Best: 0.4771
# [Test] Fold 1 | Ep   3/10000 | Pearson: 0.3344 | Best: 0.3613
# Fold 1 | Ep   4/10000 | LR: 0.000999 | Loss: 0.6233 | Pearson: 0.4695 | Best: 0.4771
# [Test] Fold 1 | Ep   4/10000 | Pearson: 0.3189 | Best: 0.3613
# Fold 1 | Ep   5/10000 | LR: 0.000998 | Loss: 0.5868 | Pearson: 0.4364 | Best: 0.4771
# [Test] Fold 1 | Ep   5/10000 | Pearson: 0.3149 | Best: 0.3613
# Fold 1 | Ep   6/10000 | LR: 0.000998 | Loss: 0.5044 | Pearson: 0.4532 | Best: 0.4771
# [Test] Fold 1 | Ep   6/10000 | Pearson: 0.2971 | Best: 0.3613
# Fold 1 | Ep   7/10000 | LR: 0.000997 | Loss: 0.5108 | Pearson: 0.4437 | Best: 0.4771
# [Test] Fold 1 | Ep   7/10000 | Pearson: 0.3225 | Best: 0.3613
# Fold 1 | Ep   8/10000 | LR: 0.000996 | Loss: 0.4745 | Pearson: 0.4622 | Best: 0.4771
# [Test] Fold 1 | Ep   8/10000 | Pearson: 0.3271 | Best: 0.3613
# Fold 1 | Ep   9/10000 | LR: 0.000995 | Loss: 0.4598 | Pearson: 0.4330 | Best: 0.4771
# [Test] Fold 1 | Ep   9/10000 | Pearson: 0.3416 | Best: 0.3613
# Fold 1 | Ep  10/10000 | LR: 0.000994 | Loss: 0.4711 | Pearson: 0.4107 | Best: 0.4771
# [Test] Fold 1 | Ep  10/10000 | Pearson: 0.3325 | Best: 0.3613
# Fold 1 | Ep  11/10000 | LR: 0.000993 | Loss: 0.4676 | Pearson: 0.4606 | Best: 0.4771
# [Test] Fold 1 | Ep  11/10000 | Pearson: 0.3218 | Best: 0.3613
# Fold 1 | Ep  12/10000 | LR: 0.000991 | Loss: 0.4450 | Pearson: 0.4194 | Best: 0.4771
# [Test] Fold 1 | Ep  12/10000 | Pearson: 0.3094 | Best: 0.3613
# Fold 1 | Ep  13/10000 | LR: 0.000990 | Loss: 0.4517 | Pearson: 0.4450 | Best: 0.4771
# [Test] Fold 1 | Ep  13/10000 | Pearson: 0.3164 | Best: 0.3613
# Fold 1 | Ep  14/10000 | LR: 0.000988 | Loss: 0.4581 | Pearson: 0.4114 | Best: 0.4771
# [Test] Fold 1 | Ep  14/10000 | Pearson: 0.3203 | Best: 0.3613
# Fold 1 | Ep  15/10000 | LR: 0.000986 | Loss: 0.4286 | Pearson: 0.4540 | Best: 0.4771
# [Test] Fold 1 | Ep  15/10000 | Pearson: 0.3403 | Best: 0.3613
# Fold 1 | Ep  16/10000 | LR: 0.000984 | Loss: 0.4148 | Pearson: 0.4453 | Best: 0.4771
# [Test] Fold 1 | Ep  16/10000 | Pearson: 0.3366 | Best: 0.3613
# Fold 1 | Ep  17/10000 | LR: 0.000982 | Loss: 0.4307 | Pearson: 0.4156 | Best: 0.4771
# [Test] Fold 1 | Ep  17/10000 | Pearson: 0.3080 | Best: 0.3613
# Fold 1 | Ep  18/10000 | LR: 0.000980 | Loss: 0.4125 | Pearson: 0.4249 | Best: 0.4771
# [Test] Fold 1 | Ep  18/10000 | Pearson: 0.2992 | Best: 0.3613
# Fold 1 | Ep  19/10000 | LR: 0.000978 | Loss: 0.3942 | Pearson: 0.4106 | Best: 0.4771
# [Test] Fold 1 | Ep  19/10000 | Pearson: 0.3204 | Best: 0.3613
# Fold 1 | Ep  20/10000 | LR: 0.000976 | Loss: 0.3965 | Pearson: 0.4119 | Best: 0.4771
# [Test] Fold 1 | Ep  20/10000 | Pearson: 0.3232 | Best: 0.3613
# Fold 1 | Ep  21/10000 | LR: 0.000973 | Loss: 0.3816 | Pearson: 0.4324 | Best: 0.4771
# [Test] Fold 1 | Ep  21/10000 | Pearson: 0.3347 | Best: 0.3613
# Fold 1 | Ep  22/10000 | LR: 0.000970 | Loss: 0.4006 | Pearson: 0.4411 | Best: 0.4771
# [Test] Fold 1 | Ep  22/10000 | Pearson: 0.3088 | Best: 0.3613
# Fold 1 | Ep  23/10000 | LR: 0.000968 | Loss: 0.3935 | Pearson: 0.4276 | Best: 0.4771
# [Test] Fold 1 | Ep  23/10000 | Pearson: 0.3032 | Best: 0.3613
# Fold 1 | Ep  24/10000 | LR: 0.000965 | Loss: 0.3632 | Pearson: 0.4565 | Best: 0.4771
# [Test] Fold 1 | Ep  24/10000 | Pearson: 0.3268 | Best: 0.3613
# Fold 1 | Ep  25/10000 | LR: 0.000962 | Loss: 0.4034 | Pearson: 0.4305 | Best: 0.4771
# [Test] Fold 1 | Ep  25/10000 | Pearson: 0.3193 | Best: 0.3613
# Fold 1 | Ep  26/10000 | LR: 0.000959 | Loss: 0.3787 | Pearson: 0.4460 | Best: 0.4771
# [Test] Fold 1 | Ep  26/10000 | Pearson: 0.3148 | Best: 0.3613
# Fold 1 | Ep  27/10000 | LR: 0.000956 | Loss: 0.3903 | Pearson: 0.4365 | Best: 0.4771
# [Test] Fold 1 | Ep  27/10000 | Pearson: 0.3347 | Best: 0.3613
# Fold 1 | Ep  28/10000 | LR: 0.000952 | Loss: 0.3885 | Pearson: 0.4390 | Best: 0.4771
# [Test] Fold 1 | Ep  28/10000 | Pearson: 0.3405 | Best: 0.3613
# Fold 1 | Ep  29/10000 | LR: 0.000949 | Loss: 0.3709 | Pearson: 0.4240 | Best: 0.4771
# [Test] Fold 1 | Ep  29/10000 | Pearson: 0.3140 | Best: 0.3613
# Fold 1 | Ep  30/10000 | LR: 0.000946 | Loss: 0.3599 | Pearson: 0.4365 | Best: 0.4771
# [Test] Fold 1 | Ep  30/10000 | Pearson: 0.2955 | Best: 0.3613
# Fold 1 | Ep  31/10000 | LR: 0.000942 | Loss: 0.3496 | Pearson: 0.4298 | Best: 0.4771
# [Test] Fold 1 | Ep  31/10000 | Pearson: 0.3145 | Best: 0.3613
# Fold 1 | Ep  32/10000 | LR: 0.000938 | Loss: 0.3705 | Pearson: 0.4326 | Best: 0.4771
# [Test] Fold 1 | Ep  32/10000 | Pearson: 0.3262 | Best: 0.3613
# Fold 1 | Ep  33/10000 | LR: 0.000934 | Loss: 0.3888 | Pearson: 0.4259 | Best: 0.4771
# [Test] Fold 1 | Ep  33/10000 | Pearson: 0.3158 | Best: 0.3613
# Fold 1 | Ep  34/10000 | LR: 0.000930 | Loss: 0.3685 | Pearson: 0.4417 | Best: 0.4771
# [Test] Fold 1 | Ep  34/10000 | Pearson: 0.3407 | Best: 0.3613
# Fold 1 | Ep  35/10000 | LR: 0.000926 | Loss: 0.3653 | Pearson: 0.4395 | Best: 0.4771
# [Test] Fold 1 | Ep  35/10000 | Pearson: 0.3268 | Best: 0.3613
# Fold 1 | Ep  36/10000 | LR: 0.000922 | Loss: 0.3703 | Pearson: 0.4383 | Best: 0.4771
# [Test] Fold 1 | Ep  36/10000 | Pearson: 0.3271 | Best: 0.3613
# Fold 1 | Ep  37/10000 | LR: 0.000918 | Loss: 0.3735 | Pearson: 0.4374 | Best: 0.4771
# [Test] Fold 1 | Ep  37/10000 | Pearson: 0.2894 | Best: 0.3613
# Fold 1 | Ep  38/10000 | LR: 0.000914 | Loss: 0.3689 | Pearson: 0.4414 | Best: 0.4771
# [Test] Fold 1 | Ep  38/10000 | Pearson: 0.3229 | Best: 0.3613
# Fold 1 | Ep  39/10000 | LR: 0.000909 | Loss: 0.3211 | Pearson: 0.4301 | Best: 0.4771
# [Test] Fold 1 | Ep  39/10000 | Pearson: 0.3035 | Best: 0.3613
# Fold 1 | Ep  40/10000 | LR: 0.000905 | Loss: 0.3688 | Pearson: 0.4360 | Best: 0.4771
# [Test] Fold 1 | Ep  40/10000 | Pearson: 0.3134 | Best: 0.3613
# Fold 1 | Ep  41/10000 | LR: 0.000900 | Loss: 0.3403 | Pearson: 0.4239 | Best: 0.4771
# [Test] Fold 1 | Ep  41/10000 | Pearson: 0.3104 | Best: 0.3613
# Fold 1 | Ep  42/10000 | LR: 0.000895 | Loss: 0.3360 | Pearson: 0.4457 | Best: 0.4771
# [Test] Fold 1 | Ep  42/10000 | Pearson: 0.3107 | Best: 0.3613
# Fold 1 | Ep  43/10000 | LR: 0.000890 | Loss: 0.3532 | Pearson: 0.4151 | Best: 0.4771
# [Test] Fold 1 | Ep  43/10000 | Pearson: 0.3059 | Best: 0.3613
# Fold 1 | Ep  44/10000 | LR: 0.000885 | Loss: 0.3305 | Pearson: 0.4032 | Best: 0.4771
# [Test] Fold 1 | Ep  44/10000 | Pearson: 0.2818 | Best: 0.3613
# Fold 1 | Ep  45/10000 | LR: 0.000880 | Loss: 0.3170 | Pearson: 0.4235 | Best: 0.4771
# [Test] Fold 1 | Ep  45/10000 | Pearson: 0.3208 | Best: 0.3613
# Fold 1 | Ep  46/10000 | LR: 0.000875 | Loss: 0.3261 | Pearson: 0.4114 | Best: 0.4771
# [Test] Fold 1 | Ep  46/10000 | Pearson: 0.2967 | Best: 0.3613
# Fold 1 | Ep  47/10000 | LR: 0.000870 | Loss: 0.3445 | Pearson: 0.4174 | Best: 0.4771
# [Test] Fold 1 | Ep  47/10000 | Pearson: 0.3104 | Best: 0.3613
# Fold 1 | Ep  48/10000 | LR: 0.000865 | Loss: 0.3173 | Pearson: 0.4054 | Best: 0.4771
# [Test] Fold 1 | Ep  48/10000 | Pearson: 0.3237 | Best: 0.3613
# Fold 1 | Ep  49/10000 | LR: 0.000859 | Loss: 0.3156 | Pearson: 0.3984 | Best: 0.4771
# [Test] Fold 1 | Ep  49/10000 | Pearson: 0.2899 | Best: 0.3613
# Fold 1 | Ep  50/10000 | LR: 0.000854 | Loss: 0.3208 | Pearson: 0.4405 | Best: 0.4771
# [Test] Fold 1 | Ep  50/10000 | Pearson: 0.3041 | Best: 0.3613
# Fold 1 | Ep  51/10000 | LR: 0.000848 | Loss: 0.3132 | Pearson: 0.4192 | Best: 0.4771
# [Test] Fold 1 | Ep  51/10000 | Pearson: 0.3038 | Best: 0.3613
# Fold 1 | Ep  52/10000 | LR: 0.000842 | Loss: 0.3083 | Pearson: 0.4010 | Best: 0.4771
# [Test] Fold 1 | Ep  52/10000 | Pearson: 0.3218 | Best: 0.3613
# Fold 1 | Ep  53/10000 | LR: 0.000837 | Loss: 0.2981 | Pearson: 0.4039 | Best: 0.4771
# [Test] Fold 1 | Ep  53/10000 | Pearson: 0.3163 | Best: 0.3613
# Fold 1 | Ep  54/10000 | LR: 0.000831 | Loss: 0.3014 | Pearson: 0.3747 | Best: 0.4771
# [Test] Fold 1 | Ep  54/10000 | Pearson: 0.3069 | Best: 0.3613
# Fold 1 | Ep  55/10000 | LR: 0.000825 | Loss: 0.2895 | Pearson: 0.4077 | Best: 0.4771
# [Test] Fold 1 | Ep  55/10000 | Pearson: 0.3342 | Best: 0.3613
# Fold 1 | Ep  56/10000 | LR: 0.000819 | Loss: 0.2959 | Pearson: 0.3993 | Best: 0.4771
# [Test] Fold 1 | Ep  56/10000 | Pearson: 0.3149 | Best: 0.3613
# Fold 1 | Ep  57/10000 | LR: 0.000813 | Loss: 0.3184 | Pearson: 0.3955 | Best: 0.4771
# [Test] Fold 1 | Ep  57/10000 | Pearson: 0.3319 | Best: 0.3613
# Fold 1 | Ep  58/10000 | LR: 0.000807 | Loss: 0.2780 | Pearson: 0.4081 | Best: 0.4771
# [Test] Fold 1 | Ep  58/10000 | Pearson: 0.3205 | Best: 0.3613
# Fold 1 | Ep  59/10000 | LR: 0.000800 | Loss: 0.2574 | Pearson: 0.4246 | Best: 0.4771
# [Test] Fold 1 | Ep  59/10000 | Pearson: 0.3258 | Best: 0.3613
# Fold 1 | Ep  60/10000 | LR: 0.000794 | Loss: 0.2624 | Pearson: 0.4167 | Best: 0.4771
# [Test] Fold 1 | Ep  60/10000 | Pearson: 0.3297 | Best: 0.3613
# Fold 1 | Ep  61/10000 | LR: 0.000788 | Loss: 0.2818 | Pearson: 0.4206 | Best: 0.4771
# [Test] Fold 1 | Ep  61/10000 | Pearson: 0.3234 | Best: 0.3613
# Fold 1 | Ep  62/10000 | LR: 0.000781 | Loss: 0.2450 | Pearson: 0.3934 | Best: 0.4771
# [Test] Fold 1 | Ep  62/10000 | Pearson: 0.3177 | Best: 0.3613
# Fold 1 | Ep  63/10000 | LR: 0.000775 | Loss: 0.2615 | Pearson: 0.4086 | Best: 0.4771
# [Test] Fold 1 | Ep  63/10000 | Pearson: 0.3225 | Best: 0.3613
# Fold 1 | Ep  64/10000 | LR: 0.000768 | Loss: 0.2786 | Pearson: 0.4063 | Best: 0.4771
# [Test] Fold 1 | Ep  64/10000 | Pearson: 0.3143 | Best: 0.3613
# Fold 1 | Ep  65/10000 | LR: 0.000761 | Loss: 0.2612 | Pearson: 0.3847 | Best: 0.4771
# [Test] Fold 1 | Ep  65/10000 | Pearson: 0.3177 | Best: 0.3613
# Fold 1 | Ep  66/10000 | LR: 0.000755 | Loss: 0.2507 | Pearson: 0.3987 | Best: 0.4771
# [Test] Fold 1 | Ep  66/10000 | Pearson: 0.3379 | Best: 0.3613
# Fold 1 | Ep  67/10000 | LR: 0.000748 | Loss: 0.2511 | Pearson: 0.4196 | Best: 0.4771
# [Test] Fold 1 | Ep  67/10000 | Pearson: 0.3176 | Best: 0.3613
# Fold 1 | Ep  68/10000 | LR: 0.000741 | Loss: 0.2394 | Pearson: 0.3938 | Best: 0.4771
# [Test] Fold 1 | Ep  68/10000 | Pearson: 0.2859 | Best: 0.3613
# Fold 1 | Ep  69/10000 | LR: 0.000734 | Loss: 0.2552 | Pearson: 0.3974 | Best: 0.4771
# [Test] Fold 1 | Ep  69/10000 | Pearson: 0.3301 | Best: 0.3613
# Fold 1 | Ep  70/10000 | LR: 0.000727 | Loss: 0.2325 | Pearson: 0.3843 | Best: 0.4771
# [Test] Fold 1 | Ep  70/10000 | Pearson: 0.3213 | Best: 0.3613
# Fold 1 | Ep  71/10000 | LR: 0.000720 | Loss: 0.2074 | Pearson: 0.3942 | Best: 0.4771
# [Test] Fold 1 | Ep  71/10000 | Pearson: 0.3112 | Best: 0.3613
# Fold 1 | Ep  72/10000 | LR: 0.000713 | Loss: 0.2193 | Pearson: 0.3814 | Best: 0.4771
# [Test] Fold 1 | Ep  72/10000 | Pearson: 0.2883 | Best: 0.3613
# Fold 1 | Ep  73/10000 | LR: 0.000706 | Loss: 0.2284 | Pearson: 0.4074 | Best: 0.4771
# [Test] Fold 1 | Ep  73/10000 | Pearson: 0.3147 | Best: 0.3613
# Fold 1 | Ep  74/10000 | LR: 0.000699 | Loss: 0.2234 | Pearson: 0.3998 | Best: 0.4771
# [Test] Fold 1 | Ep  74/10000 | Pearson: 0.3074 | Best: 0.3613
# Fold 1 | Ep  75/10000 | LR: 0.000692 | Loss: 0.1964 | Pearson: 0.4098 | Best: 0.4771
# [Test] Fold 1 | Ep  75/10000 | Pearson: 0.3017 | Best: 0.3613
# Fold 1 | Ep  76/10000 | LR: 0.000684 | Loss: 0.2226 | Pearson: 0.3717 | Best: 0.4771
# [Test] Fold 1 | Ep  76/10000 | Pearson: 0.2833 | Best: 0.3613
# Fold 1 | Ep  77/10000 | LR: 0.000677 | Loss: 0.2111 | Pearson: 0.3781 | Best: 0.4771
# [Test] Fold 1 | Ep  77/10000 | Pearson: 0.3191 | Best: 0.3613
# Fold 1 | Ep  78/10000 | LR: 0.000670 | Loss: 0.2093 | Pearson: 0.3917 | Best: 0.4771
# [Test] Fold 1 | Ep  78/10000 | Pearson: 0.2998 | Best: 0.3613
# Fold 1 | Ep  79/10000 | LR: 0.000662 | Loss: 0.1922 | Pearson: 0.4099 | Best: 0.4771
# [Test] Fold 1 | Ep  79/10000 | Pearson: 0.3103 | Best: 0.3613
# Fold 1 | Ep  80/10000 | LR: 0.000655 | Loss: 0.1902 | Pearson: 0.3879 | Best: 0.4771
# [Test] Fold 1 | Ep  80/10000 | Pearson: 0.3224 | Best: 0.3613
# Fold 1 | Ep  81/10000 | LR: 0.000647 | Loss: 0.2053 | Pearson: 0.3850 | Best: 0.4771
# [Test] Fold 1 | Ep  81/10000 | Pearson: 0.2895 | Best: 0.3613
# Fold 1 | Ep  82/10000 | LR: 0.000640 | Loss: 0.1973 | Pearson: 0.3740 | Best: 0.4771
# [Test] Fold 1 | Ep  82/10000 | Pearson: 0.3061 | Best: 0.3613
# Fold 1 | Ep  83/10000 | LR: 0.000632 | Loss: 0.1730 | Pearson: 0.3941 | Best: 0.4771
# [Test] Fold 1 | Ep  83/10000 | Pearson: 0.2974 | Best: 0.3613
# Fold 1 | Ep  84/10000 | LR: 0.000625 | Loss: 0.1795 | Pearson: 0.3590 | Best: 0.4771
# [Test] Fold 1 | Ep  84/10000 | Pearson: 0.3200 | Best: 0.3613
# Fold 1 | Ep  85/10000 | LR: 0.000617 | Loss: 0.1831 | Pearson: 0.3984 | Best: 0.4771
# [Test] Fold 1 | Ep  85/10000 | Pearson: 0.3104 | Best: 0.3613
# Fold 1 | Ep  86/10000 | LR: 0.000609 | Loss: 0.1689 | Pearson: 0.3721 | Best: 0.4771
# [Test] Fold 1 | Ep  86/10000 | Pearson: 0.3077 | Best: 0.3613
# Fold 1 | Ep  87/10000 | LR: 0.000602 | Loss: 0.1837 | Pearson: 0.4028 | Best: 0.4771
# [Test] Fold 1 | Ep  87/10000 | Pearson: 0.2982 | Best: 0.3613
# Fold 1 | Ep  88/10000 | LR: 0.000594 | Loss: 0.1686 | Pearson: 0.3946 | Best: 0.4771
# [Test] Fold 1 | Ep  88/10000 | Pearson: 0.3057 | Best: 0.3613
# Fold 1 | Ep  89/10000 | LR: 0.000586 | Loss: 0.1745 | Pearson: 0.4003 | Best: 0.4771
# [Test] Fold 1 | Ep  89/10000 | Pearson: 0.3202 | Best: 0.3613
# Fold 1 | Ep  90/10000 | LR: 0.000579 | Loss: 0.1783 | Pearson: 0.3715 | Best: 0.4771
# [Test] Fold 1 | Ep  90/10000 | Pearson: 0.3042 | Best: 0.3613
# Fold 1 | Ep  91/10000 | LR: 0.000571 | Loss: 0.1713 | Pearson: 0.3961 | Best: 0.4771
# [Test] Fold 1 | Ep  91/10000 | Pearson: 0.3198 | Best: 0.3613
# Fold 1 | Ep  92/10000 | LR: 0.000563 | Loss: 0.1522 | Pearson: 0.3808 | Best: 0.4771
# [Test] Fold 1 | Ep  92/10000 | Pearson: 0.3011 | Best: 0.3613
# Fold 1 | Ep  93/10000 | LR: 0.000555 | Loss: 0.1703 | Pearson: 0.3796 | Best: 0.4771
# [Test] Fold 1 | Ep  93/10000 | Pearson: 0.3056 | Best: 0.3613
# Fold 1 | Ep  94/10000 | LR: 0.000548 | Loss: 0.1440 | Pearson: 0.3553 | Best: 0.4771
# [Test] Fold 1 | Ep  94/10000 | Pearson: 0.3113 | Best: 0.3613
# Fold 1 | Ep  95/10000 | LR: 0.000540 | Loss: 0.1638 | Pearson: 0.3722 | Best: 0.4771
# [Test] Fold 1 | Ep  95/10000 | Pearson: 0.3034 | Best: 0.3613
# Fold 1 | Ep  96/10000 | LR: 0.000532 | Loss: 0.1599 | Pearson: 0.3721 | Best: 0.4771
# [Test] Fold 1 | Ep  96/10000 | Pearson: 0.3092 | Best: 0.3613
# Fold 1 | Ep  97/10000 | LR: 0.000524 | Loss: 0.1516 | Pearson: 0.3555 | Best: 0.4771
# [Test] Fold 1 | Ep  97/10000 | Pearson: 0.2888 | Best: 0.3613
# Fold 1 | Ep  98/10000 | LR: 0.000516 | Loss: 0.1568 | Pearson: 0.3722 | Best: 0.4771
# [Test] Fold 1 | Ep  98/10000 | Pearson: 0.3073 | Best: 0.3613
# Fold 1 | Ep  99/10000 | LR: 0.000508 | Loss: 0.1518 | Pearson: 0.3580 | Best: 0.4771
# [Test] Fold 1 | Ep  99/10000 | Pearson: 0.3102 | Best: 0.3613
# Fold 1 | Ep 100/10000 | LR: 0.000501 | Loss: 0.1489 | Pearson: 0.3761 | Best: 0.4771
# [Test] Fold 1 | Ep 100/10000 | Pearson: 0.3006 | Best: 0.3613
# Fold 1 | Ep 101/10000 | LR: 0.000493 | Loss: 0.1463 | Pearson: 0.3775 | Best: 0.4771
# [Test] Fold 1 | Ep 101/10000 | Pearson: 0.3011 | Best: 0.3613
# Fold 1 | Ep 102/10000 | LR: 0.000485 | Loss: 0.1457 | Pearson: 0.3804 | Best: 0.4771
# [Test] Fold 1 | Ep 102/10000 | Pearson: 0.3131 | Best: 0.3613
# Fold 1 | Ep 103/10000 | LR: 0.000477 | Loss: 0.1495 | Pearson: 0.3540 | Best: 0.4771
# !!! Early Stopping triggered at epoch 103 !!!
#
# --- Starting 5-Fold Cross Validation: Fold 2 ---
# Fold 2 | Ep   1/10000 | LR: 0.001000 | Loss: 1.0320 | Pearson: 0.3282 | Best: 0.3282
# [Test] Fold 2 | Ep   1/10000 | Pearson: 0.2644 | Best: 0.2644
# Fold 2 | Ep   2/10000 | LR: 0.001000 | Loss: 0.8186 | Pearson: 0.3967 | Best: 0.3967
# [Test] Fold 2 | Ep   2/10000 | Pearson: 0.3010 | Best: 0.3010
# Fold 2 | Ep   3/10000 | LR: 0.000999 | Loss: 0.6961 | Pearson: 0.3999 | Best: 0.3999
# [Test] Fold 2 | Ep   3/10000 | Pearson: 0.3045 | Best: 0.3045
# Fold 2 | Ep   4/10000 | LR: 0.000999 | Loss: 0.6223 | Pearson: 0.3706 | Best: 0.3999
# [Test] Fold 2 | Ep   4/10000 | Pearson: 0.3089 | Best: 0.3089
# Fold 2 | Ep   5/10000 | LR: 0.000998 | Loss: 0.5549 | Pearson: 0.3716 | Best: 0.3999
# [Test] Fold 2 | Ep   5/10000 | Pearson: 0.3264 | Best: 0.3264
# Fold 2 | Ep   6/10000 | LR: 0.000998 | Loss: 0.5423 | Pearson: 0.4067 | Best: 0.4067
# [Test] Fold 2 | Ep   6/10000 | Pearson: 0.3348 | Best: 0.3348
# Fold 2 | Ep   7/10000 | LR: 0.000997 | Loss: 0.5272 | Pearson: 0.3975 | Best: 0.4067
# [Test] Fold 2 | Ep   7/10000 | Pearson: 0.3200 | Best: 0.3348
# Fold 2 | Ep   8/10000 | LR: 0.000996 | Loss: 0.6794 | Pearson: 0.3920 | Best: 0.4067
# [Test] Fold 2 | Ep   8/10000 | Pearson: 0.3293 | Best: 0.3348
# Fold 2 | Ep   9/10000 | LR: 0.000995 | Loss: 0.5552 | Pearson: 0.3786 | Best: 0.4067
# [Test] Fold 2 | Ep   9/10000 | Pearson: 0.3466 | Best: 0.3466
# Fold 2 | Ep  10/10000 | LR: 0.000994 | Loss: 0.4726 | Pearson: 0.3902 | Best: 0.4067
# [Test] Fold 2 | Ep  10/10000 | Pearson: 0.3216 | Best: 0.3466
# Fold 2 | Ep  11/10000 | LR: 0.000993 | Loss: 0.4700 | Pearson: 0.3709 | Best: 0.4067
# [Test] Fold 2 | Ep  11/10000 | Pearson: 0.2992 | Best: 0.3466
# Fold 2 | Ep  12/10000 | LR: 0.000991 | Loss: 0.5159 | Pearson: 0.3649 | Best: 0.4067
# [Test] Fold 2 | Ep  12/10000 | Pearson: 0.3106 | Best: 0.3466
# Fold 2 | Ep  13/10000 | LR: 0.000990 | Loss: 0.4431 | Pearson: 0.3889 | Best: 0.4067
# [Test] Fold 2 | Ep  13/10000 | Pearson: 0.3331 | Best: 0.3466
# Fold 2 | Ep  14/10000 | LR: 0.000988 | Loss: 0.4117 | Pearson: 0.3819 | Best: 0.4067
# [Test] Fold 2 | Ep  14/10000 | Pearson: 0.3322 | Best: 0.3466
# Fold 2 | Ep  15/10000 | LR: 0.000986 | Loss: 0.4178 | Pearson: 0.3732 | Best: 0.4067
# [Test] Fold 2 | Ep  15/10000 | Pearson: 0.3087 | Best: 0.3466
# Fold 2 | Ep  16/10000 | LR: 0.000984 | Loss: 0.4284 | Pearson: 0.3303 | Best: 0.4067
# [Test] Fold 2 | Ep  16/10000 | Pearson: 0.3065 | Best: 0.3466
# Fold 2 | Ep  17/10000 | LR: 0.000982 | Loss: 0.4094 | Pearson: 0.3678 | Best: 0.4067
# [Test] Fold 2 | Ep  17/10000 | Pearson: 0.3050 | Best: 0.3466
# Fold 2 | Ep  18/10000 | LR: 0.000980 | Loss: 0.3868 | Pearson: 0.3728 | Best: 0.4067
# [Test] Fold 2 | Ep  18/10000 | Pearson: 0.3180 | Best: 0.3466
# Fold 2 | Ep  19/10000 | LR: 0.000978 | Loss: 0.4273 | Pearson: 0.3738 | Best: 0.4067
# [Test] Fold 2 | Ep  19/10000 | Pearson: 0.2789 | Best: 0.3466
# Fold 2 | Ep  20/10000 | LR: 0.000976 | Loss: 0.4346 | Pearson: 0.4025 | Best: 0.4067
# [Test] Fold 2 | Ep  20/10000 | Pearson: 0.3056 | Best: 0.3466
# Fold 2 | Ep  21/10000 | LR: 0.000973 | Loss: 0.3846 | Pearson: 0.4311 | Best: 0.4311
# [Test] Fold 2 | Ep  21/10000 | Pearson: 0.3213 | Best: 0.3466
# Fold 2 | Ep  22/10000 | LR: 0.000970 | Loss: 0.3983 | Pearson: 0.3752 | Best: 0.4311
# [Test] Fold 2 | Ep  22/10000 | Pearson: 0.3168 | Best: 0.3466
# Fold 2 | Ep  23/10000 | LR: 0.000968 | Loss: 0.4016 | Pearson: 0.3840 | Best: 0.4311
# [Test] Fold 2 | Ep  23/10000 | Pearson: 0.2993 | Best: 0.3466
# Fold 2 | Ep  24/10000 | LR: 0.000965 | Loss: 0.3963 | Pearson: 0.3734 | Best: 0.4311
# [Test] Fold 2 | Ep  24/10000 | Pearson: 0.3096 | Best: 0.3466
# Fold 2 | Ep  25/10000 | LR: 0.000962 | Loss: 0.3915 | Pearson: 0.3478 | Best: 0.4311
# [Test] Fold 2 | Ep  25/10000 | Pearson: 0.3219 | Best: 0.3466
# Fold 2 | Ep  26/10000 | LR: 0.000959 | Loss: 0.3950 | Pearson: 0.3933 | Best: 0.4311
# [Test] Fold 2 | Ep  26/10000 | Pearson: 0.3295 | Best: 0.3466
# Fold 2 | Ep  27/10000 | LR: 0.000956 | Loss: 0.3747 | Pearson: 0.4125 | Best: 0.4311
# [Test] Fold 2 | Ep  27/10000 | Pearson: 0.3089 | Best: 0.3466
# Fold 2 | Ep  28/10000 | LR: 0.000952 | Loss: 0.4102 | Pearson: 0.3738 | Best: 0.4311
# [Test] Fold 2 | Ep  28/10000 | Pearson: 0.3070 | Best: 0.3466
# Fold 2 | Ep  29/10000 | LR: 0.000949 | Loss: 0.4009 | Pearson: 0.3778 | Best: 0.4311
# [Test] Fold 2 | Ep  29/10000 | Pearson: 0.2802 | Best: 0.3466
# Fold 2 | Ep  30/10000 | LR: 0.000946 | Loss: 0.3986 | Pearson: 0.3709 | Best: 0.4311
# [Test] Fold 2 | Ep  30/10000 | Pearson: 0.2867 | Best: 0.3466
# Fold 2 | Ep  31/10000 | LR: 0.000942 | Loss: 0.4025 | Pearson: 0.3912 | Best: 0.4311
# [Test] Fold 2 | Ep  31/10000 | Pearson: 0.3148 | Best: 0.3466
# Fold 2 | Ep  32/10000 | LR: 0.000938 | Loss: 0.3883 | Pearson: 0.3392 | Best: 0.4311
# [Test] Fold 2 | Ep  32/10000 | Pearson: 0.2916 | Best: 0.3466
# Fold 2 | Ep  33/10000 | LR: 0.000934 | Loss: 0.3795 | Pearson: 0.3695 | Best: 0.4311
# [Test] Fold 2 | Ep  33/10000 | Pearson: 0.2969 | Best: 0.3466
# Fold 2 | Ep  34/10000 | LR: 0.000930 | Loss: 0.3749 | Pearson: 0.3915 | Best: 0.4311
# [Test] Fold 2 | Ep  34/10000 | Pearson: 0.2961 | Best: 0.3466
# Fold 2 | Ep  35/10000 | LR: 0.000926 | Loss: 0.3675 | Pearson: 0.3841 | Best: 0.4311
# [Test] Fold 2 | Ep  35/10000 | Pearson: 0.2877 | Best: 0.3466
# Fold 2 | Ep  36/10000 | LR: 0.000922 | Loss: 0.3958 | Pearson: 0.3886 | Best: 0.4311
# [Test] Fold 2 | Ep  36/10000 | Pearson: 0.3055 | Best: 0.3466
# Fold 2 | Ep  37/10000 | LR: 0.000918 | Loss: 0.3822 | Pearson: 0.3987 | Best: 0.4311
# [Test] Fold 2 | Ep  37/10000 | Pearson: 0.3098 | Best: 0.3466
# Fold 2 | Ep  38/10000 | LR: 0.000914 | Loss: 0.3879 | Pearson: 0.3928 | Best: 0.4311
# [Test] Fold 2 | Ep  38/10000 | Pearson: 0.3262 | Best: 0.3466
# Fold 2 | Ep  39/10000 | LR: 0.000909 | Loss: 0.4169 | Pearson: 0.3697 | Best: 0.4311
# [Test] Fold 2 | Ep  39/10000 | Pearson: 0.3063 | Best: 0.3466
# Fold 2 | Ep  40/10000 | LR: 0.000905 | Loss: 0.3768 | Pearson: 0.3679 | Best: 0.4311
# [Test] Fold 2 | Ep  40/10000 | Pearson: 0.2929 | Best: 0.3466
# Fold 2 | Ep  41/10000 | LR: 0.000900 | Loss: 0.3875 | Pearson: 0.3700 | Best: 0.4311
# [Test] Fold 2 | Ep  41/10000 | Pearson: 0.3334 | Best: 0.3466
# Fold 2 | Ep  42/10000 | LR: 0.000895 | Loss: 0.3710 | Pearson: 0.3734 | Best: 0.4311
# [Test] Fold 2 | Ep  42/10000 | Pearson: 0.3099 | Best: 0.3466
# Fold 2 | Ep  43/10000 | LR: 0.000890 | Loss: 0.3772 | Pearson: 0.3622 | Best: 0.4311
# [Test] Fold 2 | Ep  43/10000 | Pearson: 0.2954 | Best: 0.3466
# Fold 2 | Ep  44/10000 | LR: 0.000885 | Loss: 0.3705 | Pearson: 0.3623 | Best: 0.4311
# [Test] Fold 2 | Ep  44/10000 | Pearson: 0.3246 | Best: 0.3466
# Fold 2 | Ep  45/10000 | LR: 0.000880 | Loss: 0.3501 | Pearson: 0.3560 | Best: 0.4311
# [Test] Fold 2 | Ep  45/10000 | Pearson: 0.3126 | Best: 0.3466
# Fold 2 | Ep  46/10000 | LR: 0.000875 | Loss: 0.3773 | Pearson: 0.3566 | Best: 0.4311
# [Test] Fold 2 | Ep  46/10000 | Pearson: 0.3526 | Best: 0.3526
# Fold 2 | Ep  47/10000 | LR: 0.000870 | Loss: 0.3359 | Pearson: 0.3598 | Best: 0.4311
# [Test] Fold 2 | Ep  47/10000 | Pearson: 0.3033 | Best: 0.3526
# Fold 2 | Ep  48/10000 | LR: 0.000865 | Loss: 0.3644 | Pearson: 0.3420 | Best: 0.4311
# [Test] Fold 2 | Ep  48/10000 | Pearson: 0.3075 | Best: 0.3526
# Fold 2 | Ep  49/10000 | LR: 0.000859 | Loss: 0.3889 | Pearson: 0.3510 | Best: 0.4311
# [Test] Fold 2 | Ep  49/10000 | Pearson: 0.3143 | Best: 0.3526
# Fold 2 | Ep  50/10000 | LR: 0.000854 | Loss: 0.3696 | Pearson: 0.3634 | Best: 0.4311
# [Test] Fold 2 | Ep  50/10000 | Pearson: 0.3044 | Best: 0.3526
# Fold 2 | Ep  51/10000 | LR: 0.000848 | Loss: 0.3668 | Pearson: 0.3405 | Best: 0.4311
# [Test] Fold 2 | Ep  51/10000 | Pearson: 0.2993 | Best: 0.3526
# Fold 2 | Ep  52/10000 | LR: 0.000842 | Loss: 0.3822 | Pearson: 0.3673 | Best: 0.4311
# [Test] Fold 2 | Ep  52/10000 | Pearson: 0.3113 | Best: 0.3526
# Fold 2 | Ep  53/10000 | LR: 0.000837 | Loss: 0.3507 | Pearson: 0.3740 | Best: 0.4311
# [Test] Fold 2 | Ep  53/10000 | Pearson: 0.3152 | Best: 0.3526
# Fold 2 | Ep  54/10000 | LR: 0.000831 | Loss: 0.3378 | Pearson: 0.3542 | Best: 0.4311
# [Test] Fold 2 | Ep  54/10000 | Pearson: 0.2927 | Best: 0.3526
# Fold 2 | Ep  55/10000 | LR: 0.000825 | Loss: 0.3306 | Pearson: 0.3854 | Best: 0.4311
# [Test] Fold 2 | Ep  55/10000 | Pearson: 0.3128 | Best: 0.3526
# Fold 2 | Ep  56/10000 | LR: 0.000819 | Loss: 0.3418 | Pearson: 0.3466 | Best: 0.4311
# [Test] Fold 2 | Ep  56/10000 | Pearson: 0.3015 | Best: 0.3526
# Fold 2 | Ep  57/10000 | LR: 0.000813 | Loss: 0.3607 | Pearson: 0.3655 | Best: 0.4311
# [Test] Fold 2 | Ep  57/10000 | Pearson: 0.3035 | Best: 0.3526
# Fold 2 | Ep  58/10000 | LR: 0.000807 | Loss: 0.3713 | Pearson: 0.3765 | Best: 0.4311
# [Test] Fold 2 | Ep  58/10000 | Pearson: 0.3005 | Best: 0.3526
# Fold 2 | Ep  59/10000 | LR: 0.000800 | Loss: 0.3618 | Pearson: 0.3985 | Best: 0.4311
# [Test] Fold 2 | Ep  59/10000 | Pearson: 0.3023 | Best: 0.3526
# Fold 2 | Ep  60/10000 | LR: 0.000794 | Loss: 0.3355 | Pearson: 0.3637 | Best: 0.4311
# [Test] Fold 2 | Ep  60/10000 | Pearson: 0.2971 | Best: 0.3526
# Fold 2 | Ep  61/10000 | LR: 0.000788 | Loss: 0.3008 | Pearson: 0.3690 | Best: 0.4311
# [Test] Fold 2 | Ep  61/10000 | Pearson: 0.2771 | Best: 0.3526
# Fold 2 | Ep  62/10000 | LR: 0.000781 | Loss: 0.3656 | Pearson: 0.3759 | Best: 0.4311
# [Test] Fold 2 | Ep  62/10000 | Pearson: 0.2810 | Best: 0.3526
# Fold 2 | Ep  63/10000 | LR: 0.000775 | Loss: 0.3340 | Pearson: 0.3839 | Best: 0.4311
# [Test] Fold 2 | Ep  63/10000 | Pearson: 0.3000 | Best: 0.3526
# Fold 2 | Ep  64/10000 | LR: 0.000768 | Loss: 0.3441 | Pearson: 0.3716 | Best: 0.4311
# [Test] Fold 2 | Ep  64/10000 | Pearson: 0.2883 | Best: 0.3526
# Fold 2 | Ep  65/10000 | LR: 0.000761 | Loss: 0.3399 | Pearson: 0.3618 | Best: 0.4311
# [Test] Fold 2 | Ep  65/10000 | Pearson: 0.3108 | Best: 0.3526
# Fold 2 | Ep  66/10000 | LR: 0.000755 | Loss: 0.3277 | Pearson: 0.3800 | Best: 0.4311
# [Test] Fold 2 | Ep  66/10000 | Pearson: 0.3135 | Best: 0.3526
# Fold 2 | Ep  67/10000 | LR: 0.000748 | Loss: 0.3132 | Pearson: 0.3519 | Best: 0.4311
# [Test] Fold 2 | Ep  67/10000 | Pearson: 0.2985 | Best: 0.3526
# Fold 2 | Ep  68/10000 | LR: 0.000741 | Loss: 0.5063 | Pearson: 0.2674 | Best: 0.4311
# [Test] Fold 2 | Ep  68/10000 | Pearson: 0.3117 | Best: 0.3526
# Fold 2 | Ep  69/10000 | LR: 0.000734 | Loss: 0.3858 | Pearson: 0.2781 | Best: 0.4311
# [Test] Fold 2 | Ep  69/10000 | Pearson: 0.2964 | Best: 0.3526
# Fold 2 | Ep  70/10000 | LR: 0.000727 | Loss: 0.3544 | Pearson: 0.3019 | Best: 0.4311
# [Test] Fold 2 | Ep  70/10000 | Pearson: 0.3193 | Best: 0.3526
# Fold 2 | Ep  71/10000 | LR: 0.000720 | Loss: 0.3276 | Pearson: 0.3058 | Best: 0.4311
# [Test] Fold 2 | Ep  71/10000 | Pearson: 0.3135 | Best: 0.3526
# Fold 2 | Ep  72/10000 | LR: 0.000713 | Loss: 0.3020 | Pearson: 0.3153 | Best: 0.4311
# [Test] Fold 2 | Ep  72/10000 | Pearson: 0.3217 | Best: 0.3526
# Fold 2 | Ep  73/10000 | LR: 0.000706 | Loss: 0.2977 | Pearson: 0.3176 | Best: 0.4311
# [Test] Fold 2 | Ep  73/10000 | Pearson: 0.3179 | Best: 0.3526
# Fold 2 | Ep  74/10000 | LR: 0.000699 | Loss: 0.3475 | Pearson: 0.3124 | Best: 0.4311
# [Test] Fold 2 | Ep  74/10000 | Pearson: 0.3047 | Best: 0.3526
# Fold 2 | Ep  75/10000 | LR: 0.000692 | Loss: 0.3277 | Pearson: 0.3265 | Best: 0.4311
# [Test] Fold 2 | Ep  75/10000 | Pearson: 0.2940 | Best: 0.3526
# Fold 2 | Ep  76/10000 | LR: 0.000684 | Loss: 0.3304 | Pearson: 0.3276 | Best: 0.4311
# [Test] Fold 2 | Ep  76/10000 | Pearson: 0.3110 | Best: 0.3526
# Fold 2 | Ep  77/10000 | LR: 0.000677 | Loss: 0.2930 | Pearson: 0.3434 | Best: 0.4311
# [Test] Fold 2 | Ep  77/10000 | Pearson: 0.3148 | Best: 0.3526
# Fold 2 | Ep  78/10000 | LR: 0.000670 | Loss: 0.2888 | Pearson: 0.3351 | Best: 0.4311
# [Test] Fold 2 | Ep  78/10000 | Pearson: 0.3134 | Best: 0.3526
# Fold 2 | Ep  79/10000 | LR: 0.000662 | Loss: 0.2882 | Pearson: 0.3342 | Best: 0.4311
# [Test] Fold 2 | Ep  79/10000 | Pearson: 0.3100 | Best: 0.3526
# Fold 2 | Ep  80/10000 | LR: 0.000655 | Loss: 0.2984 | Pearson: 0.3332 | Best: 0.4311
# [Test] Fold 2 | Ep  80/10000 | Pearson: 0.3018 | Best: 0.3526
# Fold 2 | Ep  81/10000 | LR: 0.000647 | Loss: 0.2960 | Pearson: 0.3425 | Best: 0.4311
# [Test] Fold 2 | Ep  81/10000 | Pearson: 0.3067 | Best: 0.3526
# Fold 2 | Ep  82/10000 | LR: 0.000640 | Loss: 0.2756 | Pearson: 0.3486 | Best: 0.4311
# [Test] Fold 2 | Ep  82/10000 | Pearson: 0.2953 | Best: 0.3526
# Fold 2 | Ep  83/10000 | LR: 0.000632 | Loss: 0.2700 | Pearson: 0.3514 | Best: 0.4311
# [Test] Fold 2 | Ep  83/10000 | Pearson: 0.3023 | Best: 0.3526
# Fold 2 | Ep  84/10000 | LR: 0.000625 | Loss: 0.2834 | Pearson: 0.3570 | Best: 0.4311
# [Test] Fold 2 | Ep  84/10000 | Pearson: 0.3011 | Best: 0.3526
# Fold 2 | Ep  85/10000 | LR: 0.000617 | Loss: 0.2992 | Pearson: 0.3534 | Best: 0.4311
# [Test] Fold 2 | Ep  85/10000 | Pearson: 0.2915 | Best: 0.3526
# Fold 2 | Ep  86/10000 | LR: 0.000609 | Loss: 0.2759 | Pearson: 0.3576 | Best: 0.4311
# [Test] Fold 2 | Ep  86/10000 | Pearson: 0.2879 | Best: 0.3526
# Fold 2 | Ep  87/10000 | LR: 0.000602 | Loss: 0.2717 | Pearson: 0.3478 | Best: 0.4311
# [Test] Fold 2 | Ep  87/10000 | Pearson: 0.2808 | Best: 0.3526
# Fold 2 | Ep  88/10000 | LR: 0.000594 | Loss: 0.4307 | Pearson: 0.3517 | Best: 0.4311
# [Test] Fold 2 | Ep  88/10000 | Pearson: 0.2761 | Best: 0.3526
# Fold 2 | Ep  89/10000 | LR: 0.000586 | Loss: 0.3209 | Pearson: 0.3306 | Best: 0.4311
# [Test] Fold 2 | Ep  89/10000 | Pearson: 0.2843 | Best: 0.3526
# Fold 2 | Ep  90/10000 | LR: 0.000579 | Loss: 0.2928 | Pearson: 0.3352 | Best: 0.4311
# [Test] Fold 2 | Ep  90/10000 | Pearson: 0.2788 | Best: 0.3526
# Fold 2 | Ep  91/10000 | LR: 0.000571 | Loss: 0.2807 | Pearson: 0.3447 | Best: 0.4311
# [Test] Fold 2 | Ep  91/10000 | Pearson: 0.2691 | Best: 0.3526
# Fold 2 | Ep  92/10000 | LR: 0.000563 | Loss: 0.2618 | Pearson: 0.3318 | Best: 0.4311
# ...
# Fold 4 | Ep   9/10000 | LR: 0.000995 | Loss: 0.4762 | Pearson: 0.4014 | Best: 0.4537
# [Test] Fold 4 | Ep   9/10000 | Pearson: 0.3337 | Best: 0.3666
# Fold 4 | Ep  10/10000 | LR: 0.000994 | Loss: 0.4671 | Pearson: 0.3680 | Best: 0.4537
# [Test] Fold 4 | Ep  10/10000 | Pearson: 0.3178 | Best: 0.3666
# Fold 4 | Ep  11/10000 | LR: 0.000993 | Loss: 0.4451 | Pearson: 0.3872 | Best: 0.4537
# [Test] Fold 4 | Ep  11/10000 | Pearson: 0.3210 | Best: 0.3666
# Fold 4 | Ep  12/10000 | LR: 0.000991 | Loss: 0.4745 | Pearson: 0.3492 | Best: 0.4537
# [Test] Fold 4 | Ep  12/10000 | Pearson: 0.2812 | Best: 0.3666
# Fold 4 | Ep  13/10000 | LR: 0.000990 | Loss: 0.4419 | Pearson: 0.4260 | Best: 0.4537
# [Test] Fold 4 | Ep  13/10000 | Pearson: 0.3246 | Best: 0.3666
# Fold 4 | Ep  14/10000 | LR: 0.000988 | Loss: 0.4520 | Pearson: 0.3638 | Best: 0.4537
# [Test] Fold 4 | Ep  14/10000 | Pearson: 0.2856 | Best: 0.3666
# Fold 4 | Ep  15/10000 | LR: 0.000986 | Loss: 0.4138 | Pearson: 0.4100 | Best: 0.4537
# [Test] Fold 4 | Ep  15/10000 | Pearson: 0.2871 | Best: 0.3666
# Fold 4 | Ep  16/10000 | LR: 0.000984 | Loss: 0.4158 | Pearson: 0.4560 | Best: 0.4560
# [Test] Fold 4 | Ep  16/10000 | Pearson: 0.2996 | Best: 0.3666
# Fold 4 | Ep  17/10000 | LR: 0.000982 | Loss: 0.4041 | Pearson: 0.4135 | Best: 0.4560
# [Test] Fold 4 | Ep  17/10000 | Pearson: 0.3027 | Best: 0.3666
# Fold 4 | Ep  18/10000 | LR: 0.000980 | Loss: 0.4300 | Pearson: 0.3896 | Best: 0.4560
# [Test] Fold 4 | Ep  18/10000 | Pearson: 0.3174 | Best: 0.3666
# Fold 4 | Ep  19/10000 | LR: 0.000978 | Loss: 0.4217 | Pearson: 0.3807 | Best: 0.4560
# [Test] Fold 4 | Ep  19/10000 | Pearson: 0.3201 | Best: 0.3666
# Fold 4 | Ep  20/10000 | LR: 0.000976 | Loss: 0.4323 | Pearson: 0.4126 | Best: 0.4560
# [Test] Fold 4 | Ep  20/10000 | Pearson: 0.2881 | Best: 0.3666
# Fold 4 | Ep  21/10000 | LR: 0.000973 | Loss: 0.4201 | Pearson: 0.3957 | Best: 0.4560
# [Test] Fold 4 | Ep  21/10000 | Pearson: 0.3100 | Best: 0.3666
# Fold 4 | Ep  22/10000 | LR: 0.000970 | Loss: 0.4060 | Pearson: 0.4253 | Best: 0.4560
# [Test] Fold 4 | Ep  22/10000 | Pearson: 0.2987 | Best: 0.3666
# Fold 4 | Ep  23/10000 | LR: 0.000968 | Loss: 0.4087 | Pearson: 0.3646 | Best: 0.4560
# [Test] Fold 4 | Ep  23/10000 | Pearson: 0.2763 | Best: 0.3666
# Fold 4 | Ep  24/10000 | LR: 0.000965 | Loss: 0.3856 | Pearson: 0.3827 | Best: 0.4560
# [Test] Fold 4 | Ep  24/10000 | Pearson: 0.2701 | Best: 0.3666
# Fold 4 | Ep  25/10000 | LR: 0.000962 | Loss: 0.4023 | Pearson: 0.3864 | Best: 0.4560
# [Test] Fold 4 | Ep  25/10000 | Pearson: 0.2709 | Best: 0.3666
# Fold 4 | Ep  26/10000 | LR: 0.000959 | Loss: 0.4107 | Pearson: 0.3930 | Best: 0.4560
# [Test] Fold 4 | Ep  26/10000 | Pearson: 0.2604 | Best: 0.3666
# Fold 4 | Ep  27/10000 | LR: 0.000956 | Loss: 0.3784 | Pearson: 0.4030 | Best: 0.4560
# [Test] Fold 4 | Ep  27/10000 | Pearson: 0.2625 | Best: 0.3666
# Fold 4 | Ep  28/10000 | LR: 0.000952 | Loss: 0.3790 | Pearson: 0.3592 | Best: 0.4560
# [Test] Fold 4 | Ep  28/10000 | Pearson: 0.2646 | Best: 0.3666
# Fold 4 | Ep  29/10000 | LR: 0.000949 | Loss: 0.3835 | Pearson: 0.3603 | Best: 0.4560
# [Test] Fold 4 | Ep  29/10000 | Pearson: 0.2857 | Best: 0.3666
# Fold 4 | Ep  30/10000 | LR: 0.000946 | Loss: 0.3839 | Pearson: 0.3633 | Best: 0.4560
# [Test] Fold 4 | Ep  30/10000 | Pearson: 0.2848 | Best: 0.3666
# Fold 4 | Ep  31/10000 | LR: 0.000942 | Loss: 0.3613 | Pearson: 0.3542 | Best: 0.4560
# [Test] Fold 4 | Ep  31/10000 | Pearson: 0.2853 | Best: 0.3666
# Fold 4 | Ep  32/10000 | LR: 0.000938 | Loss: 0.3761 | Pearson: 0.3815 | Best: 0.4560
# [Test] Fold 4 | Ep  32/10000 | Pearson: 0.2818 | Best: 0.3666
# Fold 4 | Ep  33/10000 | LR: 0.000934 | Loss: 0.3492 | Pearson: 0.3368 | Best: 0.4560
# [Test] Fold 4 | Ep  33/10000 | Pearson: 0.2454 | Best: 0.3666
# Fold 4 | Ep  34/10000 | LR: 0.000930 | Loss: 0.3713 | Pearson: 0.3830 | Best: 0.4560
# [Test] Fold 4 | Ep  34/10000 | Pearson: 0.2663 | Best: 0.3666
# Fold 4 | Ep  35/10000 | LR: 0.000926 | Loss: 0.3558 | Pearson: 0.4124 | Best: 0.4560
# [Test] Fold 4 | Ep  35/10000 | Pearson: 0.2630 | Best: 0.3666
# Fold 4 | Ep  36/10000 | LR: 0.000922 | Loss: 0.3625 | Pearson: 0.3698 | Best: 0.4560
# [Test] Fold 4 | Ep  36/10000 | Pearson: 0.2559 | Best: 0.3666
# Fold 4 | Ep  37/10000 | LR: 0.000918 | Loss: 0.3559 | Pearson: 0.3385 | Best: 0.4560
# [Test] Fold 4 | Ep  37/10000 | Pearson: 0.2486 | Best: 0.3666
# Fold 4 | Ep  38/10000 | LR: 0.000914 | Loss: 0.3458 | Pearson: 0.3221 | Best: 0.4560
# [Test] Fold 4 | Ep  38/10000 | Pearson: 0.2614 | Best: 0.3666
# Fold 4 | Ep  39/10000 | LR: 0.000909 | Loss: 0.3625 | Pearson: 0.2951 | Best: 0.4560
# [Test] Fold 4 | Ep  39/10000 | Pearson: 0.2438 | Best: 0.3666
# Fold 4 | Ep  40/10000 | LR: 0.000905 | Loss: 0.3537 | Pearson: 0.3625 | Best: 0.4560
# [Test] Fold 4 | Ep  40/10000 | Pearson: 0.2405 | Best: 0.3666
# Fold 4 | Ep  41/10000 | LR: 0.000900 | Loss: 0.3475 | Pearson: 0.3844 | Best: 0.4560
# [Test] Fold 4 | Ep  41/10000 | Pearson: 0.2820 | Best: 0.3666
# Fold 4 | Ep  42/10000 | LR: 0.000895 | Loss: 0.3662 | Pearson: 0.3422 | Best: 0.4560
# [Test] Fold 4 | Ep  42/10000 | Pearson: 0.2641 | Best: 0.3666
# Fold 4 | Ep  43/10000 | LR: 0.000890 | Loss: 0.3443 | Pearson: 0.3306 | Best: 0.4560
# [Test] Fold 4 | Ep  43/10000 | Pearson: 0.2465 | Best: 0.3666
# Fold 4 | Ep  44/10000 | LR: 0.000885 | Loss: 0.3174 | Pearson: 0.3902 | Best: 0.4560
# [Test] Fold 4 | Ep  44/10000 | Pearson: 0.2648 | Best: 0.3666
# Fold 4 | Ep  45/10000 | LR: 0.000880 | Loss: 0.3288 | Pearson: 0.3701 | Best: 0.4560
# [Test] Fold 4 | Ep  45/10000 | Pearson: 0.2680 | Best: 0.3666
# Fold 4 | Ep  46/10000 | LR: 0.000875 | Loss: 0.3184 | Pearson: 0.3404 | Best: 0.4560
# [Test] Fold 4 | Ep  46/10000 | Pearson: 0.2657 | Best: 0.3666
# Fold 4 | Ep  47/10000 | LR: 0.000870 | Loss: 0.3428 | Pearson: 0.3574 | Best: 0.4560
# [Test] Fold 4 | Ep  47/10000 | Pearson: 0.2793 | Best: 0.3666
# Fold 4 | Ep  48/10000 | LR: 0.000865 | Loss: 0.3138 | Pearson: 0.3436 | Best: 0.4560
# [Test] Fold 4 | Ep  48/10000 | Pearson: 0.2486 | Best: 0.3666
# Fold 4 | Ep  49/10000 | LR: 0.000859 | Loss: 0.3025 | Pearson: 0.3901 | Best: 0.4560
# [Test] Fold 4 | Ep  49/10000 | Pearson: 0.2604 | Best: 0.3666
# Fold 4 | Ep  50/10000 | LR: 0.000854 | Loss: 0.3049 | Pearson: 0.3750 | Best: 0.4560
# [Test] Fold 4 | Ep  50/10000 | Pearson: 0.2610 | Best: 0.3666
# Fold 4 | Ep  51/10000 | LR: 0.000848 | Loss: 0.3029 | Pearson: 0.4102 | Best: 0.4560
# [Test] Fold 4 | Ep  51/10000 | Pearson: 0.2396 | Best: 0.3666
# Fold 4 | Ep  52/10000 | LR: 0.000842 | Loss: 0.3109 | Pearson: 0.4259 | Best: 0.4560
# [Test] Fold 4 | Ep  52/10000 | Pearson: 0.2284 | Best: 0.3666
# Fold 4 | Ep  53/10000 | LR: 0.000837 | Loss: 0.2887 | Pearson: 0.3852 | Best: 0.4560
# [Test] Fold 4 | Ep  53/10000 | Pearson: 0.2200 | Best: 0.3666
# Fold 4 | Ep  54/10000 | LR: 0.000831 | Loss: 0.3010 | Pearson: 0.3121 | Best: 0.4560
# [Test] Fold 4 | Ep  54/10000 | Pearson: 0.2786 | Best: 0.3666
# Fold 4 | Ep  55/10000 | LR: 0.000825 | Loss: 0.3057 | Pearson: 0.3158 | Best: 0.4560
# [Test] Fold 4 | Ep  55/10000 | Pearson: 0.2855 | Best: 0.3666
# Fold 4 | Ep  56/10000 | LR: 0.000819 | Loss: 0.2868 | Pearson: 0.3262 | Best: 0.4560
# [Test] Fold 4 | Ep  56/10000 | Pearson: 0.2424 | Best: 0.3666
# Fold 4 | Ep  57/10000 | LR: 0.000813 | Loss: 0.2835 | Pearson: 0.3469 | Best: 0.4560
# [Test] Fold 4 | Ep  57/10000 | Pearson: 0.2639 | Best: 0.3666
# Fold 4 | Ep  58/10000 | LR: 0.000807 | Loss: 0.2835 | Pearson: 0.3877 | Best: 0.4560
# [Test] Fold 4 | Ep  58/10000 | Pearson: 0.2502 | Best: 0.3666
# Fold 4 | Ep  59/10000 | LR: 0.000800 | Loss: 0.2808 | Pearson: 0.4197 | Best: 0.4560
# [Test] Fold 4 | Ep  59/10000 | Pearson: 0.2560 | Best: 0.3666
# Fold 4 | Ep  60/10000 | LR: 0.000794 | Loss: 0.2451 | Pearson: 0.4225 | Best: 0.4560
# [Test] Fold 4 | Ep  60/10000 | Pearson: 0.2740 | Best: 0.3666
# Fold 4 | Ep  61/10000 | LR: 0.000788 | Loss: 0.2502 | Pearson: 0.3853 | Best: 0.4560
# [Test] Fold 4 | Ep  61/10000 | Pearson: 0.2721 | Best: 0.3666
# Fold 4 | Ep  62/10000 | LR: 0.000781 | Loss: 0.2413 | Pearson: 0.3544 | Best: 0.4560
# [Test] Fold 4 | Ep  62/10000 | Pearson: 0.2379 | Best: 0.3666
# Fold 4 | Ep  63/10000 | LR: 0.000775 | Loss: 0.2579 | Pearson: 0.3045 | Best: 0.4560
# [Test] Fold 4 | Ep  63/10000 | Pearson: 0.2326 | Best: 0.3666
# Fold 4 | Ep  64/10000 | LR: 0.000768 | Loss: 0.2398 | Pearson: 0.3817 | Best: 0.4560
# [Test] Fold 4 | Ep  64/10000 | Pearson: 0.2420 | Best: 0.3666
# Fold 4 | Ep  65/10000 | LR: 0.000761 | Loss: 0.2455 | Pearson: 0.4149 | Best: 0.4560
# [Test] Fold 4 | Ep  65/10000 | Pearson: 0.2713 | Best: 0.3666
# Fold 4 | Ep  66/10000 | LR: 0.000755 | Loss: 0.2318 | Pearson: 0.3561 | Best: 0.4560
# [Test] Fold 4 | Ep  66/10000 | Pearson: 0.2363 | Best: 0.3666
# Fold 4 | Ep  67/10000 | LR: 0.000748 | Loss: 0.2300 | Pearson: 0.3627 | Best: 0.4560
# [Test] Fold 4 | Ep  67/10000 | Pearson: 0.2213 | Best: 0.3666
# Fold 4 | Ep  68/10000 | LR: 0.000741 | Loss: 0.2182 | Pearson: 0.3625 | Best: 0.4560
# [Test] Fold 4 | Ep  68/10000 | Pearson: 0.2693 | Best: 0.3666
# Fold 4 | Ep  69/10000 | LR: 0.000734 | Loss: 0.2179 | Pearson: 0.3588 | Best: 0.4560
# [Test] Fold 4 | Ep  69/10000 | Pearson: 0.2432 | Best: 0.3666
# Fold 4 | Ep  70/10000 | LR: 0.000727 | Loss: 0.2241 | Pearson: 0.3181 | Best: 0.4560
# [Test] Fold 4 | Ep  70/10000 | Pearson: 0.2135 | Best: 0.3666
# Fold 4 | Ep  71/10000 | LR: 0.000720 | Loss: 0.2171 | Pearson: 0.3796 | Best: 0.4560
# [Test] Fold 4 | Ep  71/10000 | Pearson: 0.2216 | Best: 0.3666
# Fold 4 | Ep  72/10000 | LR: 0.000713 | Loss: 0.2267 | Pearson: 0.3609 | Best: 0.4560
# [Test] Fold 4 | Ep  72/10000 | Pearson: 0.2397 | Best: 0.3666
# Fold 4 | Ep  73/10000 | LR: 0.000706 | Loss: 0.2110 | Pearson: 0.3168 | Best: 0.4560
# [Test] Fold 4 | Ep  73/10000 | Pearson: 0.2106 | Best: 0.3666
# Fold 4 | Ep  74/10000 | LR: 0.000699 | Loss: 0.2064 | Pearson: 0.3152 | Best: 0.4560
# [Test] Fold 4 | Ep  74/10000 | Pearson: 0.2349 | Best: 0.3666
# Fold 4 | Ep  75/10000 | LR: 0.000692 | Loss: 0.2143 | Pearson: 0.3487 | Best: 0.4560
# [Test] Fold 4 | Ep  75/10000 | Pearson: 0.2176 | Best: 0.3666
# Fold 4 | Ep  76/10000 | LR: 0.000684 | Loss: 0.1955 | Pearson: 0.3682 | Best: 0.4560
# [Test] Fold 4 | Ep  76/10000 | Pearson: 0.2323 | Best: 0.3666
# Fold 4 | Ep  77/10000 | LR: 0.000677 | Loss: 0.2037 | Pearson: 0.3681 | Best: 0.4560
# [Test] Fold 4 | Ep  77/10000 | Pearson: 0.2227 | Best: 0.3666
# Fold 4 | Ep  78/10000 | LR: 0.000670 | Loss: 0.1780 | Pearson: 0.3642 | Best: 0.4560
# [Test] Fold 4 | Ep  78/10000 | Pearson: 0.2286 | Best: 0.3666
# Fold 4 | Ep  79/10000 | LR: 0.000662 | Loss: 0.1798 | Pearson: 0.3516 | Best: 0.4560
# [Test] Fold 4 | Ep  79/10000 | Pearson: 0.2278 | Best: 0.3666
# Fold 4 | Ep  80/10000 | LR: 0.000655 | Loss: 0.1860 | Pearson: 0.3787 | Best: 0.4560
# [Test] Fold 4 | Ep  80/10000 | Pearson: 0.2413 | Best: 0.3666
# Fold 4 | Ep  81/10000 | LR: 0.000647 | Loss: 0.1793 | Pearson: 0.4052 | Best: 0.4560
# [Test] Fold 4 | Ep  81/10000 | Pearson: 0.2411 | Best: 0.3666
# Fold 4 | Ep  82/10000 | LR: 0.000640 | Loss: 0.1837 | Pearson: 0.3647 | Best: 0.4560
# [Test] Fold 4 | Ep  82/10000 | Pearson: 0.2232 | Best: 0.3666
# Fold 4 | Ep  83/10000 | LR: 0.000632 | Loss: 0.1763 | Pearson: 0.3468 | Best: 0.4560
# [Test] Fold 4 | Ep  83/10000 | Pearson: 0.2423 | Best: 0.3666
# Fold 4 | Ep  84/10000 | LR: 0.000625 | Loss: 0.1919 | Pearson: 0.3307 | Best: 0.4560
# [Test] Fold 4 | Ep  84/10000 | Pearson: 0.2309 | Best: 0.3666
# Fold 4 | Ep  85/10000 | LR: 0.000617 | Loss: 0.1861 | Pearson: 0.3545 | Best: 0.4560
# [Test] Fold 4 | Ep  85/10000 | Pearson: 0.2311 | Best: 0.3666
# Fold 4 | Ep  86/10000 | LR: 0.000609 | Loss: 0.1759 | Pearson: 0.3523 | Best: 0.4560
# [Test] Fold 4 | Ep  86/10000 | Pearson: 0.2189 | Best: 0.3666
# Fold 4 | Ep  87/10000 | LR: 0.000602 | Loss: 0.1686 | Pearson: 0.3184 | Best: 0.4560
# [Test] Fold 4 | Ep  87/10000 | Pearson: 0.2301 | Best: 0.3666
# Fold 4 | Ep  88/10000 | LR: 0.000594 | Loss: 0.1777 | Pearson: 0.3496 | Best: 0.4560
# [Test] Fold 4 | Ep  88/10000 | Pearson: 0.2111 | Best: 0.3666
# Fold 4 | Ep  89/10000 | LR: 0.000586 | Loss: 0.1757 | Pearson: 0.3367 | Best: 0.4560
# [Test] Fold 4 | Ep  89/10000 | Pearson: 0.2043 | Best: 0.3666
# Fold 4 | Ep  90/10000 | LR: 0.000579 | Loss: 0.1822 | Pearson: 0.3509 | Best: 0.4560
# [Test] Fold 4 | Ep  90/10000 | Pearson: 0.2467 | Best: 0.3666
# Fold 4 | Ep  91/10000 | LR: 0.000571 | Loss: 0.1612 | Pearson: 0.3254 | Best: 0.4560
# [Test] Fold 4 | Ep  91/10000 | Pearson: 0.2326 | Best: 0.3666
# Fold 4 | Ep  92/10000 | LR: 0.000563 | Loss: 0.1750 | Pearson: 0.3392 | Best: 0.4560
# [Test] Fold 4 | Ep  92/10000 | Pearson: 0.2297 | Best: 0.3666
# Fold 4 | Ep  93/10000 | LR: 0.000555 | Loss: 0.1699 | Pearson: 0.3439 | Best: 0.4560
# [Test] Fold 4 | Ep  93/10000 | Pearson: 0.2317 | Best: 0.3666
# Fold 4 | Ep  94/10000 | LR: 0.000548 | Loss: 0.1558 | Pearson: 0.3447 | Best: 0.4560
# [Test] Fold 4 | Ep  94/10000 | Pearson: 0.2500 | Best: 0.3666
# Fold 4 | Ep  95/10000 | LR: 0.000540 | Loss: 0.1445 | Pearson: 0.3005 | Best: 0.4560
# [Test] Fold 4 | Ep  95/10000 | Pearson: 0.2152 | Best: 0.3666
# Fold 4 | Ep  96/10000 | LR: 0.000532 | Loss: 0.1522 | Pearson: 0.3331 | Best: 0.4560
# [Test] Fold 4 | Ep  96/10000 | Pearson: 0.2391 | Best: 0.3666
# Fold 4 | Ep  97/10000 | LR: 0.000524 | Loss: 0.1509 | Pearson: 0.3509 | Best: 0.4560
# [Test] Fold 4 | Ep  97/10000 | Pearson: 0.2534 | Best: 0.3666
# Fold 4 | Ep  98/10000 | LR: 0.000516 | Loss: 0.1431 | Pearson: 0.3566 | Best: 0.4560
# [Test] Fold 4 | Ep  98/10000 | Pearson: 0.2378 | Best: 0.3666
# Fold 4 | Ep  99/10000 | LR: 0.000508 | Loss: 0.1455 | Pearson: 0.3392 | Best: 0.4560
# [Test] Fold 4 | Ep  99/10000 | Pearson: 0.2592 | Best: 0.3666
# Fold 4 | Ep 100/10000 | LR: 0.000501 | Loss: 0.1390 | Pearson: 0.3389 | Best: 0.4560
# [Test] Fold 4 | Ep 100/10000 | Pearson: 0.2266 | Best: 0.3666
# Fold 4 | Ep 101/10000 | LR: 0.000493 | Loss: 0.1409 | Pearson: 0.3675 | Best: 0.4560
# [Test] Fold 4 | Ep 101/10000 | Pearson: 0.2461 | Best: 0.3666
# Fold 4 | Ep 102/10000 | LR: 0.000485 | Loss: 0.1411 | Pearson: 0.3185 | Best: 0.4560
# [Test] Fold 4 | Ep 102/10000 | Pearson: 0.2539 | Best: 0.3666
# Fold 4 | Ep 103/10000 | LR: 0.000477 | Loss: 0.1511 | Pearson: 0.3245 | Best: 0.4560
# [Test] Fold 4 | Ep 103/10000 | Pearson: 0.2060 | Best: 0.3666
# Fold 4 | Ep 104/10000 | LR: 0.000469 | Loss: 0.1390 | Pearson: 0.3131 | Best: 0.4560
# [Test] Fold 4 | Ep 104/10000 | Pearson: 0.2290 | Best: 0.3666
# Fold 4 | Ep 105/10000 | LR: 0.000461 | Loss: 0.1316 | Pearson: 0.3437 | Best: 0.4560
# [Test] Fold 4 | Ep 105/10000 | Pearson: 0.2302 | Best: 0.3666
# Fold 4 | Ep 106/10000 | LR: 0.000453 | Loss: 0.1449 | Pearson: 0.3266 | Best: 0.4560
# [Test] Fold 4 | Ep 106/10000 | Pearson: 0.2346 | Best: 0.3666
# Fold 4 | Ep 107/10000 | LR: 0.000446 | Loss: 0.1301 | Pearson: 0.3679 | Best: 0.4560
# [Test] Fold 4 | Ep 107/10000 | Pearson: 0.2280 | Best: 0.3666
# Fold 4 | Ep 108/10000 | LR: 0.000438 | Loss: 0.1360 | Pearson: 0.3008 | Best: 0.4560
# [Test] Fold 4 | Ep 108/10000 | Pearson: 0.2213 | Best: 0.3666
# Fold 4 | Ep 109/10000 | LR: 0.000430 | Loss: 0.1340 | Pearson: 0.3338 | Best: 0.4560
# [Test] Fold 4 | Ep 109/10000 | Pearson: 0.2432 | Best: 0.3666
# Fold 4 | Ep 110/10000 | LR: 0.000422 | Loss: 0.1280 | Pearson: 0.3202 | Best: 0.4560
# [Test] Fold 4 | Ep 110/10000 | Pearson: 0.2149 | Best: 0.3666
# Fold 4 | Ep 111/10000 | LR: 0.000415 | Loss: 0.1331 | Pearson: 0.3376 | Best: 0.4560
# [Test] Fold 4 | Ep 111/10000 | Pearson: 0.2292 | Best: 0.3666
# Fold 4 | Ep 112/10000 | LR: 0.000407 | Loss: 0.1238 | Pearson: 0.3003 | Best: 0.4560
# [Test] Fold 4 | Ep 112/10000 | Pearson: 0.2218 | Best: 0.3666
# Fold 4 | Ep 113/10000 | LR: 0.000399 | Loss: 0.1354 | Pearson: 0.3026 | Best: 0.4560
# [Test] Fold 4 | Ep 113/10000 | Pearson: 0.2062 | Best: 0.3666
# Fold 4 | Ep 114/10000 | LR: 0.000392 | Loss: 0.1178 | Pearson: 0.3270 | Best: 0.4560
# [Test] Fold 4 | Ep 114/10000 | Pearson: 0.2130 | Best: 0.3666
# Fold 4 | Ep 115/10000 | LR: 0.000384 | Loss: 0.1195 | Pearson: 0.3429 | Best: 0.4560
# [Test] Fold 4 | Ep 115/10000 | Pearson: 0.2314 | Best: 0.3666
# Fold 4 | Ep 116/10000 | LR: 0.000376 | Loss: 0.1254 | Pearson: 0.2958 | Best: 0.4560
# !!! Early Stopping triggered at epoch 116 !!!
#
# ========================================
# 5-Fold CV Average Pearson Correlation: 0.4597
# ========================================
